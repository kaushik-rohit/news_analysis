# %%
import pandas as pd
from gensim import models, corpora
from gensim.parsing.preprocessing import preprocess_string, strip_tags, strip_punctuation
from gensim.parsing.preprocessing import remove_stopwords, stem_text, strip_non_alphanum, strip_multiple_whitespaces
from gensim.parsing.preprocessing import strip_short, strip_numeric
from gensim.parsing.preprocessing import STOPWORDS
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from semantic_text_similarity.models import WebBertSimilarity
import multiprocessing as mp
import nltk
import pandas as pd
import numpy as np
import tensorflow as tf
from scipy import spatial
import parmap
import os
import swifter
from tqdm import tqdm
import sqlite3

# %%
topics_index_to_name_map = {
    0: 'Agriculture, animals, food and rural affairs',
    1: 'Asylum, immigration and nationality',
    2: 'Business, industry and consumers',
    3: 'Communities and families',
    4: 'Crime, civil law, justice and rights',
    5: 'Culture, media and sport',
    6: 'Defence',
    7: 'Economy and finance',
    8: 'Education',
    9: 'Employment and training',
    10: 'Energy and environment',
    11: 'European Union',
    12: 'Health services and medicine',
    13: 'Housing and planning',
    14: 'International affairs',
    15: 'Parliament, government and politics',
    16: 'Science and technology',
    17: 'Social security and pensions',
    18: 'Social services',
    19: 'Transport',
    20: 'Others'
}
topics_name_to_index_map = {y:x for x,y in topics_index_to_name_map.items()}

def strip_short2(text):
    return strip_short(text, minsize=4)


def preprocess_text(text):
    FILTERS = [lambda x: x.lower(), strip_multiple_whitespaces, strip_tags, strip_punctuation,
                   strip_non_alphanum, strip_numeric, strip_short2]
    return preprocess_string(text, FILTERS)

def preprocess(topic):
    ret = []
    topic = topic.strip()
    
    if '|' in topic:
        topics = topic.split('|')
        t = topics[0]
        t = t.strip()
        return topics_name_to_index_map[t]
        
    return topics_name_to_index_map[topic]

# %%
doc2vec_model = Doc2Vec.load('models/doc2vec/doc2vec_2010_2016_no_Others')

# %%
articles = pd.read_csv('./data/news_predictions/news_2016_predictions.csv')

# %%
articles = articles.dropna(subset=['transcript'])
articles = articles.drop(['Unnamed: 0'], axis=1)
articles = articles.loc[articles.month == 6]

# %%
vector = []
transcripts = articles.transcript.values

preprocessed_transcripts = parmap.map(preprocess_text, transcripts, pm_pbar=True)
# Out:
# 155392it [00:14, 10971.79it/s]

# %%
vector_transcripts = parmap.map(doc2vec_model.infer_vector, preprocessed_transcripts, pm_pbar=True)
articles['vector'] = vector_transcripts
# Out:
# 155392it [01:52, 1384.76it/s]

# %%
import datetime
articles['date'] = articles.apply(lambda x: datetime.date(x.year, x.month, x.day), axis=1)

# %%
print('preparing data!!')
df = pd.read_csv('./data/2016_debate.csv')
df = df.drop(df[df.topic == 'admin'].index)
df = df.drop(df[df.topic == 'Others'].index)
df = df.drop(df[df.transcript.str.split().map(len) < 10].index)
# Out:
# preparing data!!

# %%
df['vector'] = df.swifter.apply(lambda x: doc2vec_model.infer_vector(preprocess_text(x['transcript'])), axis=1)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Pandas Apply', max=2142.0, style=ProgressStyle(descriptio…

# %%
from dateutil import parser
df['date'] = df['date'].apply(lambda x: parser.parse(x).date())

# %%
df
# Out:
#             date                         topic  \
# 0     2016-01-05                       Defence
# 1     2016-01-05                European Union
# 2     2016-01-05        Energy and environment
# 3     2016-01-05           Economy and finance
# 4     2016-01-05  Health services and medicine
# ...          ...                           ...
# 2437  2016-12-20  Health services and medicine
# 2438  2016-12-20  Health services and medicine
# 2439  2016-12-20  Health services and medicine
# 2440  2016-12-20  Health services and medicine
# 2441  2016-12-20          Housing and planning
#
#                                              transcript  \
# 0     With permission, Mr Speaker, I will make a sta...
# 1     With permission, Mr Speaker, I would like to m...
# 2     With permission, Mr Speaker, I would like to m...
# 3     I thank the many colleagues who have stayed so...
# 4     14.  What steps his Department is taking to in...
# ...                                                 ...
# 2437  13. How many patient days of delayed discharge...
# 2438  10. What assessment he has made of the potenti...
# 2439  T2.  If he will make a statement on his depart...
# 2440  15. What assessment he has made of the potenti...
# 2441  I beg to move,  That this House has considered...
#
#                                                  vector
# 0     [0.0038627787, 0.16613455, 0.7865501, -0.02226...
# 1     [0.08787448, -1.0847125, 1.7855617, -0.9878115...
# 2     [-0.54103595, -0.8347334, -0.19081135, 2.35676...
# 3     [-1.5605081, -0.7581342, 1.0427865, 0.28244412...
# 4     [-0.5808947, 0.52790385, 0.5559714, 1.5502323,...
# ...                                                 ...
# 2437  [-1.2311676, -0.5779405, -0.5349262, -0.414065...
# 2438  [-0.8975457, -0.15285091, 0.819843, 0.14723383...
# 2439  [-0.13278913, 1.2363504, 0.85807025, 1.251639,...
# 2440  [0.66957015, 0.7701326, -2.025422, 1.739207, -...
# 2441  [-1.0638325, 0.5223639, 0.74000883, -2.6005847...
#
# [2142 rows x 4 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity
from datetime import datetime, timedelta
def predict(news):
    dt = news.date
    news_vector = np.array(news.vector)
    news_vector = news_vector.reshape(1, 100)
    df_vector = df.vector.values
    vec = [df_vector[i] for i in range(len(df_vector))]
    vec = np.array(vec)
    max_index = -1
    max_sim = -1
    sim = cosine_similarity(news_vector, vec)
    max_index = np.argmax(sim)
    
    return df.iloc[max_index]['topic']

# %%
predict(articles.iloc[4])
# Out:
# 'Agriculture, animals, food and rural affairs'

# %%
preds = []

for index, row in tqdm(articles.iterrows(), total=len(articles)):
    preds.append(predict(row))
    
articles['prediction_cosine'] = preds
# Out:
#   1%|▏         | 2274/155293 [00:05<06:04, 420.32it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-98-869e41acc855> in <module>
#       2
#       3 for index, row in tqdm(articles.iterrows(), total=len(articles)):
# ----> 4     preds.append(predict(row))
#       5
#       6 articles['prediction_cosine'] = preds
#
# <ipython-input-96-f61410afd22b> in predict(news)
#       6     news_vector = news_vector.reshape(1, 100)
#       7     df_vector = df.vector.values
# ----> 8     vec = [df_vector[i] for i in range(len(df_vector))]
#       9     vec = np.array(vec)
#      10     max_index = -1
#
# <ipython-input-96-f61410afd22b> in <listcomp>(.0)
#       6     news_vector = news_vector.reshape(1, 100)
#       7     df_vector = df.vector.values
# ----> 8     vec = [df_vector[i] for i in range(len(df_vector))]
#       9     vec = np.array(vec)
#      10     max_index = -1
#
# KeyboardInterrupt:

# %%
articles
# Out:
#         source_id             source  day  month  year  \
# 815059     163795  Belfast Telegraph    1      6  2016
# 815060     163795  Belfast Telegraph    1      6  2016
# 815061     163795  Belfast Telegraph    1      6  2016
# 815062     163795  Belfast Telegraph    1      6  2016
# 815063     163795  Belfast Telegraph    1      6  2016
# ...           ...                ...  ...    ...   ...
# 970363     412338              Wales   30      6  2016
# 970364     412338              Wales   30      6  2016
# 970365     412338              Wales   30      6  2016
# 970366     412338              Wales   30      6  2016
# 970367     412338              Wales   30      6  2016
#
#                                              program_name  \
# 815059  North West 'needs task force on jobs to be rev...
# 815060             Time to take your town centre to heart
# 815061                     Causeway Coast for food heaven
# 815062  Here comes summer - time for Country Kitchen s...
# 815063                       NI for the cream of the crop
# ...                                                   ...
# 970363  Amazon announce Second Prime Day shopping even...
# 970364  Morning news headlines: Boris Johnson and Ther...
# 970365  Inspection finds Welsh police force kept too m...
# 970366  Inspection found that a Welsh police force kep...
# 970367  Inquiry finds parents were 'let down' by stand...
#
#                                                transcript  parliament  \
# 815059  Gavin Killeen, who said more needs to be done ...           1
# 815060  Rather than complain, residents can participat...           1
# 815061  Despite its infancy, the CCAG Food Network has...           1
# 815062  Country Kitchen side salads are the perfect ac...           1
# 815063  Comber Earlies - in season now, Lough Neagh Ee...           1
# ...                                                   ...         ...
# 970363  Prime Day will take place on July 12, with the...           1
# 970364  Tory heavyweights Boris Johnson and Theresa Ma...           1
# 970365  HM Inspectorate of Constabulary (HMIC) publish...           1
# 970366  HM Inspectorate of Constabulary (HMIC) publish...           1
# 970367  A review commissioned by NHS England Medical D...           1
#
#                                           top1_topic  top1_acc  \
# 815059           Parliament, government and politics     72.42
# 815060                      Culture, media and sport     24.98
# 815061                      Culture, media and sport     52.31
# 815062                      Culture, media and sport     28.93
# 815063  Agriculture, animals, food and rural affairs     40.33
# ...                                              ...       ...
# 970363              Business, industry and consumers     20.31
# 970364           Parliament, government and politics     25.05
# 970365          Crime, civil law, justice and rights     39.50
# 970366          Crime, civil law, justice and rights     35.47
# 970367                  Health services and medicine     76.88
#
#                                           top2_topic  top2_acc  \
# 815059              Business, industry and consumers      6.75
# 815060              Business, industry and consumers     23.64
# 815061  Agriculture, animals, food and rural affairs     17.63
# 815062                                        Others     24.34
# 815063                      Culture, media and sport     39.01
# ...                                              ...       ...
# 970363                                        Others     15.73
# 970364                      Culture, media and sport     18.58
# 970365                      Communities and families     11.34
# 970366                      Communities and families     14.13
# 970367                                        Others     16.05
#
#                                           top3_topic  top3_acc  \
# 815059                           Economy and finance      4.93
# 815060  Agriculture, animals, food and rural affairs     10.36
# 815061              Business, industry and consumers      8.31
# 815062              Business, industry and consumers     10.81
# 815063                                        Others      4.54
# ...                                              ...       ...
# 970363                                     Transport      6.81
# 970364                         International affairs     17.69
# 970365           Parliament, government and politics      9.34
# 970366                  Health services and medicine     10.10
# 970367                      Communities and families      1.26
#
#                                                    vector        date  \
# 815059  [0.21521333, -0.61631656, 1.1988628, 0.2426858...  2016-06-01
# 815060  [0.09298251, 1.0889144, 2.142314, -1.4128298, ...  2016-06-01
# 815061  [1.4593987, 1.3749042, 0.7192617, 1.3394088, 1...  2016-06-01
# 815062  [0.0028712775, 0.92605275, -0.25203443, -0.232...  2016-06-01
# 815063  [0.3191508, 1.3862733, 0.52248347, 1.443869, 1...  2016-06-01
# ...                                                   ...         ...
# 970363  [1.3523831, -0.6249906, 2.4624922, 1.0074334, ...  2016-06-30
# 970364  [-0.42023158, 0.48719677, -0.2652266, -0.17420...  2016-06-30
# 970365  [-2.9431205, 0.49691546, -2.0984313, 0.6602685...  2016-06-30
# 970366  [-3.0568829, 0.4597003, -1.9608382, 0.8233612,...  2016-06-30
# 970367  [-3.0266054, -0.39138258, 0.40667287, -0.94656...  2016-06-30
#
#                                         prediction_cosine
# 815059                Parliament, government and politics
# 815060       Agriculture, animals, food and rural affairs
# 815061       Agriculture, animals, food and rural affairs
# 815062       Agriculture, animals, food and rural affairs
# 815063       Agriculture, animals, food and rural affairs
# ...                                                   ...
# 970363                           Communities and families
# 970364                              International affairs
# 970365  Communities and families | Crime, civil law, j...
# 970366  Communities and families | Crime, civil law, j...
# 970367                           Communities and families
#
# [155293 rows x 17 columns]

# %%
articles.to_csv('news_prediction_June_cosine_sim_no_Others.csv')
