# %%
import pandas as pd
from gensim import models, corpora
from gensim.parsing.preprocessing import preprocess_string, strip_tags, strip_punctuation
from gensim.parsing.preprocessing import remove_stopwords, stem_text, strip_non_alphanum, strip_multiple_whitespaces
from gensim.parsing.preprocessing import strip_short, strip_numeric
from gensim.parsing.preprocessing import STOPWORDS
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from sklearn.utils import class_weight
import multiprocessing as mp
import nltk
import pandas as pd
import numpy as np
import tensorflow as tf
import parmap
import ast

# %%
topics_index_to_name_map = {
    0: 'Agriculture, animals, food and rural affairs',
    1: 'Asylum, immigration and nationality',
    2: 'Business, industry and consumers',
    3: 'Communities and families',
    4: 'Crime, civil law, justice and rights',
    5: 'Culture, media and sport',
    6: 'Defence',
    7: 'Economy and finance',
    8: 'Education',
    9: 'Employment and training',
    10: 'Energy and environment',
    11: 'European Union',
    12: 'Health services and medicine',
    13: 'Housing and planning',
    14: 'International affairs',
    15: 'Parliament, government and politics',
    16: 'Science and technology',
    17: 'Social security and pensions',
    18: 'Social services',
    19: 'Transport',
    20: 'Others'
}
topics_name_to_index_map = {y:x for x,y in topics_index_to_name_map.items()}

topics = list(topics_name_to_index_map.keys())

def strip_short2(text):
    return strip_short(text, minsize=4)


def preprocess_text(text):
    FILTERS = [lambda x: x.lower(), strip_multiple_whitespaces, strip_tags, strip_punctuation,
                   strip_non_alphanum, strip_numeric, strip_short2]
    return preprocess_string(text, FILTERS)

def preprocess(topic):
    ret = []
    topic = topic.strip()
    
    if '|' in topic:
        topics = topic.split('|')
        t = topics[0]
        t = t.strip()
        return topics_name_to_index_map[t]
        
    return topics_name_to_index_map[topic]

# %%
year = 2018

# %%
news_pred = pd.read_csv('../data/news_predictions/news_{}_predictions.csv'.format(year))

# %%
sources = news_pred['source'].unique()

# %%
counts = {month:{source: {topic:0 for topic in topics} for source in sources} for month in range(1, 13)}

# %%
news_pred.head()
# Out:
#    Unnamed: 0  source_id             source  day  month  year  \
# 0           0     163795  Belfast Telegraph    1      1  2018
# 1           1     163795  Belfast Telegraph    1      1  2018
# 2           2     163795  Belfast Telegraph    1      1  2018
# 3           3     163795  Belfast Telegraph    1      1  2018
# 4           4     163795  Belfast Telegraph    1      1  2018
#
#                                         program_name  \
# 0  Shocking number of nurses giving up jobs in NI...
# 1             City's record run ends on a sore point
# 2  Fears for health service as hundreds of downtr...
# 3  Outrage after children witness man being assau...
# 4  Diabetes drug could be used in battle with Alz...
#
#                                           transcript  parliament  \
# 0                             Full story, see page 4         NaN
# 1  But injuries to Gabriel Jesus and this season'...         NaN
# 2  Just under 600 nurses and midwives left the Nu...         NaN
# 3  It marked the end of a year in which almost 10...         NaN
# 4  A so-called "triple receptor drug" created to ...         NaN
#
#                             top1_topic  top1_acc  \
# 0  Parliament, government and politics     26.78
# 1                               Others     50.70
# 2                      Social services     86.75
# 3  Parliament, government and politics     33.84
# 4         Health services and medicine     78.47
#
#                      top2_topic  top2_acc  \
# 0                        Others     14.83
# 1      Culture, media and sport      8.24
# 2  Health services and medicine      8.91
# 3                        Others     23.80
# 4                        Others      3.60
#
#                              top3_topic  top3_acc
# 0  Crime, civil law, justice and rights      7.30
# 1              Communities and families      7.92
# 2                                Others      2.19
# 3  Crime, civil law, justice and rights     20.98
# 4                Energy and environment      2.34

# %%
for index, row in news_pred.iterrows():
    month = row['month']
    source = row['source']
    topic = row['top1_topic']
    counts[month][source][topic] += 1

# %%
rows = []

# %%
for month in range(1, 13):
    for source in sources:
        row = [month, source]
        for topic in topics:
            row.append(counts[month][source][topic])
        rows.append(row)
columns = ['month', 'source'] + topics
df = pd.DataFrame(rows, columns=columns)

# %%
df = df.sort_values(by=['month', 'source'])

# %%
df
# Out:
#      month             source  Agriculture, animals, food and rural affairs  \
# 0        1  Belfast Telegraph                                           198
# 1        1            Express                                           381
# 2        1           Guardian                                           174
# 3        1             Herald                                            91
# 4        1        Independent                                           243
# ..     ...                ...                                           ...
# 210     12           Standard                                           100
# 211     12               Star                                           167
# 215     12                Sun                                            40
# 212     12          Telegraph                                           431
# 213     12              Wales                                            97
#
#      Asylum, immigration and nationality  Business, industry and consumers  \
# 0                                      3                               539
# 1                                      8                               746
# 2                                     12                               214
# 3                                      3                               190
# 4                                     19                               446
# ..                                   ...                               ...
# 210                                    8                               126
# 211                                    1                               109
# 215                                    0                                11
# 212                                   17                               609
# 213                                    0                                67
#
#      Communities and families  Crime, civil law, justice and rights  \
# 0                          47                                   678
# 1                          31                                   266
# 2                          45                                   185
# 3                          10                                   155
# 4                          40                                   299
# ..                        ...                                   ...
# 210                        14                                   116
# 211                         8                                    94
# 215                         8                                    13
# 212                        34                                   298
# 213                         4                                   113
#
#      Culture, media and sport  Defence  Economy and finance  ...  \
# 0                        2790      160                  331  ...
# 1                        6957      293                  751  ...
# 2                        1298       50                  190  ...
# 3                         544       37                  107  ...
# 4                        2142      121                  365  ...
# ..                        ...      ...                  ...  ...
# 210                      1718       40                   69  ...
# 211                      3048      106                   30  ...
# 215                       168        3                    3  ...
# 212                      2476      127                  428  ...
# 213                       538        7                   11  ...
#
#      European Union  Health services and medicine  Housing and planning  \
# 0                98                           481                    10
# 1               641                           711                     6
# 2                87                           201                     9
# 3                21                           134                     2
# 4               239                           427                     8
# ..              ...                           ...                   ...
# 210             120                            97                     0
# 211              44                           114                     0
# 215               3                            17                     0
# 212             442                           327                     5
# 213              18                            75                     4
#
#      International affairs  Parliament, government and politics  \
# 0                      386                                 2045
# 1                      713                                 1524
# 2                      327                                  455
# 3                      114                                  689
# 4                      772                                  586
# ..                     ...                                  ...
# 210                     95                                  254
# 211                     81                                  295
# 215                      6                                   51
# 212                    453                                 1275
# 213                     14                                  386
#
#      Science and technology  Social security and pensions  Social services  \
# 0                         1                             0               71
# 1                         2                             0               10
# 2                         0                             0               21
# 3                         0                             0                4
# 4                         7                             1               20
# ..                      ...                           ...              ...
# 210                       0                             0                1
# 211                       3                             0                6
# 215                       0                             0                5
# 212                       1                             0               13
# 213                       0                             0               29
#
#      Transport  Others
# 0          502    2470
# 1          795    3638
# 2          151    1063
# 3          158     541
# 4          357    1738
# ..         ...     ...
# 210        240     983
# 211        195    1598
# 215         35     247
# 212        467    2279
# 213        109     529
#
# [216 rows x 23 columns]

# %%
df.to_csv('counts_news_count_by_source_{}.csv'.format(year))

# %%
count_by_month = df.drop(['source'], axis=1).groupby(['month'], as_index=False).sum()

# %%
count_by_month.to_csv('count_by_month_{}.csv'.format(year))

# %% [markdown]
# # BBC COUNTS

# %%
bbc_sources = [54, 106, 107, 175, 279]
years = [2014, 2015, 2016, 2017]

# %%
for year in years:
    print(year)
    counts = {month:{source: {topic:0 for topic in topics} for source in bbc_sources} for month in range(1, 13)}
    word_counts = {month:{source: {topic:0 for topic in topics} for source in bbc_sources} for month in range(1, 13)}
    for source in bbc_sources:
        df = pd.read_csv('../data/partition_predictions/topics_pred_on_bert_partitioned_bbc_{}_{}_with_news_classifier_no_Others.csv'.format(source, year))
        df = df.drop(['Unnamed: 0'], axis=1)
        df['date'] = pd.to_datetime(df['date'])
        df['topic'] = df['topic'].apply(lambda x: ast.literal_eval(x)[0][0])
        display(df.head())
        for index, row in df.iterrows():
            month = row['date'].month
            topic = row['topic']
            counts[month][source][topic] += 1
            word_counts[month][source][topic] += len(row.transcript.split())
            
    rows = []
    word_count_rows = []
    
    for month in range(1, 13):
        for source in bbc_sources:
            row = [month, source]
            word_count_row = [month, source]
            
            for topic in topics:
                row.append(counts[month][source][topic])
                word_count_row.append(word_counts[month][source][topic])
            rows.append(row)
            word_count_rows.append(word_count_row)
            
    columns = ['month', 'source'] + topics
    res_df = pd.DataFrame(rows, columns=columns)
    res_df.to_csv('./bbc_partition_count_by_source_topic_{}.csv'.format(year), index=False)
    res_df = pd.DataFrame(word_count_rows, columns=columns)
    res_df.to_csv('./bbc_partition_word_count_by_source_topic_{}.csv'.format(year), index=False)
# Out:
# 2014
#    partition_id       date                                         transcript  \
# 0             0 2014-12-06  # Oh, yeah # I see your smiling face # Like I’...
# 1             0 2014-12-06  Two hostages are killed in Yemen during a fail...
# 2             0 2014-12-06  Our hearts are full of sorrow tonight, our pra...
# 3             0 2014-12-06  Ferocious winds and torrential rain in the eas...
# 4             0 2014-12-06  President Obama has condemned as "barbaric" th...
#
#                                  topic
# 0             Culture, media and sport
# 1  Parliament, government and politics
# 2  Parliament, government and politics
# 3             Culture, media and sport
# 4                              Defence
#    partition_id       date                                         transcript  \
# 0             0 2014-07-05  A woman should have two good things, good heel...
# 1             0 2014-07-05  Susan needs 31 points to leap frog Stuart and ...
# 2             0 2014-07-05  I was a bit over come, I burst into tears and ...
# 3             0 2014-07-05  (HE LAUGHS) l’ve loved it, l’ve met four reall...
# 4             0 2014-07-05  # Bon-bon-bon-bon-bon-bonkers...# Subtitles by...
#
#                                  topic
# 0  Parliament, government and politics
# 1             Culture, media and sport
# 2  Parliament, government and politics
# 3             Culture, media and sport
# 4  Parliament, government and politics
#    partition_id       date                                         transcript  \
# 0             0 2014-05-04  # You know it's true # itfc subtitles ~ Welcom...
# 1             0 2014-05-04  This is the scene outside the police Sinn Fein...
# 2             0 2014-05-04  Ed Miliband has called for an independent revi...
# 3             0 2014-05-04  South Korea's President has met with the relat...
# 4             0 2014-05-04  Subtitles It will be a dry night tonight for m...
#
#                                   topic
# 0              Culture, media and sport
# 1  Crime, civil law, justice and rights
culture, media and sport
#    partition_id       date                                         transcript  \
# 0             0 2017-02-05  But if the President is fuming, it’s because h...
# 1             0 2017-02-05  First, his travel ban was overturned by a fede...
# 2             0 2017-02-05  That interview wiLL be played just before the ...
# 3             0 2017-02-05  Marine Le Pen Launched her run at the presiden...
# 4             0 2017-02-05  And Welsh star, new hero, George North runs th...
#
#                       topic
# 0  Culture, media and sport
# 1  Culture, media and sport
# 2  Culture, media and sport
# 3  Culture, media and sport
# 4  Culture, media and sport
#    partition_id       date                                         transcript  \
# 0             0 2017-01-01  For now, from aLL of us here, it’s goodbye Aar...
# 1             0 2017-01-01  Good evening, the headlines: Police in Turkey ...
# 2             0 2017-01-01  She had blood all and saw her on the floor. Sh...
# 3             0 2017-01-01  The Queen has missed the New Year The Queen ha...
# 4             1 2017-01-08  Your headlines: The Prime Minister has hinted ...
#
#                                   topic
# 0              Culture, media and sport
# 1  Crime, civil law, justice and rights
# 2              Culture, media and sport
# 3   Parliament, government and politics
# 4                        European Union
#    partition_id       date                                         transcript  \
# 0             0 2017-08-06  The world’s fastest man - Usain Bolt - says he...
# 1             0 2017-08-06  The United Nations Security Council has voted ...
# 2             0 2017-08-06  The government has launched an independent rev...
# 3             0 2017-08-06  Until then, from us all here, have a very good...
# 4             0 2017-08-06  Music today is from one of Ireland’s most famo...
#
#                       topic
# 0  Culture, media and sport
# 1       Economy and finance
# 2    Energy and environment
# 3  Culture, media and sport
# 4  Culture, media and sport
#    partition_id       date                                         transcript  \
# 0             0 2017-10-01  Violence in Catalonia, as the Spanish governme...
# 1             0 2017-10-01  Do you think years after your Job’ job} Do you...
# 2             0 2017-10-01  Two women are killed by a knifeman in a suspec...
# 3             0 2017-10-01  Catalan officials say more than 700 people hav...
# 4             0 2017-10-01  Riot police using extraordinary force to preve...
#
#                                  topic
# 0             Culture, media and sport
# 1  Parliament, government and politics
# 2             Culture, media and sport
# 3  Parliament, government and politics
# 4             Culture, media and sport

# %% [markdown]
# # PARTITION COUNTS WINDOW TOPIC PREDICTION

# %%
years = [2014, 2015, 2016, 2017, 2018]

for year in years:
    print(year)
    counts = {month:{topic:0 for topic in topics} for month in range(1, 13)}
    word_counts = {month:{topic:0 for topic in topics} for month in range(1, 13)}

    df = pd.read_csv('./window_topic_prediction_with_short_sentences_merged_54_{}.csv'.format(year))
    df = df.drop(['Unnamed: 0'], axis=1)
    # df.columns = ['partition_id', 'date', 'transcript', 'topic']
    df['date'] = pd.to_datetime(df['date'])
    # df['topic'] = df['topic'].apply(lambda x: ast.literal_eval(x)[0][0])

    last_topic = None
    for index, row in df.iterrows():
        month = row['date'].month
        topic = row['topic']
        if topic != last_topic:
            counts[month][topic] += 1
        last_topic = topic
        word_counts[month][topic] += len(row.transcript.split())

    others_df = pd.read_csv('./dropped_partitions_54_{}.csv'.format(year))
    others_df = others_df.drop(['Unnamed: 0'], axis=1)
    others_df['date'] = pd.to_datetime(others_df['date'])

    for index, row in others_df.iterrows():
        month = row['date'].month
        topic = 'Others'
        counts[month][topic] += 1
        word_counts[month][topic] += len(row.transcript.split())

    rows = []
    word_count_rows = []

    for month in range(1, 13):
        row = [month]
        word_count_row = [month]

        for topic in topics:
            row.append(counts[month][topic])
            word_count_row.append(word_counts[month][topic])
        rows.append(row)
        word_count_rows.append(word_count_row)

    columns = ['month'] + topics
    res_df = pd.DataFrame(rows, columns=columns)
    res_df.to_csv('./bbc_partition_count_by_source_topic_{}.csv'.format(year), index=False)
    res_df = pd.DataFrame(word_count_rows, columns=columns)
    res_df.to_csv('./bbc_partition_word_count_by_source_topic_{}.csv'.format(year), index=False)
# Out:
# 2014
# 2015
# 2016
# 2017
# 2018

# %% [markdown]
# # BBC News at One, Six, Ten partition count

# %%
years = list(range(2014, 2019))
rows = []
word_count_rows = []

for year in years:
    df = pd.read_csv('../data/partition_predictions/window_topic_prediction_with_short_sentences_merged_54_{}.csv'.format(year))

    programs = ['BBC News at One', 'BBC News at Six', 'BBC News at Ten']

    counts = {month:{program:0 for program in programs} for month in range(1, 13)}
    word_counts = {month:{program:0 for program in programs} for month in range(1, 13)}

    for program in programs:
        print(program, year)
        df_p = df.loc[df.source == program]
        df_p = df_p.drop(['Unnamed: 0'], axis=1)
        print(program, year)
        print(len(df_p))
        # df.columns = ['partition_id', 'date', 'transcript', 'topic']
        df_p['date'] = pd.to_datetime(df_p['date'])
        # df['topic'] = df['topic'].apply(lambda x: ast.literal_eval(x)[0][0])
        display(df_p.head())

        last_topic = None
        for index, row in df_p.iterrows():
            month = row['date'].month
            topic = row['topic']
            if topic != last_topic:
                counts[month][program] += 1
            last_topic = topic
            word_counts[month][program] += len(row.transcript.split())

        for month in range(1, 13):
            row = [year, month]
            word_count_row = [year, month]

            for program in programs:
                row.append(counts[month][program])
                word_count_row.append(word_counts[month][program])
            rows.append(row)
            word_count_rows.append(word_count_row)

columns = ['year', 'month'] + programs
res_df = pd.DataFrame(rows, columns=columns)
res_df.to_csv('./bbc_news_at_one_six_ten_partition_count.csv', index=False)
res_df = pd.DataFrame(word_count_rows, columns=columns)
res_df.to_csv('./bbc_news_at_one_six_ten_word_count.csv', index=False)
# Out:
# BBC News at One 2014
# BBC News at One 2014
# 6659
#      partition_id       date           source  \
# 207           445 2014-03-04  BBC News at One
# 208           445 2014-03-04  BBC News at One
# 209           445 2014-03-04  BBC News at One
# 210           445 2014-03-04  BBC News at One
# 211           445 2014-03-04  BBC News at One
#
#                                             transcript type  \
# 207   Yanukovych its legitimate president. Russian ...    p
# 208   As Vladimir Putin warns the West that sanctio...    p
# 209   Also this lunchtime... At the Oscar Pistorius...    p
# 210   On display for the first time ever in Britain...    p
# 211   And this is an exhibition that gives showers ...    p
#
#                         topic
# 207     International affairs
# 208     International affairs
# 209                 Education
# 210  Culture, media and sport
# 211  Communities and families
# BBC News at Six 2014
# BBC News at Six 2014
# 8177
#      partition_id       date           source  \
# 133           442 2014-03-07  BBC News at Six
# 134           442 2014-03-07  BBC News at Six
# 135           442 2014-03-07  BBC News at Six
# 136           442 2014-03-07  BBC News at Six
# 137           442 2014-03-07  BBC News at Six
#
#                                             transcript type  \
# 133   The head ofthe The head of the Metropolitan P...    p
# 134   Vladimir Putin opens the Winter Paralympics i...    p
# 135   Network Rail apologises unreservedly for what...    p
# 136   The cost of a pint of milk going down, as the...    p
# 137   And trenches where the First World War’s sold...    p
#
#                                    topic
# 820   And laughing all the way to the football Worl...    p
#
#                                    topic
# 816                       European Union
# 817                       European Union
# 818  Parliament, government and politics
# 819  Parliament, government and politics
# 820  Parliament, government and politics

# %%
df['source'].unique()
# Out:
# array(['BBC News', 'BBC London News', 'BBC News at One',
#        'BBC News at Six', 'BBC News at Ten',
#        'BBC News Special: May Leadership Challenge'], dtype=object)

# %%
res_df
# Out:
#      year  month  BBC News at One  BBC News at Six  BBC News at Ten
# 0    2014      1            55031                0                0
# 1    2014      2            72284                0                0
# 2    2014      3            45821                0                0
# 3    2014      4            31898                0                0
# 4    2014      5            93214                0                0
# ..    ...    ...              ...              ...              ...
# 175  2018      8           117004           166044           141136
# 176  2018      9           121208           141635           130903
# 177  2018     10           105169           173801           143380
# 178  2018     11           151798           143477           138502
# 179  2018     12           101451           126334           104155
#
# [180 rows x 5 columns]

# %%
rows
# Out:
# [[2014, 1, 317, 0, 0],
#  [2014, 2, 395, 0, 0],
#  [2014, 3, 266, 0, 0],
#  [2014, 4, 193, 0, 0],
#  [2014, 5, 589, 0, 0],
#  [2014, 6, 593, 0, 0],
#  [2014, 7, 668, 0, 0],
#  [2014, 8, 466, 0, 0],
#  [2014, 9, 405, 0, 0],
#  [2014, 10, 455, 0, 0],
#  [2014, 11, 384, 0, 0],
#  [2014, 12, 436, 0, 0],
#  [2014, 1, 317, 332, 0],
#  [2014, 2, 395, 629, 0],
#  [2014, 3, 266, 439, 0],
#  [2014, 4, 193, 384, 0],
#  [2014, 5, 589, 617, 0],
#  [2014, 6, 593, 561, 0],
#  [2014, 7, 668, 667, 0],
#  [2014, 8, 466, 541, 0],
#  [2014, 9, 405, 496, 0],
#  [2014, 10, 455, 569, 0],
#  [2014, 11, 384, 559, 0],
#  [2014, 12, 436, 489, 0],
#  [2014, 1, 317, 332, 549],
#  [2014, 2, 395, 629, 500],
#  [2014, 3, 266, 439, 518],
#  [2014, 4, 193, 384, 469],
#  [2014, 5, 589, 617, 598],
#  [2014, 6, 593, 561, 499],
#  [2014, 7, 668, 667, 484],
#  [2014, 8, 466, 541, 445],
#  [2014, 9, 405, 496, 461],
#  [2014, 10, 455, 569, 532],
#  [2014, 11, 384, 559, 523],
#  [2014, 12, 436, 489, 490],
#  [2015, 1, 554, 0, 0],
#  [2015, 2, 649, 0, 0],
#  [2015, 3, 710, 0, 0],
#  [2015, 4, 677, 0, 0],
#  [2015, 5, 605, 0, 0],
#  [2015, 6, 541, 0, 0],
#  [2015, 7, 491, 0, 0],
#  [2015, 8, 451, 0, 0],
#  [2015, 9, 514, 0, 0],
#  [2015, 10, 615, 0, 0],
#  [2015, 11, 509, 0, 0],
#  [2015, 12, 412, 0, 0],
#  [2015, 1, 554, 512, 0],
#  [2015, 2, 649, 586, 0],
#  [2015, 3, 710, 581, 0],
#  [2015, 4, 677, 544, 0],
#  [2015, 5, 605, 513, 0],
#  [2015, 6, 541, 592, 0],
#  [2015, 7, 491, 644, 0],
#  [2015, 8, 451, 644, 0],
#  [2015, 9, 514, 683, 0],
#  [2015, 10, 615, 680, 0],
#  [2015, 11, 509, 621, 0],
#  [2015, 12, 412, 523, 0],
#  [2015, 1, 554, 512, 520],
#  [2015, 2, 649, 586, 439],
#  [2015, 3, 710, 581, 515],
#  [2015, 4, 677, 544, 408],
#  [2015, 5, 605, 513, 429],
#  [2015, 6, 541, 592, 550],
#  [2015, 7, 491, 644, 648],
#  [2015, 8, 451, 644, 518],
#  [2015, 9, 514, 683, 586],
#  [2015, 10, 615, 680, 543],
#  [2015, 11, 509, 621, 561],
#  [2015, 12, 412, 523, 460],
#  [2016, 1, 534, 0, 0],
#  [2016, 2, 520, 0, 0],
#  [2016, 3, 272, 0, 0],
#  [2016, 4, 231, 0, 0],
#  [2016, 5, 468, 0, 0],
#  [2016, 6, 534, 0, 0],
#  [2016, 7, 432, 0, 0],
#  [2016, 8, 559, 0, 0],
#  [2016, 9, 551, 0, 0],
#  [2016, 10, 501, 0, 0],
#  [2016, 11, 548, 0, 0],
#  [2016, 12, 427, 0, 0],
#  [2016, 1, 534, 488, 0],
#  [2016, 2, 520, 558, 0],
#  [2016, 3, 272, 287, 0],
#  [2016, 4, 231, 13, 0],
#  [2016, 5, 468, 242, 0],
#  [2016, 6, 534, 481, 0],
#  [2016, 7, 432, 418, 0],
#  [2016, 8, 559, 622, 0],
#  [2016, 9, 551, 614, 0],
#  [2016, 10, 501, 613, 0],
#  [2016, 11, 548, 619, 0],
#  [2016, 12, 427, 513, 0],
#  [2016, 1, 534, 488, 513],
#  [2016, 2, 520, 558, 457],
#  [2016, 3, 272, 287, 281],
#  [2016, 4, 231, 13, 0],
#  [2016, 5, 468, 242, 349],
#  [2016, 6, 534, 481, 405],
#  [2016, 7, 432, 418, 464],
#  [2016, 8, 559, 622, 513],
#  [2016, 9, 551, 614, 582],
#  [2016, 10, 501, 613, 599],
#  [2016, 11, 548, 619, 588],
#  [2016, 12, 427, 513, 475],
#  [2017, 1, 630, 0, 0],
#  [2017, 2, 544, 0, 0],
#  [2017, 3, 537, 0, 0],
#  [2017, 4, 470, 0, 0],
#  [2017, 5, 522, 0, 0],
#  [2017, 6, 484, 0, 0],
#  [2017, 7, 485, 0, 0],
#  [2017, 8, 591, 0, 0],
#  [2017, 9, 557, 0, 0],
#  [2017, 10, 572, 0, 0],
#  [2017, 11, 579, 0, 0],
#  [2017, 12, 397, 0, 0],
#  [2017, 1, 630, 569, 0],
#  [2017, 2, 544, 577, 0],
#  [2017, 3, 537, 603, 0],
#  [2017, 4, 470, 574, 0],
#  [2017, 5, 522, 586, 0],
#  [2017, 6, 484, 566, 0],
#  [2017, 7, 485, 642, 0],
#  [2017, 8, 591, 770, 0],
#  [2017, 9, 557, 715, 0],
#  [2017, 10, 572, 608, 0],
#  [2017, 11, 579, 626, 0],
#  [2017, 12, 397, 453, 0],
#  [2017, 1, 630, 569, 625],
#  [2017, 2, 544, 577, 553],
#  [2017, 3, 537, 603, 620],
#  [2017, 4, 470, 574, 563],
#  [2017, 5, 522, 586, 636],
#  [2017, 6, 484, 566, 529],
#  [2017, 7, 485, 642, 621],
#  [2017, 8, 591, 770, 684],
#  [2017, 9, 557, 715, 575],
#  [2017, 10, 572, 608, 618],
#  [2017, 11, 579, 626, 677],
#  [2017, 12, 397, 453, 429],
#  [2018, 1, 534, 0, 0],
#  [2018, 2, 456, 0, 0],
#  [2018, 3, 526, 0, 0],
#  [2018, 4, 473, 0, 0],
#  [2018, 5, 485, 0, 0],
#  [2018, 6, 455, 0, 0],
#  [2018, 7, 486, 0, 0],
#  [2018, 8, 400, 0, 0],
#  [2018, 9, 381, 0, 0],
#  [2018, 10, 351, 0, 0],
#  [2018, 11, 434, 0, 0],
#  [2018, 12, 301, 0, 0],
#  [2018, 1, 534, 655, 0],
#  [2018, 2, 456, 552, 0],
#  [2018, 3, 526, 638, 0],
#  [2018, 4, 473, 538, 0],
#  [2018, 5, 485, 584, 0],
#  [2018, 6, 455, 469, 0],
#  [2018, 7, 486, 610, 0],
#  [2018, 8, 400, 603, 0],
#  [2018, 9, 381, 477, 0],
#  [2018, 10, 351, 649, 0],
#  [2018, 11, 434, 531, 0],
#  [2018, 12, 301, 384, 0],
#  [2018, 1, 534, 655, 672],
#  [2018, 2, 456, 552, 588],
#  [2018, 3, 526, 638, 674],
#  [2018, 4, 473, 538, 540],
#  [2018, 5, 485, 584, 634],
#  [2018, 6, 455, 469, 461],
#  [2018, 7, 486, 610, 637],
#  [2018, 8, 400, 603, 638],
#  [2018, 9, 381, 477, 547],
#  [2018, 10, 351, 649, 709],
#  [2018, 11, 434, 531, 623],
#  [2018, 12, 301, 384, 446]]

# %%
years = list(range(2014, 2019))
rows = []
word_count_rows = []
from collections import defaultdict
import calendar


for year in years:
    df = pd.read_csv('../data/partition_predictions/window_topic_prediction_with_short_sentences_merged_54_{}.csv'.format(year))

    programs = ['BBC News at One', 'BBC News at Six', 'BBC News at Ten']

    counts = {month:{day: {program:0 for program in programs} for day in range(1, calendar.monthrange(year, month)[1]+1)} for month in range(1, 13)}
#     counts = defaultdict(dict)
    for program in programs:
        print(program, year)
        df_p = df.loc[df.source == program]
        df_p = df_p.drop(['Unnamed: 0'], axis=1)
        print(program, year)
        print(len(df_p))
        # df.columns = ['partition_id', 'date', 'transcript', 'topic']
        df_p['date'] = pd.to_datetime(df_p['date'])
        # df['topic'] = df['topic'].apply(lambda x: ast.literal_eval(x)[0][0])
        display(df_p.head())

        last_topic = None
        for index, row in df_p.iterrows():
            month = row['date'].month
            day = row['date'].day
            topic = row['topic']
            if topic != last_topic:
                counts[month][day][program] += 1
            last_topic = topic

        for month in range(1, 13):
            for day in range(1, calendar.monthrange(year, month)[1]):
                row = [year, month, day]

                for program in programs:
                    row.append(counts[month][day][program])
                rows.append(row)

columns = ['year', 'month', 'day'] + programs
res_df = pd.DataFrame(rows, columns=columns)
res_df.to_csv('./average_partition_count_day.csv', index=False)
res_df
# Out:
# BBC News at One 2014
# BBC News at One 2014
# 6659
#      partition_id       date           source  \
# 207           445 2014-03-04  BBC News at One
# 745            13 2018-06-08  BBC News at Six
# 746            13 2018-06-08  BBC News at Six
# 747            13 2018-06-08  BBC News at Six
# 748            13 2018-06-08  BBC News at Six
#
#                                             transcript type  \
# 744   The FIFA World Cup, starts Mthjune across the...    p
# 745   The Prime Minister arrives in Canada for talk...    p
# 746   The 90—year—old woman now seriously ill in ho...    p
# 747   And... laughing all the way to the football W...    p
# 748   Later on BBC London: Pay if you pollute — the...    p
#
#                                    topic
# 744  Parliament, government and politics
# 745                       European Union
# 746  Parliament, government and politics
# 747  Parliament, government and politics
# 748                            Transport
# BBC News at Ten 2018
# BBC News at Ten 2018
# 8958
#      partition_id       date           source  \
# 816            15 2018-06-08  BBC News at Ten
# 817            15 2018-06-08  BBC News at Ten
# 818            15 2018-06-08  BBC News at Ten
# 819            15 2018-06-08  BBC News at Ten
# 820            15 2018-06-08  BBC News at Ten
#
#                                             transcript type  \
# 816   Donald Trump catches leaders at the G7 summit...    p
# 817   Meanwhile Theresa May wants to talk trade, bu...    p
# 818   The 90—year—old woman now seriously ill in ho...    p
# 819   Hell hath no fury — Tyson determined to make ...    p
# 820   And laughing all the way to the football Worl...    p
#
#                                    topic
# 816                       European Union
# 817                       European Union
# 818  Parliament, government and politics
# 819  Parliament, government and politics
# 820  Parliament, government and politics
#       year  month  day  BBC News at One  BBC News at Six  BBC News at Ten
# 0     2014      1    1                0                0                0
# 1     2014      1    2                0                0                0
# 2     2014      1    3                0                0                0
# 3     2014      1    4                0                0                0
# 4     2014      1    5                0                0                0
# ...    ...    ...  ...              ...              ...              ...
# 5293  2018     12   26               25                0               24
# 5294  2018     12   27                0                0               12
# 5295  2018     12   28                0                0               24
# 5296  2018     12   29                0                0                0
# 5297  2018     12   30                0                0                0
#
# [5298 rows x 6 columns]

# %%
res_df2 = res_df.drop(['day'], axis=1).groupby(['year', 'month'], as_index=False).mean()
res_df2.to_csv('./average_partition_count_month.csv', index=False)

# %%
years = list(range(2014, 2019))
rows = []

for year in years:
    df = pd.read_csv('../data/partition_predictions/window_topic_prediction_with_short_sentences_merged_54_{}.csv'.format(year))

    programs = ['BBC News at One', 'BBC News at Six', 'BBC News at Ten']
    display(df.head())
    counts = {month:{program:0 for program in programs} for month in range(1, 13)}
    word_counts = {month:{program:0 for program in programs} for month in range(1, 13)}
    
    df = df.loc[df.source.isin(programs)]
    
    df['word_len'] = df['transcript'].apply(lambda x: len(x.split()))
    
    rows.append([year, df['word_len'].mean()])
# Out:
#    Unnamed: 0  partition_id        date            source  \
# 0           0           435  2014-03-01  BBC Weekend News
# 1           1           435  2014-03-01  BBC Weekend News
# 2           2           435  2014-03-01  BBC Weekend News
# 3           3           435  2014-03-01  BBC Weekend News
# 4           4           435  2014-03-01  BBC Weekend News
#
#                                           transcript type  \
# 0   Don’t mind, do you? Shame for both of us to l...    p
# 1   Today I was led to believe that a patient I h...    p
# 2   This is potentially a grave threat to the ter...    p
# 3   Also tonight, Ed Miliband’s plans to reform L...    p
# 4   And Newcastle’s manager, Alan Pardew, is sent...    p
#
#                                           topic
# 0  Agriculture, animals, food and rural affairs
# 1          Crime, civil law, justice and rights
# 2                         International affairs
# 3           Parliament, government and politics
# 4           Parliament, government and politics
#    Unnamed: 0  partition_id        date           source  \
# 0           0            89  2015-04-06  BBC News at One
# 1           1            89  2015-04-06  BBC News at One
# 2           2            89  2015-04-06  BBC News at One
# 3           3            89  2015-04-06  BBC News at One
# 4           4            89  2015-04-06  BBC News at One
#
#                                           transcript type  \
# 0   Tense, or what?  I’m feeling it. # ..I’m read...    p
# 1   You may depend on it for your everyday social...    p
# 2   And cheers for Prince Harry as he arrives in ...    p
# 3   Sweeping changes to pension rules which will ...    p
# 4   The official start of the new tax year has sp...    p
#
#                                  topic
# 0  Parliament, government and politics
# 1  Parliament, government and politics
# 2  Parliament, government and politics
# 3                  Economy and finance
# 4                  Economy and finance
#    Unnamed: 0  partition_id        date          source  \
# 0           0             0  2016-06-04  Joins BBC News
# 1           1             0  2016-06-04  Joins BBC News
# 2           2             0  2016-06-04  Joins BBC News
# 3           3             0  2016-06-04  Joins BBC News
# 4           4             0  2016-06-04  Joins BBC News
#
#                                           transcript type  \
# 0   we would have seen during this weekend and th...    p
# 1   manage that and make sure we stay within the ...    p
# 2   We start at the desk where you have the three...    p
# 3   So far the inexperience is an intriguing mix ...    p
# 4   It will allow, sessions to be moderated in re...    p
#
#                                           topic
# 0                                     Transport
# 1           Parliament, government and politics
# 2  Agriculture, animals, food and rural affairs
# 3           Parliament, government and politics
# 4           Parliament, government and politics
#    Unnamed: 0  partition_id        date    source  \
# 0           0           197  2017-05-01  BBC News
# 1           1           197  2017-05-01  BBC News
# 2           2           197  2017-05-01  BBC News
# 3           3           197  2017-05-01  BBC News
# 4           4           197  2017-05-01  BBC News
#
#                                           transcript type  \
# 0   MasterChef Semifinals... MasterChef Ser galle...    p
# 1   A chance discovery by a pre-school child has ...    p
# 2   As Australia tightens up its visa rules for s...    p
# 3   And before we go, let’s take you to Chengdu C...    p
# 4   We saw some big contrasts across the UK on Su...    p
#
#                                           topic
# 0                      Culture, media and sport
# 1  Agriculture, animals, food and rural affairs
# 2           Parliament, government and politics
# 3                        Energy and environment
# 4                      Culture, media and sport
#    Unnamed: 0  partition_id        date    source  \
# 0           0             0  2018-06-02  BBC News
# 1           1             0  2018-06-02  BBC News
# 2           2             0  2018-06-02  BBC News
# 3           3             0  2018-06-02  BBC News
# 4           4             0  2018-06-02  BBC News
#
#                                           transcript type  \
# 0   but also gathering storm clouds, some further...    p
# 1   Jotheremy Thorpe, I’m arresting you for consp...    p
# 2   Canada hasjoined the European Union in filing...    p
# 3   After the closure of its main steel plant 20 ...    p
# 4   This is further weakening the transatlantic r...    p
#
#                                  topic
# 0               Energy and environment
# 1  Parliament, government and politics
# 2                       European Union
# 3     Business, industry and consumers
# 4                            Transport

# %%
rows
# Out:
# [[2014, 131.00944881889762],
#  [2015, 127.72282051282052],
#  [2016, 190.20642921679584],
#  [2017, 233.0420473132006],
#  [2018, 220.57442748091603]]
