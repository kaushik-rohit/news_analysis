# %%
import pandas as pd
from gensim import models, corpora
from gensim.parsing.preprocessing import preprocess_string, strip_tags, strip_punctuation
from gensim.parsing.preprocessing import remove_stopwords, stem_text, strip_non_alphanum, strip_multiple_whitespaces
from gensim.parsing.preprocessing import strip_short, strip_numeric
from gensim.parsing.preprocessing import STOPWORDS
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from sklearn.utils import class_weight
import multiprocessing as mp
import nltk
import pandas as pd
import numpy as np
import tensorflow as tf
import parmap

# %%
topics_index_to_name_map = {
    0: 'Agriculture, animals, food and rural affairs',
    1: 'Asylum, immigration and nationality',
    2: 'Business, industry and consumers',
    3: 'Communities and families',
    4: 'Crime, civil law, justice and rights',
    5: 'Culture, media and sport',
    6: 'Defence',
    7: 'Economy and finance',
    8: 'Education',
    9: 'Employment and training',
    10: 'Energy and environment',
    11: 'European Union',
    12: 'Health services and medicine',
    13: 'Housing and planning',
    14: 'International affairs',
    15: 'Parliament, government and politics',
    16: 'Science and technology',
    17: 'Social security and pensions',
    18: 'Social services',
    19: 'Transport',
    20: 'Others'
}
topics_name_to_index_map = {y:x for x,y in topics_index_to_name_map.items()}

def strip_short2(text):
    return strip_short(text, minsize=4)


def preprocess_text(text):
    FILTERS = [lambda x: x.lower(), strip_multiple_whitespaces, strip_tags, strip_punctuation,
                   strip_non_alphanum, strip_numeric, strip_short2]
    return preprocess_string(text, FILTERS)

def preprocess(topic):
    ret = []
    topic = topic.strip()
    
    if '|' in topic:
        topics = topic.split('|')
        t = topics[0]
        t = t.strip()
        return topics_name_to_index_map[t]
        
    return topics_name_to_index_map[topic]

# %%
years = range(2010, 2016)
session_start_dt = '2010-5-1'
session_end_dt = '2015-5-31'
start_str = 'May-2010'
end_str = 'May-2015'

# %%
df_list = []
for year in years:
    print(year)
    df_list.append(pd.read_csv('../data/{}_debate.csv'.format(year)))
# Out:
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015

# %%
df = pd.concat(df_list)

# %%
df['date'] = pd.to_datetime(df['date'])
mask = (df['date'] >= session_start_dt) & (df['date'] <= session_end_dt)
df = df[mask]
df = df.reset_index(drop=True)

# %%
# df = df.drop(df[df.topic == 'admin'].index)
df = df.loc[df.topic != 'admin']
# df = df.drop(df[df.transcript.str.split().map(len) < 10].index)
df['topic'] = df.apply(lambda row: preprocess(row['topic']), axis=1)
# df = df.drop(df[df.topic == 20].index)
df['word_count'] = df['transcript'].apply(lambda x: len(x.split()))

# %%
df
# Out:
#             date  topic                                         transcript  \
# 0     2010-05-18     15  Under the terms of Standing Order No. 1A, I am...
# 5     2010-05-25     15  May I begin by saying how grateful I am to you...
# 7     2010-05-26     20  I am grateful, Mr Deputy Speaker, to be able t...
# 8     2010-05-26     14  It is a privilege to open this year’s foreign ...
# 9     2010-05-26     15  (Urgent Question): To ask the Chancellor of th...
# ...          ...    ...                                                ...
# 12522 2015-05-27      9  I am pleased to have the opportunity to introd...
# 12524 2015-05-28      6  I should first thank the Justice Secretary. In...
# 12525 2015-05-28      4  The Gracious Speech we heard yesterday set out...
# 12526 2015-05-28     20  (Urgent Question): To ask the Secretary of Sta...
# 12527 2015-05-28     15  Yesterday you kindly addressed the House befor...
#
#        labour  conservative  others  word_count
# 0         845          1667     462        2974
# 5        1205          6180    3675       11060
# 7        1434          1013       0        2447
# 8       25595         23872    8824       58291
# 9        1602           877    4829        7308
# ...       ...           ...     ...         ...
# 12522       0          4386     220        4606
# 12524     139          2056    3183        5378
# 12525   18454         28301    5816       52571
# 12526     774          4477       0        5251
# 12527       0           130      94         224
#
# [11676 rows x 7 columns]

# %%
word_counts_df = df[['topic', 'word_count', 'labour', 'conservative', 'others']].groupby(['topic']).sum()
word_counts_df['topic'] = word_counts_df.index
word_counts = {}
word_counts_df
# Out:
#        word_count   labour  conservative   others  topic
# topic
# 0          961742   293561        502443   165738      0
# 1          866390   308003        452039   106348      1
# 2         1854418   712691        680584   461143      2
# 3         1956163   707533        933222   315408      3
# 4         4278057  1446524       2264766   566767      4
# 5         1041267   302520        643255    95492      5
# 6         1967133   591011       1125656   250466      6
# 7         5614979  2378935       2470329   765715      7
# 8         1599154   544839        847034   207281      8
# 9         2067952   888209        874132   305611      9
# 10        1758166   598109        725280   434777     10
# 11        1171315   383933        682443   104939     11
# 12        2658580   912577       1383007   362996     12
# 13         806497   352492        317773   136232     13
# 14        3153998   914524       1951594   287880     14
# 15        5087676  1759350       2300689  1027637     15
# 16         338825   122368        155750    60707     16
# 17         439827   197882        126939   115006     17
# 18         238618    81331         94526    62761     18
# 19        1525279   518431        822573   184275     19
# 20        4269369  1436444       2188010   644915     20

# %%
for index, row in word_counts_df.iterrows():
    word_counts[topics_index_to_name_map[row['topic']]] = {
        'word_count': row['word_count'],
        'labour': row['labour'],
        'conservative': row['conservative'],
        'others': row['others']
    }
    
word_counts
# Out:
# {'Agriculture, animals, food and rural affairs': {'word_count': 961742,
#   'labour': 293561,
#   'conservative': 502443,
#   'others': 165738},
#  'Asylum, immigration and nationality': {'word_count': 866390,
#   'labour': 308003,
#   'conservative': 452039,
#   'others': 106348},
#  'Business, industry and consumers': {'word_count': 1854418,
#   'labour': 712691,
#   'conservative': 680584,
#   'others': 461143},
#  'Communities and families': {'word_count': 1956163,
#   'labour': 707533,
#   'conservative': 933222,
#   'others': 315408},
#  'Crime, civil law, justice and rights': {'word_count': 4278057,
#   'labour': 1446524,
#   'conservative': 2264766,
#   'others': 566767},
#  'Culture, media and sport': {'word_count': 1041267,
#   'labour': 302520,
#   'conservative': 643255,
#   'others': 95492},
#  'Defence': {'word_count': 1967133,
#   'labour': 591011,
#   'conservative': 1125656,
#   'others': 250466},
#  'Economy and finance': {'word_count': 5614979,
#   'labour': 2378935,
#   'conservative': 2470329,
#   'others': 765715},
#  'Education': {'word_count': 1599154,
#   'labour': 544839,
#   'conservative': 847034,
#   'others': 207281},
#  'Employment and training': {'word_count': 2067952,
#   'labour': 888209,
#   'conservative': 874132,
#   'others': 305611},
#  'Energy and environment': {'word_count': 1758166,
#   'labour': 598109,
#   'conservative': 725280,
#   'others': 434777},
#  'European Union': {'word_count': 1171315,
#   'labour': 383933,
#   'conservative': 682443,
#   'others': 104939},
#  'Health services and medicine': {'word_count': 2658580,
#   'labour': 912577,
#   'conservative': 1383007,
#   'others': 362996},
#  'Housing and planning': {'word_count': 806497,
#   'labour': 352492,
#   'conservative': 317773,
#   'others': 136232},
#  'International affairs': {'word_count': 3153998,
#   'labour': 914524,
#   'conservative': 1951594,
#   'others': 287880},
#  'Parliament, government and politics': {'word_count': 5087676,
#   'labour': 1759350,
#   'conservative': 2300689,
#   'others': 1027637},
#  'Science and technology': {'word_count': 338825,
#   'labour': 122368,
#   'conservative': 155750,
#   'others': 60707},
#  'Social security and pensions': {'word_count': 439827,
#   'labour': 197882,
#   'conservative': 126939,
#   'others': 115006},
#  'Social services': {'word_count': 238618,
#   'labour': 81331,
#   'conservative': 94526,
#   'others': 62761},
#  'Transport': {'word_count': 1525279,
#   'labour': 518431,
#   'conservative': 822573,
#   'others': 184275},
#  'Others': {'word_count': 4269369,
#   'labour': 1436444,
#   'conservative': 2188010,
#   'others': 644915}}

# %%
counts = df['topic'].value_counts()
topic_counts = {topics_index_to_name_map[key]: counts[key] for key in counts.keys()}
counts_df = pd.DataFrame.from_dict(topic_counts, orient='index', columns=['count'])
total = counts_df['count'].sum()
counts_df['fraction'] = counts_df.apply(lambda x: round(x['count']/total*100, 2), axis=1)

# %%
row = {'word_count': [], 'labour': [], 'conservative': [], 'others': []}
ind = counts_df.index

for i in ind:
    row['word_count'].append(word_counts[i]['word_count'])
    row['conservative'].append(word_counts[i]['conservative'])
    row['labour'].append(word_counts[i]['labour'])
    row['others'].append(word_counts[i]['others'])
counts_df['word_count'] = row['word_count']
counts_df['conservative'] = row['conservative']
counts_df['labour'] = row['labour']
counts_df['others'] = row['others']
total_word_count = counts_df['word_count'].sum()
counts_df['word fraction'] = counts_df.apply(lambda x: round(x['word_count']/total_word_count*100, 2), axis=1)
total_word_count = counts_df['conservative'].sum()
counts_df['conservative fraction'] = counts_df.apply(lambda x: round(x['conservative']/total_word_count*100, 2), axis=1)
total_word_count = counts_df['labour'].sum()
counts_df['labour fraction'] = counts_df.apply(lambda x: round(x['labour']/total_word_count*100, 2), axis=1)
total_word_count = counts_df['others'].sum()
counts_df['others fraction'] = counts_df.apply(lambda x: round(x['others']/total_word_count*100, 2), axis=1)
counts_df
# Out:
#                                               count  fraction  word_count  \
# Parliament, government and politics            1794     15.36     5087676
# Crime, civil law, justice and rights           1388     11.89     4278057
# International affairs                           886      7.59     3153998
# Economy and finance                             759      6.50     5614979
# Health services and medicine                    758      6.49     2658580
# Others                                          726      6.22     4269369
# Communities and families                        639      5.47     1956163
# Energy and environment                          635      5.44     1758166
# Education                                       627      5.37     1599154
# Business, industry and consumers                616      5.28     1854418
# Employment and training                         578      4.95     2067952
# Defence                                         574      4.92     1967133
# Transport                                       497      4.26     1525279
# Culture, media and sport                        470      4.03     1041267
# Agriculture, animals, food and rural affairs    267      2.29      961742
# Asylum, immigration and nationality             146      1.25      866390
# European Union                                  115      0.98     1171315
# Housing and planning                             89      0.76      806497
# Science and technology                           51      0.44      338825
# Social security and pensions                     31      0.27      439827
# Social services                                  30      0.26      238618
#
#                                               conservative   labour   others  \
# Parliament, government and politics                2300689  1759350  1027637
# Crime, civil law, justice and rights               2264766  1446524   566767
# International affairs                              1951594   914524   287880
# Economy and finance                                2470329  2378935   765715
# Health services and medicine                       1383007   912577   362996
# Others                                             2188010  1436444   644915
# Communities and families                            933222   707533   315408
# Energy and environment                              725280   598109   434777
# Education                                           847034   544839   207281
# Business, industry and consumers                    680584   712691   461143
# Employment and training                             874132   888209   305611
# Defence                                            1125656   591011   250466
# Transport                                           822573   518431   184275
# Culture, media and sport                            643255   302520    95492
# Agriculture, animals, food and rural affairs        502443   293561   165738
# Asylum, immigration and nationality                 452039   308003   106348
# European Union                                      682443   383933   104939
# Housing and planning                                317773   352492   136232
# Science and technology                              155750   122368    60707
# Social security and pensions                        126939   197882   115006
# Social services                                      94526    81331    62761
#
#                                               word fraction  \
# Parliament, government and politics                   11.65
# Crime, civil law, justice and rights                   9.80
# International affairs                                  7.22
# Economy and finance                                   12.86
# Health services and medicine                           6.09
# Others                                                 9.78
# Communities and families                               4.48
# Energy and environment                                 4.03
# Education                                              3.66
# Business, industry and consumers                       4.25
# Employment and training                                4.74
# Defence                                                4.51
# Transport                                              3.49
# Culture, media and sport                               2.39
# Agriculture, animals, food and rural affairs           2.20
# Asylum, immigration and nationality                    1.98
# European Union                                         2.68
# Housing and planning                                   1.85
# Science and technology                                 0.78
# Social security and pensions                           1.01
# Social services                                        0.55
#
#                                               conservative fraction  \
# Parliament, government and politics                           10.68
# Crime, civil law, justice and rights                          10.51
# International affairs                                          9.06
# Economy and finance                                           11.47
# Health services and medicine                                   6.42
# Others                                                        10.16
# Communities and families                                       4.33
# Energy and environment                                         3.37
# Education                                                      3.93
# Business, industry and consumers                               3.16
# Employment and training                                        4.06
# Defence                                                        5.23
# Transport                                                      3.82
# Culture, media and sport                                       2.99
# Agriculture, animals, food and rural affairs                   2.33
# Asylum, immigration and nationality                            2.10
# European Union                                                 3.17
# Housing and planning                                           1.48
# Science and technology                                         0.72
# Social security and pensions                                   0.59
# Social services                                                0.44
#
#                                               labour fraction  others fraction
# Parliament, government and politics                     11.39            15.43
# Crime, civil law, justice and rights                     9.36             8.51
# International affairs                                    5.92             4.32
# Economy and finance                                     15.40            11.49
# Health services and medicine                             5.91             5.45
# Others                                                   9.30             9.68
# Communities and families                                 4.58             4.73
# Energy and environment                                   3.87             6.53
# Education                                                3.53             3.11
# Business, industry and consumers                         4.61             6.92
# Employment and training                                  5.75             4.59
# Defence                                                  3.83             3.76
# Transport                                                3.36             2.77
# Culture, media and sport                                 1.96             1.43
# Agriculture, animals, food and rural affairs             1.90             2.49
# Asylum, immigration and nationality                      1.99             1.60
# European Union                                           2.48             1.58
# Housing and planning                                     2.28             2.04
# Science and technology                                   0.79             0.91
# Social security and pensions                             1.28             1.73
# Social services                                          0.53             0.94

# %%
# counts_df.sort_values(by=[''])

# %%
counts_df.to_csv('./topic_counts_debate_{}-{}.csv'.format(start_str, end_str))

# %% [markdown]
# # AGG COUNTS

# %%
years = range(2006, 2020)

# %%
rows = []
for year in years:
    print(year)
    df = pd.read_csv('../data/{}_debate.csv'.format(year))
#     df = df.drop(df[df.topic == 'admin'].index)
    df = df.loc[df.topic != 'admin']
#     df = df.drop(df[df.transcript.str.split().map(len) < 10].index)
    df['topic'] = df.apply(lambda row: preprocess(row['topic']), axis=1)
    df['word_count'] = df['transcript'].apply(lambda x: len(x.split()))
    df['month'] = df['date'].apply(lambda x: pd.to_datetime(x).month)
    df['date'] = pd.to_datetime(df['date'])
    df_month_count = df[['month', 'word_count', 'labour', 'conservative', 'others']].groupby(['month'], as_index=False).sum()
    for index, row in df_month_count.iterrows():
        debate_count = len(df.loc[df.month == row['month']])
        rows.append([year, row['month'], debate_count, row['word_count'], row['labour'], row['conservative'], row['others']])
# Out:
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019

# %%
res_df = pd.DataFrame(rows, columns=['year', 'month', 'debate_count', 'word_count', 'labour', 'conservative', 'others'])

# %%
res_df
# Out:
#      year  month  debate_count  word_count  labour  conservative  others
# 0    2006      6           255      956086  484028        324523  147535
# 1    2006      7           242      859735  471218        268191  120326
# 2    2006     10           219      901992  476665        256846  168481
# 3    2006     11           180      726120  342481        244985  138654
# 4    2006     12           146      614281  346587        162300  105394
# ..    ...    ...           ...         ...     ...           ...     ...
# 133  2018     12           199      831422  251211        414788  165423
# 134  2019      1           278     1117126  357309        578515  181302
# 135  2019      2           309     1075456  328261        580131  167064
# 136  2019      3           317     1213871  333605        643734  236532
# 137  2019      4            64      177979   43930         97948   36101
#
# [138 rows x 7 columns]

# %%
res_df.to_csv('debates_counts_agg.csv')
