# %%
import pandas as pd
from gensim import models, corpora
from gensim.parsing.preprocessing import preprocess_string, strip_tags, strip_punctuation
from gensim.parsing.preprocessing import remove_stopwords, stem_text, strip_non_alphanum, strip_multiple_whitespaces
from gensim.parsing.preprocessing import strip_short, strip_numeric
from gensim.parsing.preprocessing import STOPWORDS
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from semantic_text_similarity.models import WebBertSimilarity
import multiprocessing as mp
import nltk
import pandas as pd
import numpy as np
import tensorflow as tf
from scipy import spatial
import parmap
import os
import swifter
from tqdm import tqdm

# %%
topics_index_to_name_map = {
    0: 'Agriculture, animals, food and rural affairs',
    1: 'Asylum, immigration and nationality',
    2: 'Business, industry and consumers',
    3: 'Communities and families',
    4: 'Crime, civil law, justice and rights',
    5: 'Culture, media and sport',
    6: 'Defence',
    7: 'Economy and finance',
    8: 'Education',
    9: 'Employment and training',
    10: 'Energy and environment',
    11: 'European Union',
    12: 'Health services and medicine',
    13: 'Housing and planning',
    14: 'International affairs',
    15: 'Parliament, government and politics',
    16: 'Science and technology',
    17: 'Social security and pensions',
    18: 'Social services',
    19: 'Transport',
    20: 'Others'
}
topics_name_to_index_map = {y:x for x,y in topics_index_to_name_map.items()}

def strip_short2(text):
    return strip_short(text, minsize=4)


def preprocess_text(text):
    FILTERS = [lambda x: x.lower(), strip_multiple_whitespaces, strip_tags, strip_punctuation,
                   strip_non_alphanum, strip_numeric, strip_short2]
    return preprocess_string(text, FILTERS)

def preprocess(topic):
    ret = []
    topic = topic.strip()
    
    if '|' in topic:
        topics = topic.split('|')
        t = topics[0]
        t = t.strip()
        return topics_name_to_index_map[t]
        
    return topics_name_to_index_map[topic]

# %%
path = './data/bbc/2016/transcripts'
files = os.listdir(path)

data = []
for source in files:
    data.append(pd.read_csv(os.path.join(path, source)))
df = pd.concat(data)
df = df.drop(['Unnamed: 0', 'Has Transcript', 'Unavailable link', 'Unavailable reason'], axis=1)
df = df.reset_index(drop=True)
df
# Out:
#            Source         Date      Program Name   Time  Duration  \
# 0     BBC1 London   4-jun-2016    Joins BBC News  01:40  260 mins
# 1     BBC1 London   4-jun-2016  BBC Weekend News  12:00   15 mins
# 2     BBC1 London   4-jun-2016  BBC Weekend News  18:30   10 mins
# 3     BBC1 London   4-jun-2016  BBC Weekend News  22:50   20 mins
# 4     BBC1 London   2-jun-2016    Joins BBC News  00:20  340 mins
# ...           ...          ...               ...    ...       ...
# 1502  BBC1 London   4-dec-2016  BBC Weekend News  22:00   20 mins
# 1503  BBC1 London  30-dec-2016    Joins BBC News  01:20  280 mins
# 1504  BBC1 London  30-dec-2016          BBC News  13:10   15 mins
# 1505  BBC1 London  30-dec-2016          BBC News  18:30   15 mins
# 1506  BBC1 London  30-dec-2016          BBC News  22:40   10 mins
#
#                                              Transcript
# 0     we would have seen during this weekend and the...
# 1     Muhammad Ali, the boxing legend and giant of 2...
# 2     # just gimme the love just gimme the love... #...
# 3     But BUT This BMT This mas his BUT This was his...
# 4     It looks as though the northwest seeing the be...
# ...                                                 ...
# 1502  when Mark Duggan arrived at the scene at Ferry...
# 1503  By midnight, it’s probably across northern Eng...
# 1504  Will it be happily ever after for the Mitchell...
# 1505  Whoop-whoop-whoop. Whoop-whoop-whoop! Do you t...
# 1506  Unbelievable. ..with BBC Three on BBC iPlayer....
#
# [1507 rows x 6 columns]

# %%
def filter_short_sentence(sentences):
    n_sent = len(sentences)
    filtered_sentences = []
    for i in range(n_sent):
        if len(sentences[i].split()) >= 10:
            filtered_sentences.append(sentences[i])
    return filtered_sentences

def partition_transcript_into_topics(transcript):
    cluster = []
    sentences = nltk.sent_tokenize(transcript)
    sentences = filter_short_sentence(sentences)
    n_sent = len(sentences)
    current_cluster = [sentences[0]]
    n_cluster = 1
    for i in range(1, n_sent):
        sim = web_model.predict([(sentences[i], sentences[i-1])])[0]/5
        
#         for sent in current_cluster:
#             sim+= web_model.predict([(sent, sentences[i])])[0]/5
            
#         avg_sim = sim/len(current_cluster)
        
        if sim >= 0.1:
            current_cluster.append(sentences[i])
            if i == n_sent - 1:
                cluster.append(' '.join(current_cluster))
        else:
            n_cluster += 1
            cluster.append(' '.join(current_cluster))
            current_cluster = [sentences[i]]
    return '\n---------------------\n'.join(cluster)

# %%
web_model = WebBertSimilarity(device='cpu', batch_size=10) #defaults to GPU prediction

# %%
transcripts = df['Transcript'].values

# %%
print(partition_transcript_into_topics(transcripts[3]))
# Out:
# But BUT This BMT This mas his BUT This was his sTuge, stage. But this was his stage, where the one and only Muhammad Ali reigns supreme. I’m of a real champion of the world, do you hear me? This man is a megastar, add some more mega Toure onto that. My only fault is that I don’t realise how great I really am. You don’t like me because my big mouth, that was only publicity. Time flies when you are in good company, don’t it? I think it was the greatest betrayal in Swedish history. Wallander concludes... Tributes are paid around the world to Muhammad Ali, who’s died at the age of 74. I’ll whip any man in the world and I want everybody out there on TV to know it.
# ---------------------
# The way he moved - the speed, the grace, the power- I knew it was something magical. The Kentucky boy rose from humble beginnings to become three-time World Heavyweight Champion.
# ---------------------
# Politically, he was controversial because of his conversion to Islam, his stand on civil rights and his refusal to fight in the Vietnam War. Later, he won global respect for his humanitarian work, but was increasingly frail after a long battle with Parkinson’s disease. Tributes have been paid around the world to Muhammad Ali, who has died at the age of 74. Outspoken, but rarely outfought, Ali transcended the sport of boxing, of which he was three times World Champion. He was politically controversial, dividing opinion after converting to Islam and refusing to fight in Vietnam. President Obama paid tribute saying - "he shook up the world, and the world is better for it." Our North America editor, jon Sopel, is live from his birthplace in Kentucky. Yes, here in Louisville thereby has been a steady procession of people coming to pay their respects. On Wednesday the city will play host to a funeral in which people are expected to fly in from across the country and around the world. In the last couple of hours, Barack Obama has spoken to Muhammad Ali’s widow to express his and the nations donds. If you could bring ballet to boxing, beauty to brawn, Muhammad Ali did it.
# ---------------------
# ---------------------
# Now to some of the rest of the day’s news. Lord Kinnock said today that the Leave campaign could win the European Union referendum "by default" if turnout was low. Along with five other former Labour leaders, he warned a Brexit will happen if Labour voters stayed at home. Elsewhere, Leave campaigners promised more money for public services and control over immigration outside the EU. Well, last time I was campaigning with you I was about that big, 1987 election. A better result would be a win and that’s what the Remain campaign wants, but to do that they must get Labour voters on board, so they’re rolling out the big beasts to win them over. I hope people use their vote to avoid the risk of losing jobs, losing investment. Neil Kinnock may not have won an election, but it’s hoped he’ll appeal to Labour’s core. He attacked Tories in the Leave campaign, saying they’d made false promises about spending EU money. And, on immigration, he had this warning for the Brexit camp. Trying to persuade the British people to sacrifice the great opportunity and the security, economic and otherwise, of being in the European Union, by trying to nourish prejudice, that really is beneath them. Remain campaigners know the Labour vote is crucial to them because many Tories will back Brexit, but Leave campaigners are targeting traditional Labour supporters too by trying to tap into their concerns over immigration. At a rally tonight, they challenged their rivals on the issue. What is your vision for this country if that rate of immigration continues because you have absolutely no way of stopping it. The Leave campaign denied they were making impossible promises about life after Brexit. They unveiled five pledges, again saying EU money could be spent on the NHS and claiming leaving could create 300,000 from new trade deals, but the likelihood of negotiating such deals is disputed. Well, these are what we think we could do if you are able, finally, to do the sorts of free trade deals that are currently prohibited under the EU rules. We haven’t been able to do free trade deals either with India, with China or even with America, one of our biggest trading partners. The challenge for both sides is convincing people their vision of life inside or outside the EU is credible.
# ---------------------
# In sport, Northern Ireland had a goalless draw in their final warm-up match for the European Championships against Slovakia. Meanwhile, tournament hosts, France, had a convincing 3-0 win over Scotland.
# ---------------------
# Spain’s Garbine Muguruza has won the Ladies Singles at the French Open in Paris. She beat the Number One seed, Serena Williams, in straight sets to pick up her first Grand Slam title.
# ---------------------
# Harzand held off the challenge of favourite US Army Ranger and Idaho to win the Derby at Epsom. It was a first win in the race for trainer Dermot Weld and, for the first time, Her Majesty the Queen presented the trophy.
# ---------------------
# Before we go, we’ll leave you with the thoughts - and the fights of Muhammad Ali. # Calling all the people here to see the show #.
# ---------------------
# REPORTER: Why do you insist on being called Muhammad Ali now? Cassius Clay was my slave name, I’m no longer a slave. And, if I threaten you, I’m going to blackmail you. I said, "Mama, why don’t they call it whitemail, they lie too?"
# ---------------------
# Oh, my God he’s won the title back at 32!
# ---------------------
# Hello, there the sunshine wasn’t spread far and wide today. In Cheshire they had the highest temperatures, but there were thunderstorms. Less cloud through the night, retreating to the south-west and Northern Ireland, low cloud to eastern Scotland and north-east England. Partly because there won’t be as much cloud around by tomorrow morning. Any cloud inest earn Scotland and England retreating back to the coast. The cloud will break up in Wales, the south-west and Northern Ireland.

# %%
df['partitioned_transcript'] = df.swifter.apply(partition_transcript_into_topics)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Pandas Apply', max=1507.0, style=ProgressStyle(descriptio…

# %%
df

# %%
df.to_csv('./bert_partitions_2016.csv')
