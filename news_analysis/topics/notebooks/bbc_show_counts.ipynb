# %%
import os
import pandas as pd

# %%
bbc_ids = [54, 106, 107, 175, 279]
years = range(2015, 2018)

prefix = {
    54: 'BBC+News',
    106: 'News',
    107: 'News',
    175: 'News',
    279: ''
}

# %%
months = ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec']

# %%
for bbc_id in bbc_ids:
    rows = []
    for year in years:
        data_path = '../data/bbc/{}/{}/transcripts'.format(bbc_id, year)
        for month in months:
            csv_file = os.path.join(data_path, '{} {}-{} {}.csv'.format(prefix[bbc_id], month, year, bbc_id))
            
            if not os.path.exists(csv_file):
                continue
            df = pd.read_csv(csv_file)
            df = df.drop(['Unnamed: 0', 'Has Transcript', 'Unavailable link', 'Unavailable reason'], axis=1)
            df['word_count'] = df['Transcript'].apply(lambda x: len(x.split()))
            shows = df['Program Name'].unique()

            for show in shows:
                df_show = df.loc[df['Program Name'] == show]
                total_show_length = df_show['word_count'].sum()
                rows.append([year, month, show, total_show_length])

    res_df = pd.DataFrame(rows, columns=['year', 'month', 'show title', 'word count in show'])
    display(res_df)
    res_df.to_csv('bbc_{}_show_word_counts.csv'.format(bbc_id))
# Out:
#      year month        show title  word count in show
# 0    2015   jan  BBC Weekend News               50960
# 1    2015   jan   BBC London News               74521
# 2    2015   jan   BBC News at One              101231
# 3    2015   jan   BBC News at Six               90586
# 4    2015   jan   BBC News at Ten               92269
# ..    ...   ...               ...                 ...
# 208  2017   dec          BBC News             1684856
# 209  2017   dec   BBC London News              315045
# 210  2017   dec   BBC News at One              137517
# 211  2017   dec   BBC News at Six              128431
# 212  2017   dec   BBC News at Ten               99649
#
# [213 rows x 4 columns]
#     year month              show title  word count in show
# 0   2015   jan          Channel 4 News              213321
# 1   2015   jan  Channel 4 News Summary                1028
# 2   2015   jan     The Simpsons (2004)                3385
# 3   2015   feb          Channel 4 News              189590
# 4   2015   feb  Channel 4 News Summary                 473
# ..   ...   ...                     ...                 ...
# 68  2017   oct  Channel 4 News Summary               27801
# 69  2017   nov          Channel 4 News              410285
# 70  2017   nov  Channel 4 News Summary               26473
# 71  2017   dec          Channel 4 News              334525
# 72  2017   dec  Channel 4 News Summary               24111
#
# [73 rows x 4 columns]
#      year month        show title  word count in show
# 0    2015   jan            5 News                 602
# 1    2015   jan       5 News at 5               63397
# 2    2015   jan    5 News Tonight               78829
# 3    2015   jan    5 News Weekend                3346
# 4    2015   feb    5 News Weekend                4908
# ..    ...   ...               ...                 ...
# 176  2017   dec            5 News               13585
# 177  2017   dec    5 News Weekend               11194
# 178  2017   dec  5 News Lunchtime               14433
# 179  2017   dec       5 News at 5               81180
# 180  2017   dec    5 News Tonight               86501
#
# [181 rows x 4 columns]
#      year month                 show title  word count in show
# 0    2015   jan  ITV News at Ten & Weather              143047
# 1    2015   jan         ITV News & Weather              194809
# 2    2015   jan            ITV News London               92595
# 3    2015   jan                   ITV News                3248
# 4    2015   feb         ITV News & Weather              203499
# ..    ...   ...                        ...                 ...
# 195  2017   dec            ITV News London              288801
# 196  2017   dec         ITV Lunchtime News              121907
# 197  2017   dec           ITV Evening News              124548
# 198  2017   dec            ITV News at Ten               97823
# 199  2017   dec  Regional News and Weather                6380
#
# [200 rows x 4 columns]
#      year month                                         show title  \
# 0    2015   may  Sky News Tonight with Adam Boulton and Anna Jones
# 1    2015   may                                    Sky News at Ten
# 2    2015   may                 Sky News at Seven with Steve Dixon
# 3    2015   may                                   Sky News at Nine
# 4    2015   may                  Sky News at 11 with Lorna Dunkley
# ..    ...   ...                                                ...
# 549  2017   dec                                   Sky News Tonight
# 550  2017   dec       Sky News with Colin Brazier and Jayne Secker
# 551  2017   dec                               Sky News on the Hour
# 552  2017   dec                                      Press Preview
# 553  2017   dec                   Uncovered: Body Language Secrets
#
#      word count in show
# 0                 32336
# 1                114789
# 2                  3984
# 3                  2818
# 4                  6637
# ..                  ...
# 549               41863
# 550               45562
# 551               16409
# 552               40947
# 553                  46
#
# [554 rows x 4 columns]

# %%
rows = []
for year in years:
    for bbc_id in bbc_ids:
        data_path = '../data/bbc/{}/{}/transcripts'.format(bbc_id, year)
        
        if not os.path.exists(data_path):
            continue
        
        for month in months:
            print(year, bbc_id, month)
            csv_file = os.path.join(data_path, '{}{}-{} {}.csv'.format(prefix[bbc_id], month, year, bbc_id))
            if not os.path.exists(csv_file):
                rows.append([bbc_id, year, month, 0, 0])
                continue
            df = pd.read_csv(csv_file)
            df = df.drop(['Unnamed: 0', 'Has Transcript', 'Unavailable link', 'Unavailable reason'], axis=1)
            df['word_count'] = df['Transcript'].apply(lambda x: len(x.split()))
            n_shows = len(df['Program Name'])
            word_count = df['word_count'].sum()
            rows.append([bbc_id, year, month, word_count, n_shows])
            
            
res_df = pd.DataFrame(rows, columns=['bbc_id', 'year', 'month', 'word_count', 'show_count'])
# Out:
# 2007 54 jan
# 2007 54 feb
# 2007 54 mar
# 2007 54 apr
# 2007 54 may
# 2007 54 jun
# 2007 54 jul
# 2007 54 aug
# 2007 54 sep
# 2007 54 oct
# 2007 54 nov
# 2007 54 dec
# 2008 54 jan
# 2008 54 feb
# 2008 54 mar
# 2008 54 apr
# 2008 54 may
# 2008 54 jun
# 2008 54 jul
# 2008 54 aug
# 2008 54 sep
# 2008 54 oct
# 2008 54 nov
# 2008 54 dec
# 2009 54 jan
# 2009 54 feb
# 2009 54 mar
# 2009 54 apr
# 2009 54 may
# 2009 54 jun
# 2009 54 jul
# 2009 54 aug
# 2009 54 sep
# 2009 54 oct
# 2009 54 nov
# 2009 54 dec
# 2009 106 jan
# 2009 106 feb
# 2009 106 mar
# 2009 106 apr
# 2009 106 may
# 2009 106 jun
# 2009 106 jul
# 2009 106 aug
# 2009 106 sep
# 2009 106 oct
# 2009 106 nov
# 2009 106 dec
# 2009 175 jan
# 2009 175 feb
# 2009 175 mar
# 2009 175 apr
# 2009 175 may
# 2009 175 jun
# 2009 175 jul
# 2009 175 aug
# 2009 175 sep
# 2009 175 oct
# 2009 175 nov
# 2009 175 dec
# 2009 279 jan
# 2009 279 feb
# 2009 279 mar
# 2009 279 apr
# 2009 279 may
# 2009 279 jun
# 2009 279 jul
# 2009 279 aug
# 2009 279 sep
# 2009 279 oct
# 2009 279 nov
# 2009 279 dec
# 2010 54 jan
# 2010 54 feb
# 2010 54 mar
# 2010 54 apr
# 2010 54 may
# 2010 54 jun
# 2010 54 jul
# 2010 54 aug
# 2010 54 sep
# 2010 54 oct
# 2010 54 nov
# 2010 54 dec
# 2010 106 jan
# 2010 106 feb
# 2010 106 mar
# 2010 106 apr
# 2010 106 may
# 2010 106 jun
# 2010 106 jul
# 2010 106 aug
# 2010 106 sep
# 2010 106 oct
# 2010 106 nov
# 2010 106 dec
# 2010 107 jan
# 2010 107 feb
# 2010 107 mar
# 2010 107 apr
# 2010 107 may
# 2010 107 jun
# 2010 107 jul
# 2010 107 aug
# 2010 107 sep
# 2010 107 oct
# 2010 107 nov
# 2010 107 dec
# 2010 175 jan
# 2010 175 feb
# 2010 175 mar
# 2010 175 apr
# 2010 175 may
# 2010 175 jun
# 2010 175 jul
# 2010 175 aug
# 2010 175 sep
# 2010 175 oct
# 2010 175 nov
# 2010 175 dec
# 2010 279 jan
# 2010 279 feb
# 2010 279 mar
# 2010 279 apr
# 2010 279 may
# 2010 279 jun
# 2010 279 jul
# 2010 279 aug
# 2010 279 sep
# 2010 279 oct
# 2010 279 nov
# 2010 279 dec
# 2011 54 jan
# 2011 54 feb
# 2011 54 mar
# 2011 54 apr
# 2011 54 may
# 2011 54 jun
# 2011 54 jul
# 2011 54 aug
# 2011 54 sep
# 2011 54 oct
# 2011 54 nov
# 2011 54 dec
# 2011 106 jan
# 2011 106 feb
# 2011 106 mar
# 2011 106 apr
# 2011 106 may
# 2011 106 jun
# 2011 106 jul
# 2011 106 aug
# 2011 106 sep
# 2011 106 oct
# 2011 106 nov
# 2011 106 dec
# 2011 107 jan
# 2011 107 feb
# 2011 107 mar
# 2011 107 apr
# 2011 107 may
# 2011 107 jun
# 2011 107 jul
# 2011 107 aug
# 2011 107 sep
# 2011 107 oct
# 2011 107 nov
# 2011 107 dec
# 2011 175 jan
# 2011 175 feb
# 2011 175 mar
# 2011 175 apr
# 2011 175 may
# 2011 175 jun
# 2011 175 jul
# 2011 175 aug
# 2011 175 sep
# 2011 175 oct
# 2011 175 nov
# 2011 175 dec
# 2011 279 jan
# 2011 279 feb
# 2011 279 mar
# 2011 279 apr
# 2011 279 may
# 2011 279 jun
# 2011 279 jul
# 2011 279 aug
# 2011 279 sep
# 2011 279 oct
# 2011 279 nov
# 2011 279 dec
# 2012 54 jan
# 2012 54 feb
# 2012 54 mar
# 2012 54 apr
# 2012 54 may
# 2012 54 jun
# 2012 54 jul
# 2012 54 aug
# 2012 54 sep
# 2012 54 oct
# 2012 54 nov
# 2012 54 dec
# 2012 106 jan
# 2012 106 feb
# 2012 106 mar
# 2012 106 apr
# 2012 106 may
# 2012 106 jun
# 2012 106 jul
# 2012 106 aug
# 2012 106 sep
# 2012 106 oct
# 2012 106 nov
# 2012 106 dec
# 2012 107 jan
# 2012 107 feb
# 2012 107 mar
# 2012 107 apr
# 2012 107 may
# 2012 107 jun
# 2012 107 jul
# 2012 107 aug
# 2012 107 sep
# 2012 107 oct
# 2012 107 nov
# 2012 107 dec
# 2012 175 jan
# 2012 175 feb
# 2012 175 mar
# 2012 175 apr
# 2012 175 may
# 2012 175 jun
# 2012 175 jul
# 2012 175 aug
# 2012 175 sep
# 2012 175 oct
# 2012 175 nov
# 2012 175 dec
# 2012 279 jan
# 2012 279 feb
# 2012 279 mar
# 2012 279 apr
# 2012 279 may
# 2012 279 jun
# 2012 279 jul
# 2012 279 aug
# 2012 279 sep
# 2012 279 oct
# 2012 279 nov
# 2012 279 dec
# 2013 54 jan
# 2013 54 feb
# 2013 54 mar
# 2013 54 apr
# 2013 54 may
# 2013 54 jun
# 2013 54 jul
# 2013 54 aug
# 2013 54 sep
# 2013 54 oct
# 2013 54 nov
# 2013 54 dec
# 2013 106 jan
# 2013 106 feb
# 2013 106 mar
# 2013 106 apr
# 2013 106 may
# 2013 106 jun
# 2013 106 jul
# 2013 106 aug
# 2013 106 sep
# 2013 106 oct
# 2013 106 nov
# 2013 106 dec
# 2013 107 jan
# 2013 107 feb
# 2013 107 mar
# 2013 107 apr
# 2013 107 may
# 2013 107 jun
# 2013 107 jul
# 2013 107 aug
# 2013 107 sep
# 2013 107 oct
# 2013 107 nov
# 2013 107 dec
# 2013 175 jan
# 2013 175 feb
# 2013 175 mar
# 2013 175 apr
# 2013 175 may
# 2013 175 jun
# 2013 175 jul
# 2013 175 aug
# 2013 175 sep
# 2013 175 oct
# 2013 175 nov
# 2013 175 dec
# 2013 279 jan
# 2013 279 feb
# 2013 279 mar
# 2013 279 apr
# 2013 279 may
# 2013 279 jun
# 2013 279 jul
# 2013 279 aug
# 2013 279 sep
# 2013 279 oct
# 2013 279 nov
# 2013 279 dec
# 2014 54 jan
# 2014 54 feb
# 2014 54 mar
# 2014 54 apr
# 2014 54 may
# 2014 54 jun
# 2014 54 jul
# 2014 54 aug
# 2014 54 sep
# 2014 54 oct
# 2014 54 nov
# 2014 54 dec
# 2014 106 jan
# 2014 106 feb
# 2014 106 mar
# 2014 106 apr
# 2014 106 may
# 2014 106 jun
# 2014 106 jul
# 2014 106 aug
# 2014 106 sep
# 2014 106 oct
# 2014 106 nov
# 2014 106 dec
# 2014 107 jan
# 2014 107 feb
# 2014 107 mar
# 2014 107 apr
# 2014 107 may
# 2014 107 jun
# 2014 107 jul
# 2014 107 aug
# 2014 107 sep
# 2014 107 oct
# 2014 107 nov
# 2014 107 dec
# 2014 175 jan
# 2014 175 feb
# 2014 175 mar
# 2014 175 apr
# 2014 175 may
# 2014 175 jun
# 2014 175 jul
# 2014 175 aug
# 2014 175 sep
# 2014 175 oct
# 2014 175 nov
# 2014 175 dec
# 2014 279 jan
# 2014 279 feb
# 2014 279 mar
# 2014 279 apr
# 2014 279 may
# 2014 279 jun
# 2014 279 jul
# 2014 279 aug
# 2014 279 sep
# 2014 279 oct
# 2014 279 nov
# 2014 279 dec
# 2015 54 jan
# 2015 54 feb
# 2015 54 mar
# 2015 54 apr
# 2015 54 may
# 2015 54 jun
# 2015 54 jul
# 2015 54 aug
# 2015 54 sep
# 2015 54 oct
# 2015 54 nov
# 2015 54 dec
# 2015 106 jan
# 2015 106 feb
# 2015 106 mar
# 2015 106 apr
# 2015 106 may
# 2015 106 jun
# 2015 106 jul
# 2015 106 aug
# 2015 106 sep
# 2015 106 oct
# 2015 106 nov
# 2015 106 dec
# 2015 107 jan
# 2015 107 feb
# 2015 107 mar
# 2015 107 apr
# 2015 107 may
# 2015 107 jun
# 2015 107 jul
# 2015 107 aug
# 2015 107 sep
# 2015 107 oct
# 2015 107 nov
# 2015 107 dec
# 2015 175 jan
# 2015 175 feb
# 2015 175 mar
# 2015 175 apr
# 2015 175 may
# 2015 175 jun
# 2015 175 jul
# 2015 175 aug
# 2015 175 sep
# 2015 175 oct
# 2015 175 nov
# 2015 175 dec
# 2015 279 jan
# 2015 279 feb
# 2015 279 mar
# 2015 279 apr
# 2015 279 may
# 2015 279 jun
# 2015 279 jul
# 2015 279 aug
# 2015 279 sep
# 2015 279 oct
# 2015 279 nov
# 2015 279 dec
# 2016 54 jan
# 2016 54 feb
# 2016 54 mar
# 2016 54 apr
# 2016 54 may
# 2016 54 jun
# 2016 54 jul
# 2016 54 aug
# 2016 54 sep
# 2016 54 oct
# 2016 54 nov
# 2016 54 dec
# 2016 106 jan
# 2016 106 feb
# 2016 106 mar
# 2016 106 apr
# 2016 106 may
# 2016 106 jun
# 2016 106 jul
# 2016 106 aug
# 2016 106 sep
# 2016 106 oct
# 2016 106 nov
# 2016 106 dec
# 2016 107 jan
# 2016 107 feb
# 2016 107 mar
# 2016 107 apr
# 2016 107 may
# 2016 107 jun
# 2016 107 jul
# 2016 107 aug
# 2016 107 sep
# 2016 107 oct
# 2016 107 nov
# 2016 107 dec
# 2016 175 jan
# 2016 175 feb
# 2016 175 mar
# 2016 175 apr
# 2016 175 may
# 2016 175 jun
# 2016 175 jul
# 2016 175 aug
# 2016 175 sep
# 2016 175 oct
# 2016 175 nov
# 2016 175 dec
# 2016 279 jan
# 2016 279 feb
# 2016 279 mar
# 2016 279 apr
# 2016 279 may
# 2016 279 jun
# 2016 279 jul
# 2016 279 aug
# 2016 279 sep
# 2016 279 oct
# 2016 279 nov
# 2016 279 dec
# 2017 54 jan
# 2017 54 feb
# 2017 54 mar
# 2017 54 apr
# 2017 54 may
# 2017 54 jun
# 2017 54 jul
# 2017 54 aug
# 2017 54 sep
# 2017 54 oct
# 2017 54 nov
# 2017 54 dec
# 2017 106 jan
# 2017 106 feb
# 2017 106 mar
# 2017 106 apr
# 2017 106 may
# 2017 106 jun
# 2017 106 jul
# 2017 106 aug
# 2017 106 sep
# 2017 106 oct
# 2017 106 nov
# 2017 106 dec
# 2017 107 jan
# 2017 107 feb
# 2017 107 mar
# 2017 107 apr
# 2017 107 may
# 2017 107 jun
# 2017 107 jul
# 2017 107 aug
# 2017 107 sep
# 2017 107 oct
# 2017 107 nov
# 2017 107 dec
# 2017 175 jan
# 2017 175 feb
# 2017 175 mar
# 2017 175 apr
# 2017 175 may
# 2017 175 jun
# 2017 175 jul
# 2017 175 aug
# 2017 175 sep
# 2017 175 oct
# 2017 175 nov
# 2017 175 dec
# 2017 279 jan
# 2017 279 feb
# 2017 279 mar
# 2017 279 apr
# 2017 279 may
# 2017 279 jun
# 2017 279 jul
# 2017 279 aug
# 2017 279 sep
# 2017 279 oct
# 2017 279 nov
# 2017 279 dec
# 2018 54 jan
# 2018 54 feb
# 2018 54 mar
# 2018 54 apr
# 2018 54 may
# 2018 54 jun
# 2018 54 jul
# 2018 54 aug
# 2018 54 sep
# 2018 54 oct
# 2018 54 nov
# 2018 54 dec
# 2018 106 jan
# 2018 106 feb
# 2018 106 mar
# 2018 106 apr
# 2018 106 may
# 2018 106 jun
# 2018 106 jul
# 2018 106 aug
# 2018 106 sep
# 2018 106 oct
# 2018 106 nov
# 2018 106 dec
# 2018 107 jan
# 2018 107 feb
# 2018 107 mar
# 2018 107 apr
# 2018 107 may
# 2018 107 jun
# 2018 107 jul
# 2018 107 aug
# 2018 107 sep
# 2018 107 oct
# 2018 107 nov
# 2018 107 dec
# 2018 175 jan
# 2018 175 feb
# 2018 175 mar
# 2018 175 apr
# 2018 175 may
# 2018 175 jun
# 2018 175 jul
# 2018 175 aug
# 2018 175 sep
# 2018 175 oct
# 2018 175 nov
# 2018 175 dec
# 2018 279 jan
# 2018 279 feb
# 2018 279 mar
# 2018 279 apr
# 2018 279 may
# 2018 279 jun
# 2018 279 jul
# 2018 279 aug
# 2018 279 sep
# 2018 279 oct
# 2018 279 nov
# 2018 279 dec

# %%
res_df
# Out:
#      bbc_id  year month  word_count  show_count
# 0        54  2007   jan           0           0
# 1        54  2007   feb           0           0
# 2        54  2007   mar           0           0
# 3        54  2007   apr           0           0
# 4        54  2007   may           0           0
# ..      ...   ...   ...         ...         ...
# 607     279  2018   aug           0           0
# 608     279  2018   sep           0           0
# 609     279  2018   oct           0           0
# 610     279  2018   nov           0           0
# 611     279  2018   dec           0           0
#
# [612 rows x 5 columns]

# %%
res_df.to_csv('bbc_word_and_show_counts.csv')

# %%
for bbc_id in bbc_ids:
    rows = []
    shows = []
    for year in years:
        data_path = '../data/bbc/{}/{}/transcripts'.format(bbc_id, year)
        for month in months:
            csv_file = os.path.join(data_path, '{} {}-{} {}.csv'.format(prefix[bbc_id], month, year, bbc_id))
            
            if not os.path.exists(csv_file):
                continue
            df = pd.read_csv(csv_file)
            df = df.drop(['Unnamed: 0', 'Has Transcript', 'Unavailable link', 'Unavailable reason'], axis=1)
            df['word_count'] = df['Transcript'].apply(lambda x: len(x.split()))
            shows.extend(list(df['Program Name'].unique()))

    shows = list(set(shows))
    
    res_df = pd.DataFrame(shows, columns=['shows'])
    display(res_df)
    res_df.to_csv('bbc_{}_shows.csv'.format(bbc_id))
# Out:
#                                  shows
# 0                       Joins BBC News
# 1                      BBC News at One
# 2                     BBC Weekend News
# 3                      BBC London News
# 4                             BBC News
# 5                    Better In or Out?
# 6                      BBC News at Six
# 7                     BBC News Special
# 8  BBC News Special - Royal Engagement
# 9                      BBC News at Ten
#                     shows
# 0  Channel 4 News Special
# 1      The Fake News Show
# 2                Man Down
# 3          Channel 4 News
# 4  Channel 4 News Summary
# 5     The Simpsons (2004)
#                                                 shows
# 0             Parliament Under Attack: 5 News Special
# 1          5 News Special - Manchester: A City United
# 2                     Brexit Begins: A 5 News Special
# 3                    Shock Election: A 5 News Special
# 4                                      5 News Weekend
# 5                           Angelina Ballerina (2009)
# 6                    Paris Attacks - A 5 News Special
# 7             The Queen - A Five News Tonight Special
# 8                                      5 News in Film
# 9                                  Bananas in Pyjamas
# 10                The Calais Crisis: A 5 News Special
# 11                           Britain Out: 5 News at 5
# 12                          Your Vote: 5 News Special
# 13                  Your Vote: 5 News Tonight Special
# 14  Prince Philip - A Life in Service: 5 News Toni...
# 15                                   Five News Update
# 16                                     5 News Tonight
# 17                                        5 News at 5
# 18                 When Live News Goes Horribly Wrong
# 19         5 News Special: Election Shock: What Next?
# 20                                   5 News Lunchtime
# 21  Donald Trump: The Next President - A 5 News To...
# 22                   Terror Attacks: A 5 News Special
# 23  5 News Tonight Special: Election Shock: What N...
# 24                                             5 News
# 25                                        5 News at 7
# 26                      5 News at 20: The Blair Years
# 27                     Budget Britain: 5 News Tonight
# 28            Brexit Begins: A 5 News Tonight Special
# 29             5 News: President Trump’s Inauguration
# 30                 5 News Special: Remembrance Sunday
# 31                             5 News: Terror Special
# 32           Terror Attacks: A 5 News Tonight Special
# 33                          Britain Votes Out: 5 News
#                                                 shows
# 0                        New: And Here Is the News...
# 1   The Chancellor’s Budget 2017: An ITV News Special
# 2                      ITV News: Paris Terror Attacks
# 3                     Election 2017: ITV News Special
# 4                                 New: After the News
# 5                            ITV News - Election 2015
# 6                                ITV News: The Budget
# 7            ITV News Special: The New Prime Minister
# 8                                  ITV Lunchtime News
# 9                                ITV News - VE Day 70
# 10                                 ITV News & Weather
# 11                  The Budget 2015: ITV News Special
# 12                                           ITV News
# 13                          Regional News and Weather
# 14                                    ITV News at Ten
# 15       Prime Minister’s Questions: ITV News Special
# 16                                   ITV News Special
# 17           ITV News & Weather: Paris Terror Attacks
# 18                          ITV News at Ten & Weather
# 19                         ITV News - Election Latest
# 20                                   ITV Evening News
# 21                                    ITV News London
#                                                 shows
# 0                                    Sky News at Nine
# 1                  Sky News at 11 with Mark Longhurst
# 2                                      Sky News at 11
# 3                                           The Queen
# 4                Sky World Review and Business Report
# ..                                                ...
# 110                                     Press Preview
# 111                                        Sportsline
# 112                                 Sky Midnight News
# 113  Sunrise with Sarah-Jane Mee and Jonathan Samuels
# 114                        Sunrise With Stephen Dixon
#
# [115 rows x 1 columns]
