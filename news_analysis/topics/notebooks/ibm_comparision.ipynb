# %%
import pandas as pd
from gensim import models, corpora
from gensim.parsing.preprocessing import preprocess_string, strip_tags, strip_punctuation
from gensim.parsing.preprocessing import remove_stopwords, stem_text, strip_non_alphanum, strip_multiple_whitespaces
from gensim.parsing.preprocessing import strip_short, strip_numeric
from gensim.parsing.preprocessing import STOPWORDS
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from semantic_text_similarity.models import WebBertSimilarity
import multiprocessing as mp
import nltk
import pandas as pd
import numpy as np
import tensorflow as tf
from scipy import spatial
import parmap
import os
import swifter
from tqdm import tqdm
# Out:
# /home/ubuntu/anaconda3/envs/econ/lib/python3.7/site-packages/dask/dataframe/utils.py:15: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
topics_index_to_name_map = {
    0: 'Agriculture, animals, food and rural affairs',
    1: 'Asylum, immigration and nationality',
    2: 'Business, industry and consumers',
    3: 'Communities and families',
    4: 'Crime, civil law, justice and rights',
    5: 'Culture, media and sport',
    6: 'Defence',
    7: 'Economy and finance',
    8: 'Education',
    9: 'Employment and training',
    10: 'Energy and environment',
    11: 'European Union',
    12: 'Health services and medicine',
    13: 'Housing and planning',
    14: 'International affairs',
    15: 'Parliament, government and politics',
    16: 'Science and technology',
    17: 'Social security and pensions',
    18: 'Social services',
    19: 'Transport',
    20: 'Others'
}
topics_name_to_index_map = {y:x for x,y in topics_index_to_name_map.items()}

def strip_short2(text):
    return strip_short(text, minsize=4)


def preprocess_text(text):
    FILTERS = [lambda x: x.lower(), strip_multiple_whitespaces, strip_tags, strip_punctuation,
                   strip_non_alphanum, strip_numeric, strip_short2]
    return preprocess_string(text, FILTERS)

def preprocess(topic):
    ret = []
    topic = topic.strip()
    
    if '|' in topic:
        topics = topic.split('|')
        t = topics[0]
        t = t.strip()
        return topics_name_to_index_map[t]
        
    return topics_name_to_index_map[topic]

# %%
path = './data/2016_June_transcripts.csv'
df = pd.read_csv(path)
df = df.drop(['Unnamed: 0'], axis=1)
df
# Out:
#         source        date          program  \
# 0  BBC News 24  2016-06-01  BBC News at Six
# 1  BBC1 London  2016-06-03  BBC News at One
# 2  BBC News 24  2016-06-14  BBC News at Six
# 3  BBC News 24  2016-06-09  BBC News at Ten
# 4  BBC1 London  2016-06-21  BBC News at One
# 5  BBC News 24  2016-06-02  BBC News at Six
# 6  BBC1 London  2016-06-20  BBC News at One
# 7  BBC News 24  2016-06-02  BBC News at Ten
# 8  BBC1 London  2016-06-09  BBC News at One
# 9  BBC1 London  2016-06-01  BBC News at One
#
#                                       Ibm transcript  \
# 0  What do you want to be a police but one of the...
# 1  Yeah the BBC news one cancel button. 20 years ...
# 2  The European Union Britain and Europe immigrat...
# 3  His stats I don't need anyone with a gun stand...
# 4  Now Hey own BBC 17 macaulay has the BBC knees....
# 5  Anyone's performs live room breakfast room 6 w...
# 6  At. Thank you for everything. Starts next Mond...
# 7  I think it's about getting ready for surgery w...
# 8  I only see one so if you write with the BBC ne...
# 9  130 on BBC 1. With so many claims being made o...
#
#                                           transcript
# 0  spent God knows how many man hours, and you th...
# 1  Twenty years on the coroner at an inquest into...
# 2  MUSIC: Mr Blue Sky by ELO # Sun is shinin’ in ...
# 3  They don’t need anyone with a gun standing in ...
# 4  Guilty of murder, a father who battered his si...
# 5  BIRDSONG ROCK MUSIC PLAYS Come on now! Squeaky...
# 6  MUSIC: jupiter, The Bringer Ofjollity by Holst...
# 7  I can’t hear anything. OK, we need to intubate...
# 8  Two former prime ministers join forces to warn...
# 9  It’s notjust about getting rid of cancer, it’s...

# %%
def filter_short_sentence(sentences):
    n_sent = len(sentences)
    filtered_sentences = []
    for i in range(n_sent):
        if len(sentences[i].split()) >= 10:
            filtered_sentences.append(sentences[i])
    return filtered_sentences

def partition_transcript_into_topics(transcript):
    cluster = []
    sentences = nltk.sent_tokenize(transcript)
    sentences = filter_short_sentence(sentences)
    if (len(sentences) == 0):
        return ''
    n_sent = len(sentences)
    current_cluster = [sentences[0]]
    n_cluster = 1
    for i in range(1, n_sent):
        sim = web_model.predict([(sentences[i], sentences[i-1])])[0]/5
        
#         for sent in current_cluster:
#             sim+= web_model.predict([(sent, sentences[i])])[0]/5
            
#         avg_sim = sim/len(current_cluster)
        
        if sim >= 0.1:
            current_cluster.append(sentences[i])
            if i == n_sent - 1:
                cluster.append(' '.join(current_cluster))
        else:
            n_cluster += 1
            cluster.append(' '.join(current_cluster))
            current_cluster = [sentences[i]]
    return '\n---------------------\n'.join(cluster)

# %%
web_model = WebBertSimilarity(device='cpu', batch_size=10) #defaults to GPU prediction

# %%
transcripts = df['transcript'].values
ibm_transcripts = df['Ibm transcript'].values

# %%
partitions = []
for transcript in tqdm(ibm_transcripts):
    partitions.append(partition_transcript_into_topics(transcript))
                      
df['ibm_partitioned_transcript'] = partitions
# Out:
# 100%|██████████| 10/10 [01:27<00:00,  8.74s/it]

# %%
partitions = []
for transcript in tqdm(transcripts):
    partitions.append(partition_transcript_into_topics(transcript))
                      
df['partitioned_transcript'] = partitions
# Out:
# 100%|██████████| 10/10 [02:16<00:00, 13.68s/it]

# %%
df
# Out:
#         source        date          program  \
# 0  BBC News 24  2016-06-01  BBC News at Six
# 1  BBC1 London  2016-06-03  BBC News at One
# 2  BBC News 24  2016-06-14  BBC News at Six
# 3  BBC News 24  2016-06-09  BBC News at Ten
# 4  BBC1 London  2016-06-21  BBC News at One
# 5  BBC News 24  2016-06-02  BBC News at Six
# 6  BBC1 London  2016-06-20  BBC News at One
# 7  BBC News 24  2016-06-02  BBC News at Ten
# 8  BBC1 London  2016-06-09  BBC News at One
# 9  BBC1 London  2016-06-01  BBC News at One
#
#                                       Ibm transcript  \
# 0  What do you want to be a police but one of the...
# 1  Yeah the BBC news one cancel button. 20 years ...
# 2  The European Union Britain and Europe immigrat...
# 3  His stats I don't need anyone with a gun stand...
# 4  Now Hey own BBC 17 macaulay has the BBC knees....
# 5  Anyone's performs live room breakfast room 6 w...
# 6  At. Thank you for everything. Starts next Mond...
# 7  I think it's about getting ready for surgery w...
# 8  I only see one so if you write with the BBC ne...
# 9  130 on BBC 1. With so many claims being made o...
#
#                                           transcript  \
# 0  spent God knows how many man hours, and you th...
# 1  Twenty years on the coroner at an inquest into...
# 2  MUSIC: Mr Blue Sky by ELO # Sun is shinin’ in ...
# 3  They don’t need anyone with a gun standing in ...
# 4  Guilty of murder, a father who battered his si...
# 5  BIRDSONG ROCK MUSIC PLAYS Come on now! Squeaky...
# 6  MUSIC: jupiter, The Bringer Ofjollity by Holst...
# 7  I can’t hear anything. OK, we need to intubate...
# 8  Two former prime ministers join forces to warn...
# 9  It’s notjust about getting rid of cancer, it’s...
#
#                           ibm_partitioned_transcript  \
# 0  What do you want to be a police but one of the...
# 1  20 years on the corner investigating the death...
# 2  The European Union Britain and Europe immigrat...
# 3  His stats I don't need anyone with a gun stand...
# 4  Now Hey own BBC 17 macaulay has the BBC knees....
# 5  Anyone's performs live room breakfast room 6 w...
# 6  At 1:00 the BBC news now on BBC one with so if...
# 7  I think it's about getting ready for surgery w...
# 8  I only see one so if you write with the BBC ne...
# 9  With so many claims being made on both sides t...
#
#                               partitioned_transcript
# 0  spent God knows how many man hours, and you th...
# 1  Twenty years on the coroner at an inquest into...
# 2  MUSIC: Mr Blue Sky by ELO # Sun is shinin’ in ...
# 3  They don’t need anyone with a gun standing in ...
# 4  Guilty of murder, a father who battered his si...
# 5  The end of a high street era - BHS is to close...
# 6  MUSIC: jupiter, The Bringer Ofjollity by Holst...
# 7  OK, we need to intubate, get him ready for sur...
# 8  Two former prime ministers join forces to warn...
# 9  It’s notjust about getting rid of cancer, it’s...

# %%
df.to_csv('2016_June_transcripts_with_partition.csv')

# %%
partitions = []
for index, row in df.iterrows():
    partition_string = row['partitioned_transcript']
    partition_date = row['date']
    all_partitions = partition_string.split('\n---------------------\n')
    for partition in all_partitions:
        partitions.append((index, partition_date, partition))
partition_df = pd.DataFrame(partitions, columns=['partition_id', 'date', 'transcript'])

# %%
partition_df
# Out:
#      partition_id        date  \
# 0               0  2016-06-01
# 1               0  2016-06-01
# 2               0  2016-06-01
# 3               0  2016-06-01
# 4               0  2016-06-01
# ..            ...         ...
# 366             9  2016-06-01
# 367             9  2016-06-01
# 368             9  2016-06-01
# 369             9  2016-06-01
# 370             9  2016-06-01
#
#                                             transcript
# 0    spent God knows how many man hours, and you th...
# 1    Four decades after the Birmingham pub bombings...
# 2    One of the country’s most prolific paedophiles...
# 3    After finding debris, investigators detect sig...
# 4    And the oldest hand-written document ever foun...
# ..                                                 ...
# 366  The governing body wants more control over the...
# 367  A signal has been detected that is likely to b...
# 368  Donald Trump - who’s set to be the Republican ...
# 369  75 members of the japanese Self-Defence Forces...
# 370  These little pieces of wood and tiny scratches...
#
# [371 rows x 3 columns]

# %%
partition_df.to_csv('2016_June_partition.csv')

# %%
partitions = []
for index, row in df.iterrows():
    partition_string = row['ibm_partitioned_transcript']
    partition_date = row['date']
    all_partitions = partition_string.split('\n---------------------\n')
    for partition in all_partitions:
        partitions.append((index, partition_date, partition))
ibm_partition_df = pd.DataFrame(partitions, columns=['partition_id', 'date', 'transcript'])

# %%
ibm_partition_df
# Out:
#      partition_id        date  \
# 0               0  2016-06-01
# 1               0  2016-06-01
# 2               0  2016-06-01
# 3               0  2016-06-01
# 4               0  2016-06-01
# ..            ...         ...
# 189             9  2016-06-01
# 190             9  2016-06-01
# 191             9  2016-06-01
# 192             9  2016-06-01
# 193             9  2016-06-01
#
#                                             transcript
# 0    What do you want to be a police but one of the...
# 1    4 decades after the Birmingham pub bombings ki...
# 2    One of the country's most prolific paedophiles...
# 3    After finding debris investigators detect sign...
# 4    The oldest handwritten documents ever found in...
# ..                                                 ...
# 189  A signal has been detected that is likely to b...
# 190  Donald Trump who's set to be the Republican pr...
# 191  75 members of the Japanese self defense forces...
# 192  The first ever mention of London Britain's old...
# 193  It's time for a look at the weather and J. whe...
#
# [194 rows x 3 columns]

# %%
ibm_partition_df.to_csv('2016_June_ibm_partition.csv')

# %%
year = 2016
excluding = '_no_Others'

# %% [markdown]
# # Topic Prediction with NN Classifier

# %%
from joblib import dump, load

enc = load('./models/doc2vec/encoder_{}{}.joblib'.format(year, excluding))

def predict(X, topn=3):
    preprocessed_X = preprocess_text(X)
    vec_X = doc2vec_model.infer_vector(preprocessed_X)
    vec_X = vec_X.reshape(1, vec_X.shape[0])
    pred = classifier.predict(vec_X)
    pred_i = []
    for i, p in enumerate(pred[0]):
        one_hot = np.zeros(len(pred[0]))
        one_hot[i] = 1
        pred_i += [(enc.inverse_transform([one_hot])[0][0], p)]
    pred_sorted = sorted(pred_i, key=lambda x: x[1], reverse=True)
    return pred_sorted[:topn]


def build_network():
    model = tf.keras.models.Sequential([
        tf.keras.Input(shape=(100)),
        tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l=0.1)),
        tf.keras.layers.Dense(len(enc.categories_[0]), activation='softmax')
    ])
    loss_fn = tf.keras.losses.CategoricalCrossentropy(from_logits=False, label_smoothing=0, name='categorical_crossentropy')

    model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=loss_fn,
              metrics=['accuracy'])
    
    return model

# %%
doc2vec_model = Doc2Vec.load('./models/doc2vec/doc2vec_news_{}{}'.format(year, excluding))
classifier = build_network()
classifier.load_weights('./models/doc2vec/news_classifier_{}{}'.format(year, excluding))

# %%
transcripts = partition_df.transcript.values
predict(transcripts[5])
# Out:
# [('Crime, civil law, justice and rights', 0.7038356),
#  ('Parliament, government and politics', 0.1446062),
#  ('Culture, media and sport', 0.11053462)]

# %%
predictions = []
from tqdm import tqdm
for transcript in tqdm(transcripts):
    predictions.append(predict(transcript))
# Out:
# 100%|██████████| 371/371 [00:19<00:00, 19.19it/s]

# %%
partition_df['topic'] = predictions

# %%
partition_df
# Out:
#      partition_id        date  \
# 0               0  2016-06-01
# 1               0  2016-06-01
# 2               0  2016-06-01
# 3               0  2016-06-01
# 4               0  2016-06-01
# ..            ...         ...
# 366             9  2016-06-01
# 367             9  2016-06-01
# 368             9  2016-06-01
# 369             9  2016-06-01
# 370             9  2016-06-01
#
#                                             transcript  \
# 0    spent God knows how many man hours, and you th...
# 1    Four decades after the Birmingham pub bombings...
# 2    One of the country’s most prolific paedophiles...
# 3    After finding debris, investigators detect sig...
# 4    And the oldest hand-written document ever foun...
# ..                                                 ...
# 366  The governing body wants more control over the...
# 367  A signal has been detected that is likely to b...
# 368  Donald Trump - who’s set to be the Republican ...
# 369  75 members of the japanese Self-Defence Forces...
# 370  These little pieces of wood and tiny scratches...
#
#                                                  topic
# 0    [(Parliament, government and politics, 0.40760...
# 1    [(Parliament, government and politics, 0.62804...
# 2    [(Crime, civil law, justice and rights, 0.5972...
# 3    [(Parliament, government and politics, 0.58782...
# 4    [(Culture, media and sport, 0.38548765), (Parl...
# ..                                                 ...
# 366  [(Culture, media and sport, 0.71138096), (Parl...
# 367  [(Parliament, government and politics, 0.72483...
# 368  [(Parliament, government and politics, 0.57083...
# 369  [(International affairs, 0.41441783), (Culture...
# 370  [(Business, industry and consumers, 0.37863973...
#
# [371 rows x 4 columns]

# %%
transcripts = ibm_partition_df.transcript.values
predict(transcripts[5])
# Out:
# [('Transport', 0.8905398),
#  ('Business, industry and consumers', 0.068960205),
#  ('European Union', 0.013720543)]

# %%
predictions = []
from tqdm import tqdm
for transcript in tqdm(transcripts):
    predictions.append(predict(transcript))
# Out:
# 100%|██████████| 194/194 [00:12<00:00, 15.23it/s]

# %%
ibm_partition_df['topic'] = predictions

# %%
ibm_partition_df
# Out:
#      partition_id        date  \
# 0               0  2016-06-01
# 1               0  2016-06-01
# 2               0  2016-06-01
# 3               0  2016-06-01
# 4               0  2016-06-01
# ..            ...         ...
# 189             9  2016-06-01
# 190             9  2016-06-01
# 191             9  2016-06-01
# 192             9  2016-06-01
# 193             9  2016-06-01
#
#                                             transcript  \
# 0    What do you want to be a police but one of the...
# 1    4 decades after the Birmingham pub bombings ki...
# 2    One of the country's most prolific paedophiles...
# 3    After finding debris investigators detect sign...
# 4    The oldest handwritten documents ever found in...
# ..                                                 ...
# 189  A signal has been detected that is likely to b...
# 190  Donald Trump who's set to be the Republican pr...
# 191  75 members of the Japanese self defense forces...
# 192  The first ever mention of London Britain's old...
# 193  It's time for a look at the weather and J. whe...
#
#                                                  topic
# 0    [(Parliament, government and politics, 0.63155...
# 1    [(Parliament, government and politics, 0.54178...
# 2    [(Crime, civil law, justice and rights, 0.6025...
# 3    [(Parliament, government and politics, 0.64695...
# 4    [(European Union, 0.46035329), (Parliament, go...
# ..                                                 ...
# 189  [(Parliament, government and politics, 0.78883...
# 190  [(Parliament, government and politics, 0.58243...
# 191  [(International affairs, 0.6331176), (Parliame...
# 192  [(Business, industry and consumers, 0.5929644)...
# 193  [(Culture, media and sport, 0.47465262), (Parl...
#
# [194 rows x 4 columns]

# %%
partition_df.to_csv('2016_June_partition_prediction.csv')
ibm_partition_df.to_csv('2016_June_ibm_partition_prediction.csv')

# %% [markdown]
# # Window Prediction: Cosine Similarity

# %%
partition_df['vector'] = partition_df.swifter.apply(lambda x: doc2vec_model.infer_vector(preprocess_text(x['transcript'])), axis=1)
ibm_partition_df['vector'] = ibm_partition_df.swifter.apply(lambda x: doc2vec_model.infer_vector(preprocess_text(x['transcript'])), axis=1)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Pandas Apply', max=371.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Pandas Apply', max=194.0, style=ProgressStyle(description…

# %%
articles = pd.read_csv('./data/news_predictions/news_2016_predictions.csv')

# %%
articles = articles.dropna(subset=['transcript'])
articles = articles.loc[articles.top1_topic != 'Others']
articles = articles.drop(['Unnamed: 0'], axis=1)
articles = articles.loc[articles.month.isin([6])]
articles
# Out:
#         source_id             source  day  month  year  \
# 815059     163795  Belfast Telegraph    1      6  2016
# 815060     163795  Belfast Telegraph    1      6  2016
# 815061     163795  Belfast Telegraph    1      6  2016
# 815062     163795  Belfast Telegraph    1      6  2016
# 815063     163795  Belfast Telegraph    1      6  2016
# ...           ...                ...  ...    ...   ...
# 970363     412338              Wales   30      6  2016
# 970364     412338              Wales   30      6  2016
# 970365     412338              Wales   30      6  2016
# 970366     412338              Wales   30      6  2016
# 970367     412338              Wales   30      6  2016
#
#                                              program_name  \
# 815059  North West 'needs task force on jobs to be rev...
# 815060             Time to take your town centre to heart
# 815061                     Causeway Coast for food heaven
# 815062  Here comes summer - time for Country Kitchen s...
# 815063                       NI for the cream of the crop
# ...                                                   ...
# 970363  Amazon announce Second Prime Day shopping even...
# 970364  Morning news headlines: Boris Johnson and Ther...
# 970365  Inspection finds Welsh police force kept too m...
# 970366  Inspection found that a Welsh police force kep...
# 970367  Inquiry finds parents were 'let down' by stand...
#
#                                                transcript  parliament  \
# 815059  Gavin Killeen, who said more needs to be done ...           1
# 815060  Rather than complain, residents can participat...           1
# 815061  Despite its infancy, the CCAG Food Network has...           1
# 815062  Country Kitchen side salads are the perfect ac...           1
# 815063  Comber Earlies - in season now, Lough Neagh Ee...           1
# ...                                                   ...         ...
# 970363  Prime Day will take place on July 12, with the...           1
# 970364  Tory heavyweights Boris Johnson and Theresa Ma...           1
# 970365  HM Inspectorate of Constabulary (HMIC) publish...           1
# 970366  HM Inspectorate of Constabulary (HMIC) publish...           1
# 970367  A review commissioned by NHS England Medical D...           1
#
#                                           top1_topic  top1_acc  \
# 815059           Parliament, government and politics     72.42
# 815060                      Culture, media and sport     24.98
# 815061                      Culture, media and sport     52.31
# 815062                      Culture, media and sport     28.93
# 815063  Agriculture, animals, food and rural affairs     40.33
# ...                                              ...       ...
# 970363              Business, industry and consumers     20.31
# 970364           Parliament, government and politics     25.05
# 970365          Crime, civil law, justice and rights     39.50
# 970366          Crime, civil law, justice and rights     35.47
# 970367                  Health services and medicine     76.88
#
#                                           top2_topic  top2_acc  \
# 815059              Business, industry and consumers      6.75
# 815060              Business, industry and consumers     23.64
# 815061  Agriculture, animals, food and rural affairs     17.63
# 815062                                        Others     24.34
# 815063                      Culture, media and sport     39.01
# ...                                              ...       ...
# 970363                                        Others     15.73
# 970364                      Culture, media and sport     18.58
# 970365                      Communities and families     11.34
# 970366                      Communities and families     14.13
# 970367                                        Others     16.05
#
#                                           top3_topic  top3_acc
# 815059                           Economy and finance      4.93
# 815060  Agriculture, animals, food and rural affairs     10.36
# 815061              Business, industry and consumers      8.31
# 815062              Business, industry and consumers     10.81
# 815063                                        Others      4.54
# ...                                              ...       ...
# 970363                                     Transport      6.81
# 970364                         International affairs     17.69
# 970365           Parliament, government and politics      9.34
# 970366                  Health services and medicine     10.10
# 970367                      Communities and families      1.26
#
# [123677 rows x 14 columns]

# %%
vector = []
transcripts = articles.transcript.values

preprocessed_transcripts = parmap.map(preprocess_text, transcripts, pm_pbar=True)

vector_transcripts = parmap.map(doc2vec_model.infer_vector, preprocessed_transcripts, pm_pbar=True)
articles['vector'] = vector_transcripts

del preprocessed_transcripts

articles
# Out:
# 123776it [00:29, 4245.83it/s]
# 123776it [04:04, 505.79it/s]
#         source_id             source  day  month  year  \
# 815059     163795  Belfast Telegraph    1      6  2016
# 815060     163795  Belfast Telegraph    1      6  2016
# 815061     163795  Belfast Telegraph    1      6  2016
# 815062     163795  Belfast Telegraph    1      6  2016
# 815063     163795  Belfast Telegraph    1      6  2016
# ...           ...                ...  ...    ...   ...
# 970363     412338              Wales   30      6  2016
# 970364     412338              Wales   30      6  2016
# 970365     412338              Wales   30      6  2016
# 970366     412338              Wales   30      6  2016
# 970367     412338              Wales   30      6  2016
#
#                                              program_name  \
# 815059  North West 'needs task force on jobs to be rev...
# 815060             Time to take your town centre to heart
# 815061                     Causeway Coast for food heaven
# 815062  Here comes summer - time for Country Kitchen s...
# 815063                       NI for the cream of the crop
# ...                                                   ...
# 970363  Amazon announce Second Prime Day shopping even...
# 970364  Morning news headlines: Boris Johnson and Ther...
# 970365  Inspection finds Welsh police force kept too m...
# 970366  Inspection found that a Welsh police force kep...
# 970367  Inquiry finds parents were 'let down' by stand...
#
#                                                transcript  parliament  \
# 815059  Gavin Killeen, who said more needs to be done ...           1
# 815060  Rather than complain, residents can participat...           1
# 815061  Despite its infancy, the CCAG Food Network has...           1
# 815062  Country Kitchen side salads are the perfect ac...           1
# 815063  Comber Earlies - in season now, Lough Neagh Ee...           1
# ...                                                   ...         ...
# 970363  Prime Day will take place on July 12, with the...           1
# 970364  Tory heavyweights Boris Johnson and Theresa Ma...           1
# 970365  HM Inspectorate of Constabulary (HMIC) publish...           1
# 970366  HM Inspectorate of Constabulary (HMIC) publish...           1
# 970367  A review commissioned by NHS England Medical D...           1
#
#                                           top1_topic  top1_acc  \
# 815059           Parliament, government and politics     72.42
# 815060                      Culture, media and sport     24.98
# 815061                      Culture, media and sport     52.31
# 815062                      Culture, media and sport     28.93
# 815063  Agriculture, animals, food and rural affairs     40.33
# ...                                              ...       ...
# 970363              Business, industry and consumers     20.31
# 970364           Parliament, government and politics     25.05
# 970365          Crime, civil law, justice and rights     39.50
# 970366          Crime, civil law, justice and rights     35.47
# 970367                  Health services and medicine     76.88
#
#                                           top2_topic  top2_acc  \
# 815059              Business, industry and consumers      6.75
# 815060              Business, industry and consumers     23.64
# 815061  Agriculture, animals, food and rural affairs     17.63
# 815062                                        Others     24.34
# 815063                      Culture, media and sport     39.01
# ...                                              ...       ...
# 970363                                        Others     15.73
# 970364                      Culture, media and sport     18.58
# 970365                      Communities and families     11.34
# 970366                      Communities and families     14.13
# 970367                                        Others     16.05
#
#                                           top3_topic  top3_acc  \
# 815059                           Economy and finance      4.93
# 815060  Agriculture, animals, food and rural affairs     10.36
# 815061              Business, industry and consumers      8.31
# 815062              Business, industry and consumers     10.81
# 815063                                        Others      4.54
# ...                                              ...       ...
# 970363                                     Transport      6.81
# 970364                         International affairs     17.69
# 970365           Parliament, government and politics      9.34
# 970366                  Health services and medicine     10.10
# 970367                      Communities and families      1.26
#
#                                                    vector
# 815059  [0.3408227, -0.0209849, 0.17903826, -1.7234977...
# 815060  [-0.71105456, -0.4305179, -0.5447584, -0.42238...
# 815061  [0.6972058, -1.0441506, 2.6348343, 0.16490413,...
# 815062  [-1.3153038, 2.404461, 1.6879399, -1.8530523, ...
# 815063  [0.80128914, -0.14410646, 0.5001334, -0.420445...
# ...                                                   ...
# 970363  [-1.4910322, 0.32347322, 1.4588598, -0.1260592...
# 970364  [0.49234232, -1.7949353, 0.83398604, 0.3449338...
# 970365  [1.4860406, -0.58440536, -0.90384376, 0.650212...
# 970366  [1.2201128, -0.52487105, -0.9235491, 0.6955690...
# 970367  [0.7265289, -0.5184033, -1.1909409, 2.313576, ...
#
# [123677 rows x 15 columns]

# %%
import datetime
articles['date'] = articles.apply(lambda x: datetime.date(x.year, x.month, x.day), axis=1)

# %%
from datetime import datetime, timedelta
from sklearn.metrics.pairwise import cosine_similarity

def predict_with_window(partition):
    dt = partition.date
    start_dt = dt - timedelta(days=2)
    end_dt = dt + timedelta(days=2)
    articles_window = articles.loc[(articles['date'] >= start_dt) & (articles['date'] <= end_dt)]
    partition_vector = np.array(partition.vector)
    partition_vector = partition_vector.reshape(1, 100)
    articles_vector = articles_window.vector.values
    vec = [articles_vector[i] for i in range(len(articles_vector))]
    vec = np.array(vec)
    sim = cosine_similarity(partition_vector, vec)
    max_index = np.argmax(sim)
    
    return articles_window.iloc[max_index]['top1_topic']

# %%
partition_df['date'] = pd.to_datetime(partition_df['date'])
preds = []

for index, row in tqdm(partition_df.iterrows(), total=len(partition_df)):
    preds.append(predict_with_window(row))
    
partition_df['window prediction'] = preds
# Out:
# 100%|██████████| 371/371 [00:38<00:00,  9.74it/s]

# %%
ibm_partition_df['date'] = pd.to_datetime(ibm_partition_df['date'])

preds = []

for index, row in tqdm(ibm_partition_df.iterrows(), total=len(ibm_partition_df)):
    preds.append(predict_with_window(row))
    
ibm_partition_df['window prediction'] = preds
# Out:
# 100%|██████████| 194/194 [00:22<00:00,  8.62it/s]

# %%
partition_df = partition_df.drop(['vector'], axis=1)
ibm_partition_df = ibm_partition_df.drop(['vector'], axis=1)

# %%
partition_df.to_csv('2016_June_partition_prediction.csv')
ibm_partition_df.to_csv('2016_June_ibm_partition_prediction.csv')

# %% [markdown]
# # TFIDF WINDOW Prediction

# %%
vector = []
transcripts = articles.transcript.values

from gensim import corpora, models, similarities
preprocessed_transcripts = parmap.map(preprocess_text, transcripts, pm_pbar=True)

dictionary = corpora.Dictionary(preprocessed_transcripts)
dictionary.filter_extremes(no_below=5, no_above=0.7)
# Out:
#   0%|          | 0/123677 [00:00<?, ?it/s]
#
#
#
#
#
#  20%|█▉        | 24175/123677 [00:12<00:51, 1928.86it/s]
#
#
#
#
#
#  38%|███▊      | 46416/123677 [00:14<00:30, 2562.29it/s]
#
#
#
#
#
#  56%|█████▋    | 69624/123677 [00:16<00:16, 3320.16it/s]
#
#
#
#
#
#  72%|███████▏  | 88964/123677 [00:31<00:13, 2516.57it/s]
#
#
#
#
#
#  72%|███████▏  | 88964/123677 [00:31<00:13, 2516.57it/s]
#
#
#
#
#
#  92%|█████████▏| 114106/123677 [00:33<00:03, 2965.93it/s]
#
#
#
#
#
# 123776it [00:34, 3613.66it/s]

# %%
raw_corpus = parmap.map(dictionary.doc2bow, preprocessed_transcripts, pm_pbar=True)

tfidf = models.TfidfModel(raw_corpus)

def tfidf_transform(t):
    return tfidf[dictionary.doc2bow(preprocess_text(t))]

vector_transcripts = parmap.map(tfidf_transform, transcripts, pm_pbar=True)
articles['vector'] = vector_transcripts

articles
# Out:
#   0%|          | 0/123677 [00:00<?, ?it/s]
#
#
#
#
#
#   2%|▏         | 2901/123677 [00:02<01:24, 1422.33it/s]
#
#
#
#
#
#   9%|▉         | 11604/123677 [00:04<01:03, 1769.94it/s]
#
#
#
#
#
#  16%|█▌        | 19340/123677 [00:06<00:49, 2091.47it/s]
#
#
#
#
#
#  25%|██▌       | 30944/123677 [00:08<00:37, 2506.02it/s]
#
#
#
#
#
#  33%|███▎      | 40614/123677 [00:10<00:28, 2878.89it/s]
#
#
#
#
#
#  39%|███▉      | 48350/123677 [00:13<00:24, 3096.93it/s]
#
#
#
#
#
#  47%|████▋     | 58020/123677 [00:15<00:19, 3347.71it/s]
#
#
#
#
#
#  56%|█████▋    | 69624/123677 [00:17<00:14, 3683.94it/s]
#
#
#
#
#
#  64%|██████▍   | 79294/123677 [00:20<00:11, 3846.78it/s]
#
#
#
#
#
#  72%|███████▏  | 88964/123677 [00:22<00:08, 3945.49it/s]
#
#
#
#
#
#  80%|███████▉  | 98634/123677 [00:24<00:06, 3971.44it/s]
#
#
#
#
#
#  83%|████████▎ | 102502/123677 [00:31<00:14, 1503.61it/s]
#
#
#
#
#
#  90%|████████▉ | 111205/123677 [00:33<00:06, 1815.92it/s]
#
#
#
#
#
#  99%|█████████▉| 122809/123677 [00:35<00:00, 2285.97it/s]
#
#
#
#
#
# 123776it [00:35, 3463.39it/s]
#
#
#
#
#
#
#   0%|          | 0/123677 [00:00<?, ?it/s]
#
#
#
#
#
#   9%|▊         | 10637/123677 [00:04<00:43, 2601.03it/s]
#
#
#
#
#
#  20%|█▉        | 24175/123677 [00:06<00:31, 3176.61it/s]
#
#
#
#
#
#  30%|███       | 37713/123677 [00:08<00:22, 3768.90it/s]
#
#
#
#
#
#  41%|████      | 50284/123677 [00:10<00:17, 4252.19it/s]
#
#
#
#
#
#  53%|█████▎    | 65756/123677 [00:12<00:11, 4910.61it/s]
#
#
#
#
#
#  64%|██████▍   | 79294/123677 [00:14<00:08, 5206.29it/s]
#
#
#
#
#
#  73%|███████▎  | 90898/123677 [00:16<00:06, 5254.62it/s]
#
#
#
#
#
#  84%|████████▍ | 104436/123677 [00:18<00:03, 5497.32it/s]
#
#
#
#
#
#  95%|█████████▌| 117974/123677 [00:27<00:01, 3157.76it/s]
#
#
#
#
#
# 123776it [00:28, 4404.98it/s]
#         source_id             source  day  month  year  \
# 815059     163795  Belfast Telegraph    1      6  2016
# 815060     163795  Belfast Telegraph    1      6  2016
# 815061     163795  Belfast Telegraph    1      6  2016
# 815062     163795  Belfast Telegraph    1      6  2016
# 815063     163795  Belfast Telegraph    1      6  2016
# ...           ...                ...  ...    ...   ...
# 970363     412338              Wales   30      6  2016
# 970364     412338              Wales   30      6  2016
# 970365     412338              Wales   30      6  2016
# 970366     412338              Wales   30      6  2016
# 970367     412338              Wales   30      6  2016
#
#                                              program_name  \
# 815059  North West 'needs task force on jobs to be rev...
# 815060             Time to take your town centre to heart
# 815061                     Causeway Coast for food heaven
# 815062  Here comes summer - time for Country Kitchen s...
# 815063                       NI for the cream of the crop
# ...                                                   ...
# 970363  Amazon announce Second Prime Day shopping even...
# 970364  Morning news headlines: Boris Johnson and Ther...
# 970365  Inspection finds Welsh police force kept too m...
# 970366  Inspection found that a Welsh police force kep...
# 970367  Inquiry finds parents were 'let down' by stand...
#
#                                                transcript  parliament  \
# 815059  Gavin Killeen, who said more needs to be done ...           1
# 815060  Rather than complain, residents can participat...           1
# 815061  Despite its infancy, the CCAG Food Network has...           1
# 815062  Country Kitchen side salads are the perfect ac...           1
# 815063  Comber Earlies - in season now, Lough Neagh Ee...           1
# ...                                                   ...         ...
# 970363  Prime Day will take place on July 12, with the...           1
# 970364  Tory heavyweights Boris Johnson and Theresa Ma...           1
# 970365  HM Inspectorate of Constabulary (HMIC) publish...           1
# 970366  HM Inspectorate of Constabulary (HMIC) publish...           1
# 970367  A review commissioned by NHS England Medical D...           1
#
#                                           top1_topic  top1_acc  \
# 815059           Parliament, government and politics     72.42
# 815060                      Culture, media and sport     24.98
# 815061                      Culture, media and sport     52.31
# 815062                      Culture, media and sport     28.93
# 815063  Agriculture, animals, food and rural affairs     40.33
# ...                                              ...       ...
# 970363              Business, industry and consumers     20.31
# 970364           Parliament, government and politics     25.05
# 970365          Crime, civil law, justice and rights     39.50
# 970366          Crime, civil law, justice and rights     35.47
# 970367                  Health services and medicine     76.88
#
#                                           top2_topic  top2_acc  \
# 815059              Business, industry and consumers      6.75
# 815060              Business, industry and consumers     23.64
# 815061  Agriculture, animals, food and rural affairs     17.63
# 815062                                        Others     24.34
# 815063                      Culture, media and sport     39.01
# ...                                              ...       ...
# 970363                                        Others     15.73
# 970364                      Culture, media and sport     18.58
# 970365                      Communities and families     11.34
# 970366                      Communities and families     14.13
# 970367                                        Others     16.05
#
#                                           top3_topic  top3_acc  \
# 815059                           Economy and finance      4.93
# 815060  Agriculture, animals, food and rural affairs     10.36
# 815061              Business, industry and consumers      8.31
# 815062              Business, industry and consumers     10.81
# 815063                                        Others      4.54
# ...                                              ...       ...
# 970363                                     Transport      6.81
# 970364                         International affairs     17.69
# 970365           Parliament, government and politics      9.34
# 970366                  Health services and medicine     10.10
# 970367                      Communities and families      1.26
#
#                                                    vector        date
# 815059  [(0, 0.009768523601801414), (1, 0.037194480658...  2016-06-01
# 815060  [(0, 0.008816292574312965), (12, 0.00649942546...  2016-06-01
# 815061  [(55, 0.02630912819204411), (56, 0.03031247511...  2016-06-01
# 815062  [(11, 0.01850950104966622), (65, 0.08106747721...  2016-06-01
# 815063  [(0, 0.015123308361842233), (15, 0.01624536985...  2016-06-01
# ...                                                   ...         ...
# 970363  [(11, 0.02671843797247299), (59, 0.04164182682...  2016-06-30
# 970364  [(0, 0.007007584773078375), (5, 0.032375998337...  2016-06-30
# 970365  [(2, 0.018038846339345438), (7, 0.038170161277...  2016-06-30
# 970366  [(2, 0.018038846339345438), (7, 0.038170161277...  2016-06-30
# 970367  [(0, 0.023760049032434886), (2, 0.019433954680...  2016-06-30
#
# [123677 rows x 16 columns]

# %%
partition_df['vector'] = partition_df.swifter.apply(lambda x: tfidf_transform(x['transcript']), axis=1)
ibm_partition_df['vector'] = ibm_partition_df.swifter.apply(lambda x: tfidf_transform(x['transcript']), axis=1)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Pandas Apply', max=371.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Pandas Apply', max=194.0, style=ProgressStyle(description…

# %%
index = similarities.MatrixSimilarity(articles.vector)

# %%
def predict_with_tfidf_window(partition):
    dt = partition.date
    start_dt = dt - timedelta(days=2)
    end_dt = dt + timedelta(days=2)
    indices = articles.loc[(articles['date'] >= start_dt) & (articles['date'] <= end_dt)].index
    partition_vector = partition.vector
    
    sim = index[partition_vector]
    max_index = np.argmax(sim)
    
    return articles.iloc[max_index]['top1_topic']

# %%
preds = []
for _, row in tqdm(partition_df.iterrows(), total=len(partition_df)):
    preds.append(predict_with_tfidf_window(row))
    
partition_df['tfidf_window prediction'] = preds
# Out:
#   0%|          | 0/371 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#   0%|          | 1/371 [00:02<12:22,  2.01s/it]
#
#
#
#
#
#
#
#   1%|          | 2/371 [00:04<12:19,  2.00s/it]
#
#
#
#
#
#
#
#   1%|          | 3/371 [00:05<11:43,  1.91s/it]
#
#
#
#
#
#
#
#   1%|          | 4/371 [00:07<11:10,  1.83s/it]
#
#
#
#
#
#
#
#   1%|▏         | 5/371 [00:08<10:46,  1.77s/it]
#
#
#
#
#
#
#
#   2%|▏         | 6/371 [00:10<10:29,  1.72s/it]
#
#
#
#
#
#
#
#   2%|▏         | 7/371 [00:12<10:18,  1.70s/it]
#
#
#
#
#
#
#
#   2%|▏         | 8/371 [00:13<10:10,  1.68s/it]
#
#
#
#
#
#
#
#   2%|▏         | 9/371 [00:15<10:07,  1.68s/it]
#
#
#
#
#
#
#
#   3%|▎         | 10/371 [00:17<10:02,  1.67s/it]
#
#
#
#
#
#
#
#   3%|▎         | 11/371 [00:18<09:56,  1.66s/it]
#
#
#
#
#
#
#
#   3%|▎         | 12/371 [00:20<09:51,  1.65s/it]
#
#
#
#
#
#
#
#   4%|▎         | 13/371 [00:22<09:47,  1.64s/it]
#
#
#
#
#
#
#
#   4%|▍         | 14/371 [00:23<09:44,  1.64s/it]
#
#
#
#
#
#
#
#   4%|▍         | 15/371 [00:25<09:41,  1.63s/it]
#
#
#
#
#
#
#
#   4%|▍         | 16/371 [00:26<09:38,  1.63s/it]
#
#
#
#
#
#
#
#   5%|▍         | 17/371 [00:28<09:37,  1.63s/it]
#
#
#
#
#
#
#
#   5%|▍         | 18/371 [00:30<09:34,  1.63s/it]
#
#
#
#
#
#
#
#   5%|▌         | 19/371 [00:31<09:32,  1.63s/it]
#
#
#
#
#
#
#
#   5%|▌         | 20/371 [00:33<09:32,  1.63s/it]
#
#
#
#
#
#
#
#   6%|▌         | 21/371 [00:35<09:31,  1.63s/it]
#
#
#
#
#
#
#
#   6%|▌         | 22/371 [00:36<09:28,  1.63s/it]
#
#
#
#
#
#
#
#   6%|▌         | 23/371 [00:38<09:26,  1.63s/it]
#
#
#
#
#
#
#
#   6%|▋         | 24/371 [00:39<09:26,  1.63s/it]
#
#
#
#
#
#
#
#   7%|▋         | 25/371 [00:41<09:24,  1.63s/it]
#
#
#
#
#
#
#
#   7%|▋         | 26/371 [00:43<09:21,  1.63s/it]
#
#
#
#
#
#
#
#   7%|▋         | 27/371 [00:44<09:20,  1.63s/it]
#
#
#
#
#
#
#
#   8%|▊         | 28/371 [00:46<09:18,  1.63s/it]
#
#
#
#
#
#
#
#   8%|▊         | 29/371 [00:48<09:17,  1.63s/it]
#
#
#
#
#
#
#
#   8%|▊         | 30/371 [00:49<09:15,  1.63s/it]
#
#
#
#
#
#
#
#   8%|▊         | 31/371 [00:51<09:13,  1.63s/it]
#
#
#
#
#
#
#
#   9%|▊         | 32/371 [00:52<09:11,  1.63s/it]
#
#
#
#
#
#
#
#   9%|▉         | 33/371 [00:54<09:09,  1.63s/it]
#
#
#
#
#
#
#
#   9%|▉         | 34/371 [00:56<09:07,  1.62s/it]
#
#
#
#
#
#
#
#   9%|▉         | 35/371 [00:57<09:06,  1.63s/it]
#
#
#
#
#
#
#
#  10%|▉         | 36/371 [00:59<09:05,  1.63s/it]
#
#
#
#
#
#
#
#  10%|▉         | 37/371 [01:01<09:03,  1.63s/it]
#
#
#
#
#
#
#
#  10%|█         | 38/371 [01:02<09:01,  1.63s/it]
#
#
#
#
#
#
#
#  11%|█         | 39/371 [01:04<09:00,  1.63s/it]
#
#
#
#
#
#
#
#  11%|█         | 40/371 [01:06<08:58,  1.63s/it]
#
#
#
#
#
#
#
#  11%|█         | 41/371 [01:07<08:56,  1.63s/it]
#
#
#
#
#
#
#
#  11%|█▏        | 42/371 [01:09<08:55,  1.63s/it]
#
#
#
#
#
#
#
#  12%|█▏        | 43/371 [01:10<08:53,  1.63s/it]
#
#
#
#
#
#
#
#  12%|█▏        | 44/371 [01:12<08:51,  1.63s/it]
#
#
#
#
#
#
#
#  12%|█▏        | 45/371 [01:14<08:50,  1.63s/it]
#
#
#
#
#
#
#
#  12%|█▏        | 46/371 [01:15<08:49,  1.63s/it]
#
#
#
#
#
#
#
#  13%|█▎        | 47/371 [01:17<08:47,  1.63s/it]
#
#
#
#
#
#
#
#  13%|█▎        | 48/371 [01:19<08:47,  1.63s/it]
#
#
#
#
#
#
#
#  13%|█▎        | 49/371 [01:20<08:47,  1.64s/it]
#
#
#
#
#
#
#
#  13%|█▎        | 50/371 [01:22<08:44,  1.63s/it]
#
#
#
#
#
#
#
#  14%|█▎        | 51/371 [01:23<08:41,  1.63s/it]
#
#
#
#
#
#
#
#  14%|█▍        | 52/371 [01:25<08:40,  1.63s/it]
#
#
#
#
#
#
#
#  14%|█▍        | 53/371 [01:27<08:37,  1.63s/it]
#
#
#
#
#
#
#
#  15%|█▍        | 54/371 [01:28<08:36,  1.63s/it]
#
#
#
#
#
#
#
#  15%|█▍        | 55/371 [01:30<08:34,  1.63s/it]
#
#
#
#
#
#
#
#  15%|█▌        | 56/371 [01:32<08:33,  1.63s/it]
#
#
#
#
#
#
#
#  15%|█▌        | 57/371 [01:33<08:32,  1.63s/it]
#
#
#
#
#
#
#
#  16%|█▌        | 58/371 [01:35<08:31,  1.64s/it]
#
#
#
#
#
#
#
#  16%|█▌        | 59/371 [01:36<08:29,  1.63s/it]
#
#
#
#
#
#
#
#  16%|█▌        | 60/371 [01:38<08:27,  1.63s/it]
#
#
#
#
#
#
#
#  16%|█▋        | 61/371 [01:40<08:25,  1.63s/it]
#
#
#
#
#
#
#
#  17%|█▋        | 62/371 [01:41<08:23,  1.63s/it]
#
#
#
#
#
#
#
#  17%|█▋        | 63/371 [01:43<08:21,  1.63s/it]
#
#
#
#
#
#
#
#  17%|█▋        | 64/371 [01:45<08:20,  1.63s/it]
#
#
#
#
#
#
#
#  18%|█▊        | 65/371 [01:46<08:18,  1.63s/it]
#
#
#
#
#
#
#
#  18%|█▊        | 66/371 [01:48<08:17,  1.63s/it]
#
#
#
#
#
#
#
#  18%|█▊        | 67/371 [01:50<08:15,  1.63s/it]
#
#
#
#
#
#
#
#  18%|█▊        | 68/371 [01:51<08:15,  1.63s/it]
#
#
#
#
#
#
#
#  19%|█▊        | 69/371 [01:53<08:12,  1.63s/it]
#
#
#
#
#
#
#
#  19%|█▉        | 70/371 [01:54<08:10,  1.63s/it]
#
#
#
#
#
#
#
#  19%|█▉        | 71/371 [01:56<08:08,  1.63s/it]
#
#
#
#
#
#
#
#  19%|█▉        | 72/371 [01:58<08:07,  1.63s/it]
#
#
#
#
#
#
#
#  20%|█▉        | 73/371 [01:59<08:05,  1.63s/it]
#
#
#
#
#
#
#
#  20%|█▉        | 74/371 [02:01<08:04,  1.63s/it]
#
#
#
#
#
#
#
#  20%|██        | 75/371 [02:03<08:02,  1.63s/it]
#
#
#
#
#
#
#
#  20%|██        | 76/371 [02:04<08:00,  1.63s/it]
#
#
#
#
#
#
#
#  21%|██        | 77/371 [02:06<07:59,  1.63s/it]
#
#
#
#
#
#
#
#  21%|██        | 78/371 [02:07<07:57,  1.63s/it]
#
#
#
#
#
#
#
#  21%|██▏       | 79/371 [02:09<07:55,  1.63s/it]
#
#
#
#
#
#
#
#  22%|██▏       | 80/371 [02:11<07:54,  1.63s/it]
#
#
#
#
#
#
#
#  22%|██▏       | 81/371 [02:12<07:52,  1.63s/it]
#
#
#
#
#
#
#
#  22%|██▏       | 82/371 [02:14<07:50,  1.63s/it]
#
#
#
#
#
#
#
#  22%|██▏       | 83/371 [02:16<07:49,  1.63s/it]
#
#
#
#
#
#
#
#  23%|██▎       | 84/371 [02:17<07:48,  1.63s/it]
#
#
#
#
#
#
#
#  23%|██▎       | 85/371 [02:19<07:47,  1.63s/it]
#
#
#
#
#
#
#
#  23%|██▎       | 86/371 [02:21<07:45,  1.63s/it]
#
#
#
#
#
#
#
#  23%|██▎       | 87/371 [02:22<07:42,  1.63s/it]
#
#
#
#
#
#
#
#  24%|██▎       | 88/371 [02:24<07:40,  1.63s/it]
#
#
#
#
#
#
#
#  24%|██▍       | 89/371 [02:25<07:39,  1.63s/it]
#
#
#
#
#
#
#
#  24%|██▍       | 90/371 [02:27<07:37,  1.63s/it]
#
#
#
#
#
#
#
#  25%|██▍       | 91/371 [02:29<07:35,  1.63s/it]
#
#
#
#
#
#
#
#  25%|██▍       | 92/371 [02:30<07:33,  1.63s/it]
#
#
#
#
#
#
#
#  25%|██▌       | 93/371 [02:32<07:32,  1.63s/it]
#
#
#
#
#
#
#
#  25%|██▌       | 94/371 [02:34<07:55,  1.72s/it]
#
#
#
#
#
#
#
#  26%|██▌       | 95/371 [02:36<07:53,  1.72s/it]
#
#
#
#
#
#
#
#  26%|██▌       | 96/371 [02:37<08:08,  1.78s/it]
#
#
#
#
#
#
#
#  26%|██▌       | 97/371 [02:39<07:53,  1.73s/it]
#
#
#
#
#
#
#
#  26%|██▋       | 98/371 [02:41<07:42,  1.70s/it]
#
#
#
#
#
#
#
#  27%|██▋       | 99/371 [02:42<07:34,  1.67s/it]
#
#
#
#
#
#
#
#  27%|██▋       | 100/371 [02:44<07:27,  1.65s/it]
#
#
#
#
#
#
#
#  27%|██▋       | 101/371 [02:46<07:23,  1.64s/it]
#  27%|██▋       | 102/371 [02:47<07:19,  1.63s/it]
#
#
#
#
#
#
#
#  28%|██▊       | 103/371 [02:49<07:16,  1.63s/it]
#
#
#
#
#
#
#
#  28%|██▊       | 104/371 [02:50<07:13,  1.62s/it]
#
#
#
#
#
#
#
#  28%|██▊       | 105/371 [02:52<07:11,  1.62s/it]
#
#
#
#
#
#
#
#  29%|██▊       | 106/371 [02:54<07:08,  1.62s/it]
#
#
#
#
#
#
#
#  29%|██▉       | 107/371 [02:55<07:06,  1.62s/it]
#
#
#
#
#
#
#
#  29%|██▉       | 108/371 [02:57<07:04,  1.62s/it]
#
#
#
#
#
#
#
#  29%|██▉       | 109/371 [02:58<07:03,  1.62s/it]
#
#
#
#
#
#
#
#  30%|██▉       | 110/371 [03:00<07:01,  1.61s/it]
#
#
#
#
#
#
#
#  30%|██▉       | 111/371 [03:02<06:59,  1.61s/it]
#
#
#
#
#
#
#
#  30%|███       | 112/371 [03:03<06:58,  1.61s/it]
#
#
#
#
#
#
#
#  30%|███       | 113/371 [03:05<06:57,  1.62s/it]
#
#
#
#
#
#
#
#  31%|███       | 114/371 [03:07<06:56,  1.62s/it]
#
#
#
#
#
#
#
#  31%|███       | 115/371 [03:08<06:54,  1.62s/it]
#
#
#
#
#
#
#
#  31%|███▏      | 116/371 [03:10<06:52,  1.62s/it]
#
#
#
#
#
#
#
#  32%|███▏      | 117/371 [03:11<06:52,  1.62s/it]
#
#
#
#
#
#
#
#  32%|███▏      | 118/371 [03:13<06:50,  1.62s/it]
#
#
#
#
#
#
#
#  32%|███▏      | 119/371 [03:15<06:50,  1.63s/it]
#
#
#
#
#
#
#
#  32%|███▏      | 120/371 [03:16<06:50,  1.63s/it]
#
#
#
#
#
#
#
#  33%|███▎      | 121/371 [03:18<06:47,  1.63s/it]
#
#
#
#
#
#
#
#  33%|███▎      | 122/371 [03:20<06:44,  1.63s/it]
#
#
#
#
#
#
#
#  33%|███▎      | 123/371 [03:21<06:42,  1.62s/it]
#
#
#
#
#
#
#
#  33%|███▎      | 124/371 [03:23<06:40,  1.62s/it]
#
#
#
#
#
#
#
#  34%|███▎      | 125/371 [03:24<06:38,  1.62s/it]
#
#
#
#
#
#
#
#  34%|███▍      | 126/371 [03:26<06:36,  1.62s/it]
#
#
#
#
#
#
#
#  34%|███▍      | 127/371 [03:28<06:35,  1.62s/it]
#
#
#
#
#
#
#
#  35%|███▍      | 128/371 [03:29<06:34,  1.62s/it]
#
#
#
#
#
#
#
#  35%|███▍      | 129/371 [03:31<06:33,  1.62s/it]
#
#
#
#
#
#
#
#  35%|███▌      | 130/371 [03:33<06:31,  1.62s/it]
#
#
#
#
#
#
#
#  35%|███▌      | 131/371 [03:34<06:28,  1.62s/it]
#
#
#
#
#
#
#
#  36%|███▌      | 132/371 [03:36<06:26,  1.62s/it]
#
#
#
#
#
#
#
#  36%|███▌      | 133/371 [03:37<06:25,  1.62s/it]
#
#
#
#
#
#
#
#  36%|███▌      | 134/371 [03:39<06:23,  1.62s/it]
#
#
#
#
#
#
#
#  36%|███▋      | 135/371 [03:41<06:21,  1.62s/it]
#
#
#
#
#
#
#
#  37%|███▋      | 136/371 [03:42<06:20,  1.62s/it]
#
#
#
#
#
#
#
#  37%|███▋      | 137/371 [03:44<06:18,  1.62s/it]
#
#
#
#
#
#
#
#  37%|███▋      | 138/371 [03:45<06:16,  1.62s/it]
#
#
#
#
#
#
#
#  37%|███▋      | 139/371 [03:47<06:14,  1.62s/it]
#
#
#
#
#
#
#
#  38%|███▊      | 140/371 [03:49<06:13,  1.62s/it]
#
#
#
#
#
#
#
#  38%|███▊      | 141/371 [03:50<06:11,  1.62s/it]
#
#
#
#
#
#
#
#  38%|███▊      | 142/371 [03:52<06:09,  1.62s/it]
#
#
#
#
#
#
#
#  39%|███▊      | 143/371 [03:54<06:08,  1.62s/it]
#
#
#
#
#
#
#
#  39%|███▉      | 144/371 [03:55<06:07,  1.62s/it]
#
#
#
#
#
#
#
#  39%|███▉      | 145/371 [03:57<06:05,  1.62s/it]
#
#
#
#
#
#
#
#  39%|███▉      | 146/371 [03:58<06:04,  1.62s/it]
#
#
#
#
#
#
#
#  40%|███▉      | 147/371 [04:00<06:02,  1.62s/it]
#
#
#
#
#
#
#
#  40%|███▉      | 148/371 [04:02<06:00,  1.62s/it]
#
#
#
#
#
#
#
#  40%|████      | 149/371 [04:03<05:58,  1.62s/it]
#
#
#
#
#
#
#
#  40%|████      | 150/371 [04:05<05:57,  1.62s/it]
#
#
#
#
#
#
#
#  41%|████      | 151/371 [04:06<05:56,  1.62s/it]
#
#
#
#
#
#
#
#  41%|████      | 152/371 [04:08<05:54,  1.62s/it]
#
#
#
#
#
#
#
#  41%|████      | 153/371 [04:10<05:52,  1.62s/it]
#
#
#
#
#
#
#
#  42%|████▏     | 154/371 [04:11<05:50,  1.62s/it]
#
#
#
#
#
#
#
#  42%|████▏     | 155/371 [04:13<05:49,  1.62s/it]
#
#
#
#
#
#
#
#  42%|████▏     | 156/371 [04:15<05:47,  1.62s/it]
#
#
#
#
#
#
#
#  42%|████▏     | 157/371 [04:16<05:45,  1.62s/it]
#
#
#
#
#
#
#
#  43%|████▎     | 158/371 [04:18<05:43,  1.61s/it]
#
#
#
#
#
#
#
#  43%|████▎     | 159/371 [04:19<05:42,  1.62s/it]
#
#
#
#
#
#
#
#  43%|████▎     | 160/371 [04:21<05:40,  1.62s/it]
#
#
#
#
#
#
#
#  43%|████▎     | 161/371 [04:23<05:39,  1.62s/it]
#
#
#
#
#
#
#
#  44%|████▎     | 162/371 [04:24<05:37,  1.62s/it]
#
#
#
#
#
#
#
#  44%|████▍     | 163/371 [04:26<05:35,  1.61s/it]
#
#
#
#
#
#
#
#  44%|████▍     | 164/371 [04:27<05:34,  1.61s/it]
#
#
#
#
#
#
#
#  44%|████▍     | 165/371 [04:29<05:33,  1.62s/it]
#
#
#
#
#
#
#
#  45%|████▍     | 166/371 [04:31<05:31,  1.62s/it]
#
#
#
#
#
#
#
#  45%|████▌     | 167/371 [04:32<05:30,  1.62s/it]
#
#
#
#
#
#
#
#  45%|████▌     | 168/371 [04:34<05:29,  1.62s/it]
#
#
#
#
#
#
#
#  46%|████▌     | 169/371 [04:36<05:27,  1.62s/it]
#
#
#
#
#
#
#
#  46%|████▌     | 170/371 [04:37<05:25,  1.62s/it]
#
#
#
#
#
#
#
#  46%|████▌     | 171/371 [04:39<05:24,  1.62s/it]
#
#
#
#
#
#
#
#  46%|████▋     | 172/371 [04:40<05:22,  1.62s/it]
#
#
#
#
#
#
#
#  47%|████▋     | 173/371 [04:42<05:20,  1.62s/it]
#
#
#
#
#
#
#
#  47%|████▋     | 174/371 [04:44<05:18,  1.62s/it]
#
#
#
#
#
#
#
#  47%|████▋     | 175/371 [04:45<05:17,  1.62s/it]
#
#
#
#
#
#
#
#  47%|████▋     | 176/371 [04:47<05:15,  1.62s/it]
#
#
#
#
#
#
#
#  48%|████▊     | 177/371 [04:49<05:13,  1.62s/it]
#
#
#
#
#
#
#
#  48%|████▊     | 178/371 [04:50<05:12,  1.62s/it]
#
#
#
#
#
#
#
#  48%|████▊     | 179/371 [04:52<05:10,  1.62s/it]
#
#
#
#
#
#
#
#  49%|████▊     | 180/371 [04:53<05:08,  1.62s/it]
#
#
#
#
#
#
#
#  49%|████▉     | 181/371 [04:55<05:07,  1.62s/it]
#
#
#
#
#
#
#
#  49%|████▉     | 182/371 [04:57<05:05,  1.62s/it]
#
#
#
#
#
#
#
#  49%|████▉     | 183/371 [04:58<05:04,  1.62s/it]
#
#
#
#
#
#
#
#  50%|████▉     | 184/371 [05:00<05:02,  1.62s/it]
#
#
#
#
#
#
#
#  50%|████▉     | 185/371 [05:01<05:00,  1.62s/it]
#
#
#
#
#
#
#
#  50%|█████     | 186/371 [05:03<04:59,  1.62s/it]
#
#
#
#
#
#
#
#  50%|█████     | 187/371 [05:05<04:58,  1.62s/it]
#
#
#
#
#
#
#
#  51%|█████     | 188/371 [05:06<04:56,  1.62s/it]
#
#
#
#
#
#
#
#  51%|█████     | 189/371 [05:08<04:57,  1.63s/it]
#
#
#
#
#
#
#
#  51%|█████     | 190/371 [05:10<04:55,  1.63s/it]
#
#
#
#
#
#
#
#  51%|█████▏    | 191/371 [05:11<04:53,  1.63s/it]
#
#
#
#
#
#
#
#  52%|█████▏    | 192/371 [05:13<04:51,  1.63s/it]
#
#
#
#
#
#
#
#  52%|█████▏    | 193/371 [05:15<04:48,  1.62s/it]
#
#
#
#
#
#
#
#  52%|█████▏    | 194/371 [05:16<04:47,  1.62s/it]
#
#
#
#
#
#
#
#  53%|█████▎    | 195/371 [05:18<04:45,  1.62s/it]
#
#
#
#
#
#
#
#  53%|█████▎    | 196/371 [05:19<04:43,  1.62s/it]
#
#
#
#
#
#
#
#  53%|█████▎    | 197/371 [05:21<04:42,  1.62s/it]
#
#
#
#
#
#
#
#  53%|█████▎    | 198/371 [05:23<04:40,  1.62s/it]
#
#
#
#
#
#
#
#  54%|█████▎    | 199/371 [05:24<04:38,  1.62s/it]
#
#
#
#
#
#
#
#  54%|█████▍    | 200/371 [05:26<04:36,  1.62s/it]
#
#
#
#
#
#
#
#  54%|█████▍    | 201/371 [05:27<04:35,  1.62s/it]
#
#
#
#
#
#
#
#  54%|█████▍    | 202/371 [05:29<04:33,  1.62s/it]
#  55%|█████▍    | 203/371 [05:31<04:31,  1.62s/it]
#
#
#
#
#
#
#
#  55%|█████▍    | 204/371 [05:32<04:30,  1.62s/it]
#
#
#
#
#
#
#
#  55%|█████▌    | 205/371 [05:34<04:28,  1.62s/it]
#
#
#
#
#
#
#
#  56%|█████▌    | 206/371 [05:36<04:26,  1.62s/it]
#
#
#
#
#
#
#
#  56%|█████▌    | 207/371 [05:37<04:25,  1.62s/it]
#
#
#
#
#
#
#
#  56%|█████▌    | 208/371 [05:39<04:23,  1.62s/it]
#
#
#
#
#
#
#
#  56%|█████▋    | 209/371 [05:40<04:22,  1.62s/it]
#
#
#
#
#
#
#
#  57%|█████▋    | 210/371 [05:42<04:20,  1.62s/it]
#
#
#
#
#
#
#
#  57%|█████▋    | 211/371 [05:44<04:18,  1.62s/it]
#
#
#
#
#
#
#
#  57%|█████▋    | 212/371 [05:45<04:19,  1.63s/it]
#
#
#
#
#
#
#
#  57%|█████▋    | 213/371 [05:47<04:20,  1.65s/it]
#
#
#
#
#
#
#
#  58%|█████▊    | 214/371 [05:49<04:18,  1.64s/it]
#
#
#
#
#
#
#
#  58%|█████▊    | 215/371 [05:50<04:15,  1.64s/it]
#
#
#
#
#
#
#
#  58%|█████▊    | 216/371 [05:52<04:13,  1.63s/it]
#
#
#
#
#
#
#
#  58%|█████▊    | 217/371 [05:53<04:11,  1.63s/it]
#
#
#
#
#
#
#
#  59%|█████▉    | 218/371 [05:55<04:08,  1.63s/it]
#
#
#
#
#
#
#
#  59%|█████▉    | 219/371 [05:57<04:06,  1.62s/it]
#
#
#
#
#
#
#
#  59%|█████▉    | 220/371 [05:58<04:04,  1.62s/it]
#
#
#
#
#
#
#
#  60%|█████▉    | 221/371 [06:00<04:02,  1.62s/it]
#
#
#
#
#
#
#
#  60%|█████▉    | 222/371 [06:02<04:00,  1.62s/it]
#
#
#
#
#
#
#
#  60%|██████    | 223/371 [06:03<03:58,  1.61s/it]
#
#
#
#
#
#
#
#  60%|██████    | 224/371 [06:05<03:57,  1.61s/it]
#
#
#
#
#
#
#
#  61%|██████    | 225/371 [06:06<03:55,  1.62s/it]
#
#
#
#
#
#
#
#  61%|██████    | 226/371 [06:08<03:54,  1.62s/it]
#
#
#
#
#
#
#
#  61%|██████    | 227/371 [06:10<03:52,  1.62s/it]
#
#
#
#
#
#
#
#  61%|██████▏   | 228/371 [06:11<03:51,  1.62s/it]
#
#
#
#
#
#
#
#  62%|██████▏   | 229/371 [06:13<03:51,  1.63s/it]
#
#
#
#
#
#
#
#  62%|██████▏   | 230/371 [06:15<03:49,  1.63s/it]
#
#
#
#
#
#
#
#  62%|██████▏   | 231/371 [06:16<03:47,  1.62s/it]
#
#
#
#
#
#
#
#  63%|██████▎   | 232/371 [06:18<03:45,  1.62s/it]
#
#
#
#
#
#
#
#  63%|██████▎   | 233/371 [06:19<03:43,  1.62s/it]
#
#
#
#
#
#
#
#  63%|██████▎   | 234/371 [06:21<03:41,  1.62s/it]
#
#
#
#
#
#
#
#  63%|██████▎   | 235/371 [06:23<03:40,  1.62s/it]
#
#
#
#
#
#
#
#  64%|██████▎   | 236/371 [06:24<03:38,  1.62s/it]
#
#
#
#
#
#
#
#  64%|██████▍   | 237/371 [06:26<03:36,  1.62s/it]
#
#
#
#
#
#
#
#  64%|██████▍   | 238/371 [06:27<03:35,  1.62s/it]
#
#
#
#
#
#
#
#  64%|██████▍   | 239/371 [06:29<03:34,  1.62s/it]
#
#
#
#
#
#
#
#  65%|██████▍   | 240/371 [06:31<03:32,  1.62s/it]
#
#
#
#
#
#
#
#  65%|██████▍   | 241/371 [06:32<03:31,  1.62s/it]
#
#
#
#
#
#
#
#  65%|██████▌   | 242/371 [06:34<03:29,  1.62s/it]
#
#
#
#
#
#
#
#  65%|██████▌   | 243/371 [06:36<03:27,  1.62s/it]
#
#
#
#
#
#
#
#  66%|██████▌   | 244/371 [06:38<03:40,  1.73s/it]
#
#
#
#
#
#
#
#  66%|██████▌   | 245/371 [06:39<03:37,  1.72s/it]
#
#
#
#
#
#
#
#  66%|██████▋   | 246/371 [06:41<03:32,  1.70s/it]
#
#
#
#
#
#
#
#  67%|██████▋   | 247/371 [06:43<03:28,  1.68s/it]
#
#
#
#
#
#
#
#  67%|██████▋   | 248/371 [06:44<03:25,  1.67s/it]
#
#
#
#
#
#
#
#  67%|██████▋   | 249/371 [06:46<03:21,  1.66s/it]
#
#
#
#
#
#
#
#  67%|██████▋   | 250/371 [06:47<03:19,  1.65s/it]
#
#
#
#
#
#
#
#  68%|██████▊   | 251/371 [06:49<03:16,  1.64s/it]
#
#
#
#
#
#
#
#  68%|██████▊   | 252/371 [06:51<03:14,  1.63s/it]
#
#
#
#
#
#
#
#  68%|██████▊   | 253/371 [06:52<03:12,  1.63s/it]
#
#
#
#
#
#
#
#  68%|██████▊   | 254/371 [06:54<03:10,  1.63s/it]
#
#
#
#
#
#
#
#  69%|██████▊   | 255/371 [06:56<03:08,  1.63s/it]
#
#
#
#
#
#
#
#  69%|██████▉   | 256/371 [06:57<03:06,  1.62s/it]
#
#
#
#
#
#
#
#  69%|██████▉   | 257/371 [06:59<03:04,  1.62s/it]
#
#
#
#
#
#
#
#  70%|██████▉   | 258/371 [07:00<03:03,  1.62s/it]
#
#
#
#
#
#
#
#  70%|██████▉   | 259/371 [07:02<03:01,  1.62s/it]
#
#
#
#
#
#
#
#  70%|███████   | 260/371 [07:04<02:59,  1.62s/it]
#
#
#
#
#
#
#
#  70%|███████   | 261/371 [07:05<02:58,  1.62s/it]
#
#
#
#
#
#
#
#  71%|███████   | 262/371 [07:07<02:56,  1.62s/it]
#
#
#
#
#
#
#
#  71%|███████   | 263/371 [07:09<02:54,  1.62s/it]
#
#
#
#
#
#
#
#  71%|███████   | 264/371 [07:11<03:05,  1.73s/it]
#
#
#
#
#
#
#
#  71%|███████▏  | 265/371 [07:12<03:01,  1.71s/it]
#
#
#
#
#
#
#
#  72%|███████▏  | 266/371 [07:14<02:57,  1.69s/it]
#
#
#
#
#
#
#
#  72%|███████▏  | 267/371 [07:15<02:53,  1.67s/it]
#
#
#
#
#
#
#
#  72%|███████▏  | 268/371 [07:17<02:51,  1.66s/it]
#
#
#
#
#
#
#
#  73%|███████▎  | 269/371 [07:19<02:48,  1.65s/it]
#
#
#
#
#
#
#
#  73%|███████▎  | 270/371 [07:20<02:46,  1.64s/it]
#
#
#
#
#
#
#
#  73%|███████▎  | 271/371 [07:22<02:43,  1.64s/it]
#
#
#
#
#
#
#
#  73%|███████▎  | 272/371 [07:24<02:42,  1.64s/it]
#
#
#
#
#
#
#
#  74%|███████▎  | 273/371 [07:25<02:41,  1.65s/it]
#
#
#
#
#
#
#
#  74%|███████▍  | 274/371 [07:27<02:40,  1.65s/it]
#
#
#
#
#
#
#
#  74%|███████▍  | 275/371 [07:29<02:38,  1.65s/it]
#
#
#
#
#
#
#
#  74%|███████▍  | 276/371 [07:30<02:35,  1.64s/it]
#
#
#
#
#
#
#
#  75%|███████▍  | 277/371 [07:32<02:34,  1.64s/it]
#
#
#
#
#
#
#
#  75%|███████▍  | 278/371 [07:33<02:32,  1.64s/it]
#
#
#
#
#
#
#
#  75%|███████▌  | 279/371 [07:35<02:30,  1.64s/it]
#
#
#
#
#
#
#
#  75%|███████▌  | 280/371 [07:37<02:29,  1.64s/it]
#
#
#
#
#
#
#
#  76%|███████▌  | 281/371 [07:38<02:27,  1.63s/it]
#
#
#
#
#
#
#
#  76%|███████▌  | 282/371 [07:40<02:25,  1.63s/it]
#
#
#
#
#
#
#
#  76%|███████▋  | 283/371 [07:42<02:23,  1.63s/it]
#
#
#
#
#
#
#
#  77%|███████▋  | 284/371 [07:43<02:22,  1.63s/it]
#
#
#
#
#
#
#
#  77%|███████▋  | 285/371 [07:45<02:20,  1.64s/it]
#
#
#
#
#
#
#
#  77%|███████▋  | 286/371 [07:47<02:18,  1.63s/it]
#
#
#
#
#
#
#
#  77%|███████▋  | 287/371 [07:48<02:17,  1.63s/it]
#
#
#
#
#
#
#
#  78%|███████▊  | 288/371 [07:50<02:15,  1.63s/it]
#
#
#
#
#
#
#
#  78%|███████▊  | 289/371 [07:51<02:13,  1.63s/it]
#
#
#
#
#
#
#
#  78%|███████▊  | 290/371 [07:53<02:12,  1.63s/it]
#
#
#
#
#
#
#
#  78%|███████▊  | 291/371 [07:55<02:10,  1.63s/it]
#
#
#
#
#
#
#
#  79%|███████▊  | 292/371 [07:56<02:08,  1.63s/it]
#
#
#
#
#
#
#
#  79%|███████▉  | 293/371 [07:58<02:06,  1.63s/it]
#
#
#
#
#
#
#
#  79%|███████▉  | 294/371 [08:00<02:05,  1.63s/it]
#
#
#
#
#
#
#
#  80%|███████▉  | 295/371 [08:01<02:03,  1.63s/it]
#
#
#
#
#
#
#
#  80%|███████▉  | 296/371 [08:03<02:02,  1.63s/it]
#
#
#
#
#
#
#
#  80%|████████  | 297/371 [08:04<02:00,  1.63s/it]
#
#
#
#
#
#
#
#  80%|████████  | 298/371 [08:06<01:58,  1.63s/it]
#
#
#
#
#
#
#
#  81%|████████  | 299/371 [08:08<01:57,  1.63s/it]
#
#
#
#
#
#
#
#  81%|████████  | 300/371 [08:09<01:55,  1.63s/it]
#
#
#
#
#
#
#
#  81%|████████  | 301/371 [08:11<01:54,  1.63s/it]
#
#
#
#
#
#
#
#  81%|████████▏ | 302/371 [08:13<01:52,  1.63s/it]
#
#
#
#
#
#
#
#  82%|████████▏ | 303/371 [08:14<01:50,  1.63s/it]
#  82%|████████▏ | 304/371 [08:16<01:49,  1.63s/it]
#
#
#
#
#
#
#
#  82%|████████▏ | 305/371 [08:18<01:47,  1.63s/it]
#
#
#
#
#
#
#
#  82%|████████▏ | 306/371 [08:19<01:46,  1.63s/it]
#
#
#
#
#
#
#
#  83%|████████▎ | 307/371 [08:21<01:44,  1.63s/it]
#
#
#
#
#
#
#
#  83%|████████▎ | 308/371 [08:22<01:43,  1.64s/it]
#
#
#
#
#
#
#
#  83%|████████▎ | 309/371 [08:24<01:41,  1.64s/it]
#
#
#
#
#
#
#
#  84%|████████▎ | 310/371 [08:26<01:39,  1.64s/it]
#
#
#
#
#
#
#
#  84%|████████▍ | 311/371 [08:27<01:38,  1.64s/it]
#
#
#
#
#
#
#
#  84%|████████▍ | 312/371 [08:29<01:36,  1.64s/it]
#
#
#
#
#
#
#
#  84%|████████▍ | 313/371 [08:31<01:34,  1.63s/it]
#
#
#
#
#
#
#
#  85%|████████▍ | 314/371 [08:32<01:33,  1.63s/it]
#
#
#
#
#
#
#
#  85%|████████▍ | 315/371 [08:34<01:31,  1.64s/it]
#
#
#
#
#
#
#
#  85%|████████▌ | 316/371 [08:36<01:29,  1.63s/it]
#
#
#
#
#
#
#
#  85%|████████▌ | 317/371 [08:37<01:28,  1.63s/it]
#
#
#
#
#
#
#
#  86%|████████▌ | 318/371 [08:39<01:26,  1.63s/it]
#
#
#
#
#
#
#
#  86%|████████▌ | 319/371 [08:40<01:24,  1.63s/it]
#
#
#
#
#
#
#
#  86%|████████▋ | 320/371 [08:42<01:22,  1.63s/it]
#
#
#
#
#
#
#
#  87%|████████▋ | 321/371 [08:44<01:21,  1.63s/it]
#
#
#
#
#
#
#
#  87%|████████▋ | 322/371 [08:45<01:19,  1.63s/it]
#
#
#
#
#
#
#
#  87%|████████▋ | 323/371 [08:47<01:17,  1.62s/it]
#
#
#
#
#
#
#
#  87%|████████▋ | 324/371 [08:48<01:16,  1.62s/it]
#
#
#
#
#
#
#
#  88%|████████▊ | 325/371 [08:50<01:14,  1.62s/it]
#
#
#
#
#
#
#
#  88%|████████▊ | 326/371 [08:52<01:13,  1.63s/it]
#
#
#
#
#
#
#
#  88%|████████▊ | 327/371 [08:53<01:11,  1.63s/it]
#
#
#
#
#
#
#
#  88%|████████▊ | 328/371 [08:55<01:09,  1.63s/it]
#
#
#
#
#
#
#
#  89%|████████▊ | 329/371 [08:57<01:08,  1.63s/it]
#
#
#
#
#
#
#
#  89%|████████▉ | 330/371 [08:58<01:06,  1.63s/it]
#
#
#
#
#
#
#
#  89%|████████▉ | 331/371 [09:00<01:05,  1.63s/it]
#
#
#
#
#
#
#
#  89%|████████▉ | 332/371 [09:02<01:03,  1.63s/it]
#
#
#
#
#
#
#
#  90%|████████▉ | 333/371 [09:03<01:02,  1.63s/it]
#
#
#
#
#
#
#
#  90%|█████████ | 334/371 [09:05<01:00,  1.63s/it]
#
#
#
#
#
#
#
#  90%|█████████ | 335/371 [09:06<00:58,  1.63s/it]
#
#
#
#
#
#
#
#  91%|█████████ | 336/371 [09:08<00:57,  1.63s/it]
#
#
#
#
#
#
#
#  91%|█████████ | 337/371 [09:10<00:55,  1.63s/it]
#
#
#
#
#
#
#
#  91%|█████████ | 338/371 [09:11<00:53,  1.63s/it]
#
#
#
#
#
#
#
#  91%|█████████▏| 339/371 [09:13<00:52,  1.63s/it]
#
#
#
#
#
#
#
#  92%|█████████▏| 340/371 [09:15<00:50,  1.63s/it]
#
#
#
#
#
#
#
#  92%|█████████▏| 341/371 [09:16<00:48,  1.63s/it]
#
#
#
#
#
#
#
#  92%|█████████▏| 342/371 [09:18<00:47,  1.62s/it]
#
#
#
#
#
#
#
#  92%|█████████▏| 343/371 [09:19<00:45,  1.63s/it]
#
#
#
#
#
#
#
#  93%|█████████▎| 344/371 [09:21<00:43,  1.63s/it]
#
#
#
#
#
#
#
#  93%|█████████▎| 345/371 [09:23<00:42,  1.63s/it]
#
#
#
#
#
#
#
#  93%|█████████▎| 346/371 [09:24<00:40,  1.63s/it]
#
#
#
#
#
#
#
#  94%|█████████▎| 347/371 [09:26<00:39,  1.63s/it]
#
#
#
#
#
#
#
#  94%|█████████▍| 348/371 [09:28<00:37,  1.63s/it]
#
#
#
#
#
#
#
#  94%|█████████▍| 349/371 [09:29<00:35,  1.63s/it]
#
#
#
#
#
#
#
#  94%|█████████▍| 350/371 [09:31<00:34,  1.63s/it]
#
#
#
#
#
#
#
#  95%|█████████▍| 351/371 [09:33<00:32,  1.63s/it]
#
#
#
#
#
#
#
#  95%|█████████▍| 352/371 [09:34<00:31,  1.64s/it]
#
#
#
#
#
#
#
#  95%|█████████▌| 353/371 [09:36<00:29,  1.64s/it]
#
#
#
#
#
#
#
#  95%|█████████▌| 354/371 [09:37<00:27,  1.63s/it]
#
#
#
#
#
#
#
#  96%|█████████▌| 355/371 [09:39<00:26,  1.63s/it]
#
#
#
#
#
#
#
#  96%|█████████▌| 356/371 [09:41<00:24,  1.63s/it]
#
#
#
#
#
#
#
#  96%|█████████▌| 357/371 [09:42<00:22,  1.63s/it]
#
#
#
#
#
#
#
#  96%|█████████▋| 358/371 [09:44<00:21,  1.63s/it]
#
#
#
#
#
#
#
#  97%|█████████▋| 359/371 [09:46<00:19,  1.63s/it]
#
#
#
#
#
#
#
#  97%|█████████▋| 360/371 [09:47<00:17,  1.63s/it]
#
#
#
#
#
#
#
#  97%|█████████▋| 361/371 [09:49<00:16,  1.63s/it]
#
#
#
#
#
#
#
#  98%|█████████▊| 362/371 [09:50<00:14,  1.63s/it]
#
#
#
#
#
#
#
#  98%|█████████▊| 363/371 [09:52<00:13,  1.63s/it]
#
#
#
#
#
#
#
#  98%|█████████▊| 364/371 [09:54<00:11,  1.63s/it]
#
#
#
#
#
#
#
#  98%|█████████▊| 365/371 [09:55<00:09,  1.63s/it]
#
#
#
#
#
#
#
#  99%|█████████▊| 366/371 [09:57<00:08,  1.63s/it]
#
#
#
#
#
#
#
#  99%|█████████▉| 367/371 [09:59<00:06,  1.63s/it]
#
#
#
#
#
#
#
#  99%|█████████▉| 368/371 [10:00<00:04,  1.63s/it]
#
#
#
#
#
#
#
#  99%|█████████▉| 369/371 [10:02<00:03,  1.63s/it]
#
#
#
#
#
#
#
# 100%|█████████▉| 370/371 [10:03<00:01,  1.63s/it]
#
#
#
#
#
#
#
# 100%|██████████| 371/371 [10:05<00:00,  1.63s/it]

# %%
len(preds)
# Out:
# 371

# %%
preds = []
for _, row in tqdm(ibm_partition_df.iterrows(), total=len(ibm_partition_df)):
    preds.append(predict_with_tfidf_window(row))
    
ibm_partition_df['tfidf_window prediction'] = preds
# Out:
#   0%|          | 0/194 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#   1%|          | 1/194 [00:01<05:16,  1.64s/it]
#
#
#
#
#
#
#
#   1%|          | 2/194 [00:03<05:14,  1.64s/it]
#
#
#
#
#
#
#
#   2%|▏         | 3/194 [00:04<05:12,  1.64s/it]
#
#
#
#
#
#
#
#   2%|▏         | 4/194 [00:06<05:10,  1.63s/it]
#
#
#
#
#
#
#
#   3%|▎         | 5/194 [00:08<05:08,  1.63s/it]
#
#
#
#
#
#
#
#   3%|▎         | 6/194 [00:09<05:07,  1.63s/it]
#
#
#
#
#
#
#
#   4%|▎         | 7/194 [00:11<05:05,  1.63s/it]
#
#
#
#
#
#
#
#   4%|▍         | 8/194 [00:13<05:03,  1.63s/it]
#
#
#
#
#
#
#
#   5%|▍         | 9/194 [00:14<05:01,  1.63s/it]
#
#
#
#
#
#
#
#   5%|▌         | 10/194 [00:16<05:00,  1.63s/it]
#
#
#
#
#
#
#
#   6%|▌         | 11/194 [00:17<04:58,  1.63s/it]
#
#
#
#
#
#
#
#   6%|▌         | 12/194 [00:19<04:57,  1.63s/it]
#
#
#
#
#
#
#
#   7%|▋         | 13/194 [00:21<04:55,  1.63s/it]
#
#
#
#
#
#
#
#   7%|▋         | 14/194 [00:22<04:54,  1.64s/it]
#
#
#
#
#
#
#
#   8%|▊         | 15/194 [00:24<04:52,  1.64s/it]
#
#
#
#
#
#
#
#   8%|▊         | 16/194 [00:26<04:51,  1.64s/it]
#
#
#
#
#
#
#
#   9%|▉         | 17/194 [00:27<04:49,  1.64s/it]
#
#
#
#
#
#
#
#   9%|▉         | 18/194 [00:29<04:48,  1.64s/it]
#
#
#
#
#
#
#
#  10%|▉         | 19/194 [00:31<04:46,  1.64s/it]
#
#
#
#
#
#
#
#  10%|█         | 20/194 [00:32<04:44,  1.64s/it]
#
#
#
#
#
#
#
#  11%|█         | 21/194 [00:34<04:43,  1.64s/it]
#
#
#
#
#
#
#
#  11%|█▏        | 22/194 [00:35<04:41,  1.64s/it]
#
#
#
#
#
#
#
#  12%|█▏        | 23/194 [00:37<04:40,  1.64s/it]
#
#
#
#
#
#
#
#  12%|█▏        | 24/194 [00:39<04:38,  1.64s/it]
#
#
#
#
#
#
#
#  13%|█▎        | 25/194 [00:40<04:36,  1.64s/it]
#
#
#
#
#
#
#
#  13%|█▎        | 26/194 [00:42<04:35,  1.64s/it]
#
#
#
#
#
#
#
#  14%|█▍        | 27/194 [00:44<04:33,  1.64s/it]
#
#
#
#
#
#
#
#  14%|█▍        | 28/194 [00:45<04:32,  1.64s/it]
#
#
#
#
#
#
#
#  15%|█▍        | 29/194 [00:47<04:30,  1.64s/it]
#
#
#
#
#
#
#
#  15%|█▌        | 30/194 [00:49<04:28,  1.64s/it]
#
#
#
#
#
#
#
#  16%|█▌        | 31/194 [00:50<04:27,  1.64s/it]
#
#
#
#
#
#
#
#  16%|█▋        | 32/194 [00:52<04:25,  1.64s/it]
#
#
#
#
#
#
#
#  17%|█▋        | 33/194 [00:53<04:23,  1.64s/it]
#
#
#
#
#
#
#
#  18%|█▊        | 34/194 [00:55<04:21,  1.64s/it]
#
#
#
#
#
#
#
#  18%|█▊        | 35/194 [00:57<04:20,  1.64s/it]
#
#
#
#
#
#
#
#  19%|█▊        | 36/194 [00:58<04:19,  1.64s/it]
#
#
#
#
#
#
#
#  19%|█▉        | 37/194 [01:00<04:17,  1.64s/it]
#
#
#
#
#
#
#
#  20%|█▉        | 38/194 [01:02<04:15,  1.64s/it]
#
#
#
#
#
#
#
#  20%|██        | 39/194 [01:03<04:13,  1.64s/it]
#
#
#
#
#
#
#
#  21%|██        | 40/194 [01:05<04:12,  1.64s/it]
#
#
#
#
#
#
#
#  21%|██        | 41/194 [01:07<04:10,  1.64s/it]
#
#
#
#
#
#
#
#  22%|██▏       | 42/194 [01:08<04:08,  1.64s/it]
#
#
#
#
#
#
#
#  22%|██▏       | 43/194 [01:10<04:07,  1.64s/it]
#
#
#
#
#
#
#
#  23%|██▎       | 44/194 [01:12<04:06,  1.64s/it]
#
#
#
#
#
#
#
#  23%|██▎       | 45/194 [01:13<04:04,  1.64s/it]
#
#
#
#
#
#
#
#  24%|██▎       | 46/194 [01:15<04:02,  1.64s/it]
#
#
#
#
#
#
#
#  24%|██▍       | 47/194 [01:16<04:01,  1.64s/it]
#
#
#
#
#
#
#
#  25%|██▍       | 48/194 [01:18<03:59,  1.64s/it]
#
#
#
#
#
#
#
#  25%|██▌       | 49/194 [01:20<03:58,  1.64s/it]
#
#
#
#
#
#
#
#  26%|██▌       | 50/194 [01:21<03:56,  1.64s/it]
#
#
#
#
#
#
#
#  26%|██▋       | 51/194 [01:23<03:55,  1.64s/it]
#
#
#
#
#
#
#
#  27%|██▋       | 52/194 [01:25<03:53,  1.64s/it]
#
#
#
#
#
#
#
#  27%|██▋       | 53/194 [01:26<03:51,  1.64s/it]
#
#
#
#
#
#
#
#  28%|██▊       | 54/194 [01:28<03:50,  1.65s/it]
#
#
#
#
#
#
#
#  28%|██▊       | 55/194 [01:30<03:48,  1.64s/it]
#
#
#
#
#
#
#
#  29%|██▉       | 56/194 [01:31<03:46,  1.64s/it]
#
#
#
#
#
#
#
#  29%|██▉       | 57/194 [01:33<03:45,  1.64s/it]
#
#
#
#
#
#
#
#  30%|██▉       | 58/194 [01:35<03:44,  1.65s/it]
#
#
#
#
#
#
#
#  30%|███       | 59/194 [01:36<03:42,  1.65s/it]
#
#
#
#
#
#
#
#  31%|███       | 60/194 [01:38<03:40,  1.65s/it]
#
#
#
#
#
#
#
#  31%|███▏      | 61/194 [01:39<03:38,  1.65s/it]
#
#
#
#
#
#
#
#  32%|███▏      | 62/194 [01:41<03:37,  1.65s/it]
#
#
#
#
#
#
#
#  32%|███▏      | 63/194 [01:43<03:35,  1.65s/it]
#
#
#
#
#
#
#
#  33%|███▎      | 64/194 [01:44<03:34,  1.65s/it]
#
#
#
#
#
#
#
#  34%|███▎      | 65/194 [01:46<03:32,  1.65s/it]
#
#
#
#
#
#
#
#  34%|███▍      | 66/194 [01:48<03:30,  1.65s/it]
#
#
#
#
#
#
#
#  35%|███▍      | 67/194 [01:49<03:28,  1.64s/it]
#
#
#
#
#
#
#
#  35%|███▌      | 68/194 [01:51<03:26,  1.64s/it]
#
#
#
#
#
#
#
#  36%|███▌      | 69/194 [01:53<03:24,  1.64s/it]
#
#
#
#
#
#
#
#  36%|███▌      | 70/194 [01:54<03:23,  1.64s/it]
#
#
#
#
#
#
#
#  37%|███▋      | 71/194 [01:56<03:22,  1.64s/it]
#
#
#
#
#
#
#
#  37%|███▋      | 72/194 [01:58<03:21,  1.65s/it]
#
#
#
#
#
#
#
#  38%|███▊      | 73/194 [01:59<03:19,  1.65s/it]
#
#
#
#
#
#
#
#  38%|███▊      | 74/194 [02:01<03:18,  1.65s/it]
#
#
#
#
#
#
#
#  39%|███▊      | 75/194 [02:03<03:16,  1.65s/it]
#
#
#
#
#
#
#
#  39%|███▉      | 76/194 [02:04<03:14,  1.65s/it]
#
#
#
#
#
#
#
#  40%|███▉      | 77/194 [02:06<03:13,  1.65s/it]
#
#
#
#
#
#
#
#  40%|████      | 78/194 [02:07<03:11,  1.65s/it]
#
#
#
#
#
#
#
#  41%|████      | 79/194 [02:09<03:09,  1.65s/it]
#
#
#
#
#
#
#
#  41%|████      | 80/194 [02:11<03:08,  1.65s/it]
#
#
#
#
#
#
#
#  42%|████▏     | 81/194 [02:12<03:06,  1.65s/it]
#
#
#
#
#
#
#
#  42%|████▏     | 82/194 [02:14<03:04,  1.65s/it]
#
#
#
#
#
#
#
#  43%|████▎     | 83/194 [02:16<03:03,  1.65s/it]
#
#
#
#
#
#
#
#  43%|████▎     | 84/194 [02:17<03:01,  1.65s/it]
#
#
#
#
#
#
#
#  44%|████▍     | 85/194 [02:19<03:00,  1.65s/it]
#
#
#
#
#
#
#
#  44%|████▍     | 86/194 [02:21<02:58,  1.65s/it]
#
#
#
#
#
#
#
#  45%|████▍     | 87/194 [02:22<02:56,  1.65s/it]
#
#
#
#
#
#
#
#  45%|████▌     | 88/194 [02:24<02:55,  1.65s/it]
#
#
#
#
#
#
#
#  46%|████▌     | 89/194 [02:26<02:53,  1.65s/it]
#
#
#
#
#
#
#
#  46%|████▋     | 90/194 [02:27<02:51,  1.65s/it]
#
#
#
#
#
#
#
#  47%|████▋     | 91/194 [02:29<02:50,  1.65s/it]
#
#
#
#
#
#
#
#  47%|████▋     | 92/194 [02:31<02:48,  1.65s/it]
#
#
#
#
#
#
#
#  48%|████▊     | 93/194 [02:32<02:46,  1.65s/it]
#
#
#
#
#
#
#
#  48%|████▊     | 94/194 [02:34<02:45,  1.65s/it]
#
#
#
#
#
#
#
#  49%|████▉     | 95/194 [02:36<02:43,  1.65s/it]
#
#
#
#
#
#
#
#  49%|████▉     | 96/194 [02:37<02:42,  1.65s/it]
#
#
#
#
#
#
#
#  50%|█████     | 97/194 [02:39<02:40,  1.65s/it]
#
#
#
#
#
#
#
#  51%|█████     | 98/194 [02:41<02:38,  1.65s/it]
#
#
#
#
#
#
#
#  51%|█████     | 99/194 [02:42<02:37,  1.66s/it]
#
#
#
#
#
#
#
#  52%|█████▏    | 100/194 [02:44<02:35,  1.66s/it]
#
#
#
#
#
#
#
#  52%|█████▏    | 101/194 [02:46<02:33,  1.66s/it]
#  53%|█████▎    | 102/194 [02:47<02:32,  1.65s/it]
#
#
#
#
#
#
#
#  53%|█████▎    | 103/194 [02:49<02:30,  1.65s/it]
#
#
#
#
#
#
#
#  54%|█████▎    | 104/194 [02:50<02:28,  1.65s/it]
#
#
#
#
#
#
#
#  54%|█████▍    | 105/194 [02:52<02:27,  1.65s/it]
#
#
#
#
#
#
#
#  55%|█████▍    | 106/194 [02:54<02:25,  1.65s/it]
#
#
#
#
#
#
#
#  55%|█████▌    | 107/194 [02:55<02:23,  1.65s/it]
#
#
#
#
#
#
#
#  56%|█████▌    | 108/194 [02:57<02:21,  1.65s/it]
#
#
#
#
#
#
#
#  56%|█████▌    | 109/194 [02:59<02:20,  1.65s/it]
#
#
#
#
#
#
#
#  57%|█████▋    | 110/194 [03:00<02:18,  1.65s/it]
#
#
#
#
#
#
#
#  57%|█████▋    | 111/194 [03:02<02:16,  1.65s/it]
#
#
#
#
#
#
#
#  58%|█████▊    | 112/194 [03:04<02:15,  1.65s/it]
#
#
#
#
#
#
#
#  58%|█████▊    | 113/194 [03:05<02:13,  1.65s/it]
#
#
#
#
#
#
#
#  59%|█████▉    | 114/194 [03:07<02:11,  1.65s/it]
#
#
#
#
#
#
#
#  59%|█████▉    | 115/194 [03:09<02:10,  1.65s/it]
#
#
#
#
#
#
#
#  60%|█████▉    | 116/194 [03:10<02:08,  1.65s/it]
#
#
#
#
#
#
#
#  60%|██████    | 117/194 [03:12<02:07,  1.66s/it]
#
#
#
#
#
#
#
#  61%|██████    | 118/194 [03:14<02:05,  1.66s/it]
#
#
#
#
#
#
#
#  61%|██████▏   | 119/194 [03:15<02:04,  1.66s/it]
#
#
#
#
#
#
#
#  62%|██████▏   | 120/194 [03:17<02:02,  1.65s/it]
#
#
#
#
#
#
#
#  62%|██████▏   | 121/194 [03:19<02:00,  1.65s/it]
#
#
#
#
#
#
#
#  63%|██████▎   | 122/194 [03:20<01:58,  1.65s/it]
#
#
#
#
#
#
#
#  63%|██████▎   | 123/194 [03:22<01:57,  1.65s/it]
#
#
#
#
#
#
#
#  64%|██████▍   | 124/194 [03:23<01:55,  1.65s/it]
#
#
#
#
#
#
#
#  64%|██████▍   | 125/194 [03:25<01:53,  1.65s/it]
#
#
#
#
#
#
#
#  65%|██████▍   | 126/194 [03:27<01:52,  1.65s/it]
#
#
#
#
#
#
#
#  65%|██████▌   | 127/194 [03:28<01:50,  1.65s/it]
#
#
#
#
#
#
#
#  66%|██████▌   | 128/194 [03:30<01:48,  1.65s/it]
#
#
#
#
#
#
#
#  66%|██████▋   | 129/194 [03:32<01:47,  1.65s/it]
#
#
#
#
#
#
#
#  67%|██████▋   | 130/194 [03:33<01:45,  1.65s/it]
#
#
#
#
#
#
#
#  68%|██████▊   | 131/194 [03:35<01:43,  1.65s/it]
#
#
#
#
#
#
#
#  68%|██████▊   | 132/194 [03:37<01:42,  1.65s/it]
#
#
#
#
#
#
#
#  69%|██████▊   | 133/194 [03:38<01:40,  1.65s/it]
#
#
#
#
#
#
#
#  69%|██████▉   | 134/194 [03:40<01:38,  1.65s/it]
#
#
#
#
#
#
#
#  70%|██████▉   | 135/194 [03:42<01:37,  1.65s/it]
#
#
#
#
#
#
#
#  70%|███████   | 136/194 [03:43<01:35,  1.65s/it]
#
#
#
#
#
#
#
#  71%|███████   | 137/194 [03:45<01:34,  1.65s/it]
#
#
#
#
#
#
#
#  71%|███████   | 138/194 [03:47<01:32,  1.65s/it]
#
#
#
#
#
#
#
#  72%|███████▏  | 139/194 [03:48<01:30,  1.65s/it]
#
#
#
#
#
#
#
#  72%|███████▏  | 140/194 [03:50<01:29,  1.65s/it]
#
#
#
#
#
#
#
#  73%|███████▎  | 141/194 [03:52<01:27,  1.65s/it]
#
#
#
#
#
#
#
#  73%|███████▎  | 142/194 [03:53<01:25,  1.65s/it]
#
#
#
#
#
#
#
#  74%|███████▎  | 143/194 [03:55<01:23,  1.65s/it]
#
#
#
#
#
#
#
#  74%|███████▍  | 144/194 [03:56<01:22,  1.65s/it]
#
#
#
#
#
#
#
#  75%|███████▍  | 145/194 [03:58<01:20,  1.65s/it]
#
#
#
#
#
#
#
#  75%|███████▌  | 146/194 [04:00<01:19,  1.65s/it]
#
#
#
#
#
#
#
#  76%|███████▌  | 147/194 [04:01<01:17,  1.65s/it]
#
#
#
#
#
#
#
#  76%|███████▋  | 148/194 [04:03<01:15,  1.65s/it]
#
#
#
#
#
#
#
#  77%|███████▋  | 149/194 [04:05<01:14,  1.65s/it]
#
#
#
#
#
#
#
#  77%|███████▋  | 150/194 [04:06<01:12,  1.65s/it]
#
#
#
#
#
#
#
#  78%|███████▊  | 151/194 [04:08<01:10,  1.64s/it]
#
#
#
#
#
#
#
#  78%|███████▊  | 152/194 [04:10<01:09,  1.65s/it]
#
#
#
#
#
#
#
#  79%|███████▉  | 153/194 [04:11<01:07,  1.65s/it]
#
#
#
#
#
#
#
#  79%|███████▉  | 154/194 [04:13<01:05,  1.65s/it]
#
#
#
#
#
#
#
#  80%|███████▉  | 155/194 [04:15<01:04,  1.65s/it]

# %%
partition_df

# %%
partition_df.to_csv('2016_June_partition_prediction.csv')
ibm_partition_df.to_csv('2016_June_ibm_partition_prediction.csv')
