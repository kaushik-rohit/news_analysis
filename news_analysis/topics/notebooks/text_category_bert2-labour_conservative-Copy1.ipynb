# %%
from simpletransformers.classification import ClassificationModel, ClassificationArgs
from transformers import DistilBertTokenizerFast
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
import pandas as pd
import logging

# %%
logging.basicConfig(level=logging.INFO)
transformers_logger = logging.getLogger("transformers")
transformers_logger.setLevel(logging.WARNING)

# %%
vote_file = pd.read_csv('brexit_full_updated3.csv')
vote_file
# Out:
#     Constituency ID        full name  PANO          Constituency Name  \
# 0         E14000530   Gerald Howarth     7                  Aldershot
# 1         E14000531     Wendy Morton     8        Aldridge-Brownhills
# 2         E14000532     Graham Brady     9   Altrincham and Sale West
# 3         E14000533      Nigel Mills    11               Amber Valley
# 4         E14000534     Nick Herbert    18    Arundel and South Downs
# ..              ...              ...   ...                        ...
# 655       W07000076      Wayne David   114                 Caerphilly
# 656       W07000077      Chris Evans   336                     Islwyn
# 657       W07000078      Alun Cairns   589          Vale Of Glamorgan
# 658       W07000079    Kevin Brennan   129               Cardiff West
# 659       W07000080  Stephen Doughty   128  Cardiff South and Penarth
#
#     Party abbreviation  conShare  conShare2  conShare3  bill161  leave  \
# 0                  Con     50.59  73.403947  73.403947      1.0    1.0
# 1                  Con     52.05  69.940876  69.940876      1.0    0.0
# 2                  Con     52.99  66.503514  66.503514      1.0    1.0
# 3                  Con     43.98  55.840528  55.840528      1.0    1.0
# 4                  Con     60.79  84.442284  84.442284      NaN    0.0
# ..                 ...       ...        ...        ...      ...    ...
# 655                Lab     16.59  27.223499  27.223499      1.0    0.0
# 656                Lab     15.16  23.639482  23.639482      1.0    0.0
# 657                Con     46.02  58.527280  58.527280      1.0    0.0
# 658                Lab     25.15  38.221884  38.221884      0.0    0.0
# 659                Lab     26.81  38.525650  38.525650      0.0    0.0
#
#      party_old       ref  ref_dummy  party  old_party
# 0          1.0  0.578978          1    1.0        1.0
# 1          1.0  0.677963          1    0.0        0.0
# 2          1.0  0.385878          0    1.0        1.0
# 3          1.0  0.652991          1    1.0        1.0
# 4          1.0  0.497011          0    0.0        0.0
# ..         ...       ...        ...    ...        ...
# 655        0.0  0.551360          1    0.0        NaN
# 656        0.0  0.589399          1    0.0        NaN
# 657        1.0  0.525507          1    0.0        0.0
# 658        0.0  0.438226          0    0.0        NaN
# 659        0.0  0.428172          0    0.0        NaN
#
# [660 rows x 15 columns]

# %%
def preprocess(topic):
    ret = []
    topic = topic.strip()
    
    if '|' in topic:
        topics = topic.split('|')
        t = topics[0]
        t = t.strip()
        return t
        
    return topic

# %%
politicians_party = {}
politicians_ref = {}
politicians = vote_file['full name'].unique()
for index, row in vote_file.iterrows():
    politicians_party[row['full name']] = row['party']
    politicians_ref[row['full name']] = row['ref_dummy']

# %%
df1 = pd.read_csv('2016_commons.csv')
df2 = pd.read_csv('2017_commons.csv')
df = pd.concat([df1, df2])
df = df.drop(['Government'], axis=1)
df = df.loc[(df['Party'] == 'Conservative') | (df['Party'] == 'Labour')]
df = df.loc[df['Name'].isin(politicians)]
df['Date'] = pd.to_datetime(df['Date'])
mask = (df['Date'] > '2015-6-1') & (df['Date'] <= '2016-6-30')
df = df.loc[mask]
df['party2'] = df['Name'].apply(lambda x: politicians_party[x])
df['ref_dummy'] = df['Name'].apply(lambda x: politicians_ref[x])
df['Topic'] = df['Topic'].apply(lambda x: preprocess(x))
df = df.loc[df['Topic'] == 'Parliament, government and politics']
# df = df.loc[df['Topic'] == 'European Union']
# df = df.loc[df['Topic'] == 'Crime, civil law, justice and rights']
# df = df.loc[df['Topic'] == 'Health services and medicine']
# df = df.loc[df['Topic'] == 'International affairs']
cols = df.columns
cols = ['date', 'speaker', 'name', 'Party', 'Topic', 'transcript', 'party2', 'ref_dummy']
df.columns = cols
df.head()
# Out:
#           date                                            speaker  \
# 785 2016-01-06  The Secretary of State for Scotland (David Mun...
# 787 2016-01-06                                      David Mundell
# 789 2016-01-06                                      David Mundell
# 791 2016-01-06                                      David Mundell
# 793 2016-01-06                                      David Mundell
#
#               name         Party                                Topic  \
# 785  David Mundell  Conservative  Parliament, government and politics
# 787  David Mundell  Conservative  Parliament, government and politics
# 789  David Mundell  Conservative  Parliament, government and politics
# 791  David Mundell  Conservative  Parliament, government and politics
# 793  David Mundell  Conservative  Parliament, government and politics
#
#                                             transcript  party2  ref_dummy
# 785  May I begin by wishing you a very happy new ye...     0.0          0
# 787  My understanding is that the Deputy First Mini...     0.0          0
# 789  As I said, we are involved in an ongoing negot...     0.0          0
# 791  I think what many people in Scotland will find...     0.0          0
# 793  I am disappointed with the hon. Gentleman’s an...     0.0          0

# %%
X = []

for index, row in df.iterrows():
    party = row['Party']
    if party == 'Conservative':
        X.append([row['transcript'], 0])
    if party == 'Labour':
        X.append([row['transcript'], 1])

train_df = pd.DataFrame(X, columns=['text', 'labels'])
shuffle(train_df, random_state=42)
# Out:
#                                                    text  labels
# 184   I am surprised that the Labour party is still ...       0
# 1018  It will not be possible for law enforcement ag...       0
# 2909  I could give a variety of responses to those p...       0
# 2704  Yes, that is the burden of my speech. As the n...       0
# 602   No, I do not have time.  Some say that young p...       1
# ...                                                 ...     ...
# 3444  I pay tribute to my hon. Friend for the work h...       0
# 466   I welcome the Home Secretary’s comments becaus...       1
# 3092  I thank the Secretary of State for his answer,...       0
# 3772  This final group of amendments covers three of...       1
# 860   T1.   If he will make a statement on his depar...       0
#
# [4256 rows x 2 columns]

# %%
train_data,test_data = train_test_split(
    train_df,
    test_size=0.1,
    shuffle=False
    )

# %%
test_data
# Out:
#                                                    text  labels
# 3830  The manufacturing sector makes up roughly one ...       1
# 3831  The Government’s position on this is clear, an...       0
# 3832  I gather that my hon. Friend has been having l...       0
# 3833  I discussed those matters yesterday with the M...       0
# 3834  It is clearly good news that manufacturing job...       0
# ...                                                 ...     ...
# 4251  My hon. Friend is right. There were 312 people...       0
# 4252  Given the surge in voter registration, how can...       1
# 4253  We just had this question a few minutes ago, a...       0
# 4254  T8.   What steps will the Secretary of State t...       1
# 4255  I am afraid that the hon. Gentleman is mistake...       0
#
# [426 rows x 2 columns]

# %%
train_data
# Out:
#                                                    text  labels
# 0     I beg to move an amendment, at the end of the ...       1
# 1     In this House, we generally argue for subsidia...       1
# 2     As has been discussed during the series of deb...       1
# 3     I want to ask about devolution within Wales. S...       1
# 4     I completely agree. That is a fantastic exampl...       1
# ...                                                 ...     ...
# 3825  For the remaining one and half minutes, I call...       1
# 3826  I will be short and to the point, Madam Deputy...       0
# 3827  I thank the hon. Gentleman for giving advance ...       1
# 3828  1. What steps the Government is taking to supp...       1
# 3829  Our long-term plan is delivering a stronger ec...       0
#
# [3830 rows x 2 columns]

# %%
# model_args = ClassificationArgs(sliding_window=True, overwrite_output_dir=True)

model_args = ClassificationArgs(
    num_train_epochs=1,
    output_dir="ideology_classifier/",
    best_model_dir="ideology_classifier/best-model/",
    evaluate_during_training=True,
    evaluate_during_training_verbose=True,
    evaluate_during_training_steps=50000,
    save_steps=50000,
    save_model_every_epoch=True,
    overwrite_output_dir=True,
    max_seq_length=512,
    sliding_window=True,
    train_batch_size=6,
    eval_batch_size=32,
    regression=False,
    do_lower_case=True,
    #use_early_stopping=True
    )

model = ClassificationModel(
    "distilbert", "ideology_classifier/best-model/", use_cuda=False, args=model_args
)

# %%
model

# %%
model.train_model(train_data, eval_df=test_data)
# Out:
# INFO:simpletransformers.classification.classification_model: Converting to features started. Cache is not used.
# INFO:simpletransformers.classification.classification_model: Sliding window enabled
#   0%|          | 0/3830 [00:00<?, ?it/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (1172 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (1300 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (727 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (1087 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (872 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (875 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (562 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (779 > 512). Running this sequence through the model will result in indexing errors
# INFO:simpletransformers.classification.classification_model: 4409 features created from 3830 samples.
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:   Starting fine-tuning.
# Running Epoch 0 of 1:   0%|          | 0/735 [00:00<?, ?it/s]
# /home/ubuntu/anaconda3/envs/econ/lib/python3.7/site-packages/torch/optim/lr_scheduler.py:200: UserWarning: Please also save or load the state of the optimzer when saving or loading the scheduler.
#   warnings.warn(SAVE_STATE_WARNING, UserWarning)
# INFO:simpletransformers.classification.classification_model: Converting to features started. Cache is not used.
# INFO:simpletransformers.classification.classification_model: Sliding window enabled
# Token indices sequence length is longer than the specified maximum sequence length for this model (549 > 512). Running this sequence through the model will result in indexing errors
# INFO:simpletransformers.classification.classification_model: 426 features created from 426 samples.
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.4372657646793731, 'tp': 57, 'tn': 279, 'fp': 27, 'fn': 63, 'eval_loss': 1.1386356472969055}
# INFO:simpletransformers.classification.classification_model: Training of distilbert model complete. Saved to ideology_classifier/.
# (735,
#  {'global_step': [735],
#   'tp': [57],
#   'tn': [279],
#   'fp': [27],
#   'fn': [63],
#   'mcc': [0.4372657646793731],
#   'train_loss': [0.00842174980789423],
#   'eval_loss': [1.1386356472969055]})

# %%
result, model_outputs, wrong_predictions = model.eval_model(test_data)
# Out:
# INFO:simpletransformers.classification.classification_model: Converting to features started. Cache is not used.
# INFO:simpletransformers.classification.classification_model: Sliding window enabled
#   0%|          | 0/426 [00:00<?, ?it/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (549 > 512). Running this sequence through the model will result in indexing errors
# INFO:simpletransformers.classification.classification_model: 426 features created from 426 samples.
# Running Evaluation:   0%|          | 0/15 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.46509850828420984, 'tp': 60, 'tn': 280, 'fp': 26, 'fn': 60, 'eval_loss': 0.6931240439414978}

# %%
outputs = [output[0] for output in model_outputs]
from scipy.special import softmax
outputs = softmax(outputs, axis=1)
outputs
# Out:
# array([[0.02373769, 0.97626231],
#        [0.99591258, 0.00408742],
#        [0.99651755, 0.00348245],
#        [0.99596255, 0.00403745],
#        [0.99496831, 0.00503169],
#        [0.99576332, 0.00423668],
#        [0.99596898, 0.00403102],
#        [0.99579803, 0.00420197],
#        [0.0193564 , 0.9806436 ],
#        [0.99524769, 0.00475231],
#        [0.18518253, 0.81481747],
#        [0.99628506, 0.00371494],
#        [0.96612479, 0.03387521],
#        [0.99582053, 0.00417947],
#        [0.32503453, 0.67496547],
#        [0.99658524, 0.00341476],
#        [0.99653377, 0.00346623],
#        [0.99614366, 0.00385634],
#        [0.99448074, 0.00551926],
#        [0.66250905, 0.33749095],
#        [0.65974021, 0.34025979],
#        [0.9945428 , 0.0054572 ],
#        [0.02003702, 0.97996298],
#        [0.99520794, 0.00479206],
#        [0.9789458 , 0.0210542 ],
#        [0.99516114, 0.00483886],
#        [0.93555451, 0.06444549],
#        [0.99521612, 0.00478388],
#        [0.99323402, 0.00676598],
#        [0.9960058 , 0.0039942 ],
#        [0.99678432, 0.00321568],
#        [0.9947565 , 0.0052435 ],
#        [0.99453033, 0.00546967],
#        [0.39558373, 0.60441627],
#        [0.99428175, 0.00571825],
#        [0.9933576 , 0.0066424 ],
#        [0.99655512, 0.00344488],
#        [0.99476763, 0.00523237],
#        [0.99556153, 0.00443847],
#        [0.99609268, 0.00390732],
#        [0.0511759 , 0.9488241 ],
#        [0.99567965, 0.00432035],
#        [0.91305444, 0.08694556],
#        [0.99469952, 0.00530048],
#        [0.04621419, 0.95378581],
#        [0.99537921, 0.00462079],
#        [0.02269099, 0.97730901],
#        [0.99556666, 0.00443334],
#        [0.02268034, 0.97731966],
#        [0.99629353, 0.00370647],
#        [0.98520581, 0.01479419],
#        [0.99637464, 0.00362536],
#        [0.93883019, 0.06116981],
#        [0.99445339, 0.00554661],
#        [0.9926735 , 0.0073265 ],
#        [0.99174283, 0.00825717],
#        [0.92128417, 0.07871583],
#        [0.99683358, 0.00316642],
#        [0.99312192, 0.00687808],
#        [0.99566788, 0.00433212],
#        [0.99592226, 0.00407774],
#        [0.02324803, 0.97675197],
#        [0.99550758, 0.00449242],
#        [0.98908606, 0.01091394],
#        [0.995945  , 0.004055  ],
#        [0.02745167, 0.97254833],
#        [0.99527205, 0.00472795],
#        [0.05424706, 0.94575294],
#        [0.99612219, 0.00387781]])

# %%
import numpy as np

# %%
rows = []
class_map ={
    0: 'conservative',
    1: 'labour'
}

for i in range(len(outputs)):
    output = outputs[i]
    row = [test_data.iloc[i]['text'], output[0], output[1], test_data.iloc[i]['labels'], class_map[np.argmax(output)]]
    rows.append(row)

res_df = pd.DataFrame(rows, columns=['text', 'conservative prob', 'labour prob', 'true label', 'pred label'])
res_df['true label'] = res_df['true label'].apply(lambda x: class_map[x])
res_df
# Out:
#                                                   text  conservative prob  \
# 0    The manufacturing sector makes up roughly one ...           0.023738
# 1    The Government’s position on this is clear, an...           0.995913
# 2    I gather that my hon. Friend has been having l...           0.996518
# 3    I discussed those matters yesterday with the M...           0.995963
# 4    It is clearly good news that manufacturing job...           0.994968
# ..                                                 ...                ...
# 421  My hon. Friend is right. There were 312 people...           0.995945
# 422  Given the surge in voter registration, how can...           0.027452
# 423  We just had this question a few minutes ago, a...           0.995272
# 424  T8.   What steps will the Secretary of State t...           0.054247
# 425  I am afraid that the hon. Gentleman is mistake...           0.996122
#
#      labour prob    true label    pred label
# 0       0.976262        labour        labour
# 1       0.004087  conservative  conservative
# 2       0.003482  conservative  conservative
# 3       0.004037  conservative  conservative
# 4       0.005032  conservative  conservative
# ..           ...           ...           ...
# 421     0.004055  conservative  conservative
# 422     0.972548        labour        labour
# 423     0.004728  conservative  conservative
# 424     0.945753        labour        labour
# 425     0.003878  conservative  conservative
#
# [426 rows x 5 columns]

# %%
res_df.to_csv('labour_conservative_cross_validation.csv', index=False)

# %%
X = []

for index, row in df.iterrows():
    party = row['Party']
    party2 = row['party2']
    if party == 'Conservative' and party2 == 0:
        X.append(row['transcript'])

# %%
predictions, raw_outputs = model.predict(X)
# Out:
# INFO:simpletransformers.classification.classification_model: Converting to features started. Cache is not used.
# INFO:simpletransformers.classification.classification_model: Sliding window enabled
#   0%|          | 0/1409 [00:00<?, ?it/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (872 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (562 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (660 > 512). Running this sequence through the model will result in indexing errors
# INFO:simpletransformers.classification.classification_model: 1409 features created from 1409 samples.
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
outputs = [output[0] for output in raw_outputs]
from scipy.special import softmax
outputs = softmax(outputs, axis=1)
import numpy as np

# %%
rows = []
class_map ={
    0: 'conservative',
    1: 'labour'
}
for i in range(len(outputs)):
    output = outputs[i]
    row = [X[i], output[0], output[1], class_map[np.argmax(output)]]
    rows.append(row)

res_df = pd.DataFrame(rows, columns=['text', 'conservative prob', 'labour prob', 'label'])
res_df
# Out:
#                                                    text  conservative prob  \
# 0     May I begin by wishing you a very happy new ye...           0.999448
# 1     My understanding is that the Deputy First Mini...           0.999496
# 2     As I said, we are involved in an ongoing negot...           0.999479
# 3     I think what many people in Scotland will find...           0.999146
# 4     I am disappointed with the hon. Gentleman’s an...           0.999090
# ...                                                 ...                ...
# 1404  Cyber-security is incredibly important, especi...           0.999459
# 1405  As I said to the House a few moments ago, we w...           0.999238
# 1406  My hon. Friend is right. There were 312 people...           0.999448
# 1407  We just had this question a few minutes ago, a...           0.999339
# 1408  I am afraid that the hon. Gentleman is mistake...           0.999426
#
#       labour prob         label
# 0        0.000552  conservative
# 1        0.000504  conservative
# 2        0.000521  conservative
# 3        0.000854  conservative
# 4        0.000910  conservative
# ...           ...           ...
# 1404     0.000541  conservative
# 1405     0.000762  conservative
# 1406     0.000552  conservative
# 1407     0.000661  conservative
# 1408     0.000574  conservative
#
# [1409 rows x 4 columns]

# %%
res_df.to_csv('prediction_on_remain_conservative_16_17.csv', index=False)

# %%
test_df = pd.read_csv('test_key_speeches.csv')
X_test = list(test_df['text'].values)

# %%
predictions, raw_outputs = model.predict(X_test)
# Out:
# INFO:simpletransformers.classification.classification_model: Converting to features started. Cache is not used.
# INFO:simpletransformers.classification.classification_model: Sliding window enabled
#   0%|          | 0/1089 [00:00<?, ?it/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (1100 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (1183 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (1057 > 512). Running this sequence through the model will result in indexing errors
# INFO:simpletransformers.classification.classification_model: 1089 features created from 1089 samples.
#   0%|          | 0/35 [00:00<?, ?it/s]

# %%
raw_outputs[0]
# Out:
# array([[ 1.95227098, -1.99213946]])

# %%
outputs = [output[0] for output in raw_outputs]
outputs
# Out:
# [array([ 1.95227098, -1.99213946]),
#  array([ 1.24871838, -1.19846106]),
#  array([ 1.78973699, -1.80170774]),
#  array([ 1.60332608, -1.57185733]),
#  array([ 1.85678375, -1.79256666]),
#  array([ 1.10241163, -1.01736414]),
#  array([ 1.55285192, -1.54148531]),
#  array([ 1.17348564, -1.15665245]),
#  array([ 0.66505677, -0.65435606]),
#  array([ 0.42139491, -0.47842768]),
#  array([ 1.56490052, -1.51697445]),
#  array([ 0.57299167, -0.5326702 ]),
#  array([ 1.5603143 , -1.56902778]),
#  array([ 1.81928408, -1.92956221]),
#  array([ 1.75548112, -1.83512855]),
#  array([ 1.74382436, -1.78878212]),
#  array([ 1.69540989, -1.72577441]),
#  array([ 1.69235003, -1.67261875]),
#  array([ 1.35048258, -1.43919539]),
#  array([ 0.58446735, -0.73443586]),
#  array([ 1.59443474, -1.6988107 ]),
#  array([ 1.86144507, -1.94697988]),
#  array([ 1.38998771, -1.50859249]),
#  array([ 0.89012402, -0.87657398]),
#  array([ 1.39347672, -1.42415822]),
#  array([ 1.35665977, -1.56052506]),
#  array([ 1.01903772, -1.12112725]),
#  array([ 1.36317527, -1.45663035]),
#  array([ 1.49393356, -1.570737  ]),
#  array([ 0.61140037, -0.63530725]),
#  array([ 0.93772459, -0.97741127]),
#  array([ 1.11563849, -1.28081751]),
#  array([ 1.31015694, -1.416399  ]),
#  array([ 1.35761654, -1.4784807 ]),
#  array([ 0.83357763, -0.7539835 ]),
#  array([ 1.10640776, -1.07818222]),
#  array([ 0.56463444, -0.7534793 ]),
#  array([ 1.01816475, -1.08207929]),
#  array([ 0.94703281, -0.84176564]),
#  array([ 1.47085202, -1.48636949]),
#  array([ 1.80079961, -1.85095513]),
#  array([ 0.95512563, -0.81380618]),
#  array([ 0.63715863, -0.81517237]),
#  array([ 1.33717823, -1.31027198]),
#  array([ 1.28194606, -1.33908379]),
#  array([ 0.91958731, -0.99272341]),
#  array([ 1.30645561, -1.38951766]),
#  array([ 1.48190486, -1.57855213]),
#  array([ 1.69897902, -1.73391581]),
#  ...]

# %%
from scipy.special import softmax
outputs = softmax(outputs, axis=1)

# %%
import numpy as np

# %%
rows = []
class_map ={
    0: 'conservative',
    1: 'labour'
}
print(len(X_test))
print(len(outputs))
assert(len(X_test) == len(outputs))
for i in range(len(outputs)):
    output = outputs[i]
    row = [X_test[i], output[0], output[1], class_map[np.argmax(output)]]
    rows.append(row)

res_df = pd.DataFrame(rows, columns=['text', 'conservative prob', 'labour prob', 'label'])
res_df
# Out:
# 1089
# 1089
#                                                    text  conservative prob  \
# 0     We all agree that it is vital that everyone is...           0.981005
# 1     The IN campaign maintains that there is no pro...           0.920355
# 2     It is Government policy that Turkey should joi...           0.973181
# 3     It is also the policy of the European Union th...           0.959890
# 4     It is also a fact that both the European Union...           0.974651
# ...                                                 ...                ...
# 1084  This chance may never come again in our lifeti...           0.969630
# 1085  BAGEHOT: The prime minister is nearing the end...           0.215166
# 1086  BAGEHOT: He’s asking for things he knows he’s ...           0.323776
# 1087  BAGEHOT: You mention the Euro campaign. Are th...           0.278107
# 1088  BAGEHOT: To what extent do you think this is a...           0.340278
#
#       labour prob         label
# 0        0.018995  conservative
# 1        0.079645  conservative
# 2        0.026819  conservative
# 3        0.040110  conservative
# 4        0.025349  conservative
# ...           ...           ...
# 1084     0.030370  conservative
# 1085     0.784834        labour
# 1086     0.676224        labour
# 1087     0.721893        labour
# 1088     0.659722        labour
#
# [1089 rows x 4 columns]

# %%
res_df['label'].value_counts()
# Out:
# conservative    1061
# labour            28
# Name: label, dtype: int64

# %%
res_df.to_csv('key_speeches_labour_conservative_prediction_updated_bert.csv', index=False)

# %%
train_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-ef797c2b3b5b> in <module>
# ----> 1 train_df
#
# NameError: name 'train_df' is not defined

# %%
train_df['labels'].value_counts()

# %%
model.eval_model(train_df)
