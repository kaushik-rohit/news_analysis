# %%
import pandas as pd
from gensim import models, corpora
from gensim.parsing.preprocessing import preprocess_string, strip_tags, strip_punctuation
from gensim.parsing.preprocessing import remove_stopwords, stem_text, strip_non_alphanum, strip_multiple_whitespaces
from gensim.parsing.preprocessing import strip_short, strip_numeric
from gensim.parsing.preprocessing import STOPWORDS
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
import multiprocessing as mp
import nltk
import pandas as pd
import numpy as np
import tensorflow as tf
from scipy import spatial
import parmap
import os
import swifter

# %%
topics_index_to_name_map = {
    0: 'Agriculture, animals, food and rural affairs',
    1: 'Asylum, immigration and nationality',
    2: 'Business, industry and consumers',
    3: 'Communities and families',
    4: 'Crime, civil law, justice and rights',
    5: 'Culture, media and sport',
    6: 'Defence',
    7: 'Economy and finance',
    8: 'Education',
    9: 'Employment and training',
    10: 'Energy and environment',
    11: 'European Union',
    12: 'Health services and medicine',
    13: 'Housing and planning',
    14: 'International affairs',
    15: 'Parliament, government and politics',
    16: 'Science and technology',
    17: 'Social security and pensions',
    18: 'Social services',
    19: 'Transport',
    20: 'Others'
}
topics_name_to_index_map = {y:x for x,y in topics_index_to_name_map.items()}

def strip_short2(text):
    return strip_short(text, minsize=4)


def preprocess_text(text):
    FILTERS = [lambda x: x.lower(), strip_multiple_whitespaces, strip_tags, strip_punctuation,
                   strip_non_alphanum, strip_numeric, strip_short2]
    return preprocess_string(text, FILTERS)

def preprocess(topic):
    ret = []
    topic = topic.strip()
    
    if '|' in topic:
        topics = topic.split('|')
        t = topics[0]
        t = t.strip()
        return topics_name_to_index_map[t]
        
    return topics_name_to_index_map[topic]

# %%
path = './data/bbc/2014/transcripts'
files = os.listdir(path)

data = []
for source in files:
    data.append(pd.read_csv(os.path.join(path, source)))
df = pd.concat(data)
df = df.drop(['Unnamed: 0', 'Has Transcript', 'Unavailable link', 'Unavailable reason'], axis=1)
df
# Out:
#           Source         Date     Program Name   Time Duration  \
# 0    BBC1 London   6-dec-2014         BBC News  22:00  20 mins
# 1    BBC1 London   7-dec-2014         BBC News  22:00  20 mins
# 2    BBC1 London   7-dec-2014  BBC London News  22:20  10 mins
# 3    BBC1 London   5-dec-2014  BBC News at One  13:00  30 mins
# 4    BBC1 London   5-dec-2014  BBC News at Ten  22:00  25 mins
# ..           ...          ...              ...    ...      ...
# 107  BBC1 London  26-jun-2014  BBC News at One  13:00  30 mins
# 108  BBC1 London  26-jun-2014  BBC London News  13:30  15 mins
# 109  BBC1 London  26-jun-2014  BBC News at Six  19:10  25 mins
# 110  BBC1 London  26-jun-2014  BBC News at Ten  22:00  30 mins
# 111  BBC1 London  26-jun-2014  BBC London News  22:30  10 mins
#
#                                             Transcript
# 0    #Ah... # Dreaming ofthe days # APPLAUSE Hiya, ...
# 1    Alex Salmond unveils plans to seek a Westminst...
# 2    against the illegal trade in wildlife. He’s ve...
# 3    # The way I love you. # Making Christmas speci...
# 4    Two British men are jailed for travelling to S...
# ..                                                 ...
# 107  Hello, Glastonbury. Hello, Glastonbury! Hello,...
# 108  A little bit more cloud around but some of us ...
# 109  Yet more shocking re-lations about the extent ...
# 110  The most detailed picture yet ofthe The most d...
# 111  He was known as Mark Stone. But in fact, he wa...
#
# [1243 rows x 6 columns]

# %%
transcripts = df['Transcript'].values

# %%
sentences = [nltk.sent_tokenize(transcript) for transcript in transcripts]

# %%
X = [j for sub in sentences for j in sub]

# %%
preprocessed_X = parmap.map(preprocess_text, X, pm_pbar=True)
tagged_X = [models.doc2vec.TaggedDocument(doc, [i]) for i, doc in enumerate(preprocessed_X)]
# Out:
# 362496it [00:01, 225434.20it/s]

# %%
preprocessed_X[4]
# Out:
# ['yeah',
#  'your',
#  'smiling',
#  'face',
#  'like',
#  'never',
#  'seen',
#  'before',
#  'wonderful']

# %%
print('training doc2vec')
doc2vec_model = Doc2Vec(vector_size=100, window=3, workers=mp.cpu_count(), epochs=40)
doc2vec_model.build_vocab(tagged_X)
doc2vec_model.train(tagged_X, total_examples=doc2vec_model.corpus_count, epochs=doc2vec_model.epochs)
# Out:
# training doc2vec

# %%
doc2vec_model.save('./models/doc2vec/sent2vec')

# %%
doc2vec_model = Doc2Vec.load('./models/doc2vec/sent2vec')

# %%
from sklearn.metrics.pairwise import cosine_similarity

def filter_short_sentence(sentences):
    n_sent = len(sentences)
    filtered_sentences = []
    for i in range(n_sent):
        if len(sentences[i].split()) >= 10:
            filtered_sentences.append(sentences[i])
    return filtered_sentences

def partition_transcript_into_topics(transcript):
    cluster = []
    sentences = nltk.sent_tokenize(transcript)
    sentences = filter_short_sentence(sentences)
    n_sent = len(sentences)
    current_cluster = [sentences[0]]
    n_cluster = 1
    for i in range(1, n_sent):
        vec1 = doc2vec_model.infer_vector(preprocess_text(sentences[i]))
        sim = 0
        for sent in current_cluster:
            vec2 = doc2vec_model.infer_vector(preprocess_text(sent))
            sim+= cosine_similarity([vec1], [vec2])[0]
            
        avg_sim = sim/len(current_cluster)
        if avg_sim >= 0.4:
            current_cluster.append(sentences[i])
            if i == n_sent - 1:
                cluster.append(' '.join(current_cluster))
        else:
            n_cluster += 1
            cluster.append(' '.join(current_cluster))
            current_cluster = [sentences[i]]
    return '\n---------------------\n'.join(cluster)

# %%
df.reset_index(inplace=True)

# %%
df['partitions'] = df.swifter.apply(lambda x: partition_transcript_into_topics(x['Transcript']), axis=1)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Pandas Apply', max=1243.0, style=ProgressStyle(descriptio…
# 215
# 0.8310677260160446
# 0.5629817545413971
# 0.59916819135348
# 0.7156999688595533
# 0.5207093566656112
# 0.6719989522049824
# 0.9847413514341626
# 0.9916586196050048
# 0.539669543504715
# 0.6362369507551193
# 0.6660276452700297
# 0.6056173890829086
# 0.7701626002788544
# 0.8159753341848651
# 0.7166747248598507
# 0.6941114515066147
# 0.8103604879644182
# 0.5169069945812226
# 0.7502360083162785
# 0.8510854677297175
# 0.91628955795358
# 0.5543610762272563
# 0.8946740665783485
# 0.6917838179506361
# 0.9200764732325778
# 1.0581592693924904
# 0.8327228128910065
# 0.841384906321764
# 0.8296404716869196
# 0.8041429165750742
# 0.8663453623652458
# 0.9507665280252695
# 0.8918930366635323
# 0.9188507534563541
# 0.7822711020708084
# 0.712328914552927
# 0.936956737563014
# 0.9624238833785057
# 0.9137035235762596
# 0.9162227362394333
# 0.9467099184791247
# 1.0225630272179842
# 0.9971644734032452
# 0.9894961575046182
# 0.606303483247757
# 0.8012752085924149
# 1.034554875145356
# 1.0164541564881802
# 0.9638351052999496
# 1.2204315811395645
# 1.0877333208918571
# 1.000034620617953
# 1.0925231128931046
func, axis=axis, raw=raw, result_type=result_type, args=args, **kwds)
#
# <ipython-input-337-01356b16fadb> in <lambda>(x)
# ----> 1 df['partitions'] = df.swifter.apply(lambda x: partition_transcript_into_topics(x['Transcript']), axis=1)
#
# <ipython-input-328-3f9b1b2740fa> in partition_transcript_into_topics(transcript)
#       2     cluster = []
# ----> 3     sentences = nltk.sent_tokenize(transcript)
#       4     n_sent = len(sentences)
#
# ~/anaconda3/envs/econ/lib/python3.7/site-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#     105     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
# --> 106     return tokenizer.tokenize(text)
#     107
#
# ~/anaconda3/envs/econ/lib/python3.7/site-packages/nltk/tokenize/punkt.py in tokenize(self, text, realign_boundaries)
#    1276         """
# -> 1277         return list(self.sentences_from_text(text, realign_boundaries))
#    1278
#
# ~/anaconda3/envs/econ/lib/python3.7/site-packages/nltk/tokenize/punkt.py in sentences_from_text(self, text, realign_boundaries)
#    1330         """
# -> 1331         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1332
#
# ~/anaconda3/envs/econ/lib/python3.7/site-packages/nltk/tokenize/punkt.py in <listcomp>(.0)
#    1330         """
# -> 1331         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1332
#
# ~/anaconda3/envs/econ/lib/python3.7/site-packages/nltk/tokenize/punkt.py in span_tokenize(self, text, realign_boundaries)
#    1320             slices = self._realign_boundaries(text, slices)
# -> 1321         for sl in slices:
#    1322             yield (sl.start, sl.stop)
#
# ~/anaconda3/envs/econ/lib/python3.7/site-packages/nltk/tokenize/punkt.py in _realign_boundaries(self, text, slices)
#    1361         realign = 0
# -> 1362         for sl1, sl2 in _pair_iter(slices):
#    1363             sl1 = slice(sl1.start + realign, sl1.stop)
#
# ~/anaconda3/envs/econ/lib/python3.7/site-packages/nltk/tokenize/punkt.py in _pair_iter(it)
#     317     try:
# --> 318         prev = next(it)
#     319     except StopIteration:
#
# ~/anaconda3/envs/econ/lib/python3.7/site-packages/nltk/tokenize/punkt.py in _slices_from_text(self, text)
#    1334         last_break = 0
# -> 1335         for match in self._lang_vars.period_context_re().finditer(text):
#    1336             context = match.group() + match.group('after_tok')
#
# TypeError: expected string or bytes-like object
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-337-01356b16fadb> in <module>
# ----> 1 df['partitions'] = df.swifter.apply(lambda x: partition_transcript_into_topics(x['Transcript']), axis=1)
#
# ~/anaconda3/envs/econ/lib/python3.7/site-packages/swifter/swifter.py in apply(self, func, axis, raw, result_type, args, **kwds)
#     365                     apply_func = self._obj.apply
#     366
# --> 367                 return apply_func(func, axis=axis, raw=raw, result_type=result_type, args=args, **kwds)
#     368
#     369     def _wrapped_applymap(self, func):
#
# ~/anaconda3/envs/econ/lib/python3.7/site-packages/tqdm/std.py in inner(df, func, *args, **kwargs)
#     754                 # Apply the provided function (in **kwargs)
#     755                 # on the df using our wrapper (which provides bar updating)
# --> 756                 result = getattr(df, df_function)(wrapper, **kwargs)
#     757
#     758                 # Close bar and return pandas calculation result
#
# ~/anaconda3/envs/econ/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# ~/anaconda3/envs/econ/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~/anaconda3/envs/econ/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     294             try:
#     295                 result = libreduction.compute_reduction(
# --> 296                     values, self.f, axis=self.axis, dummy=dummy, labels=labels
#     297                 )
#     298             except ValueError as err:
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.compute_reduction()
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.Reducer.get_result()
#
# ~/anaconda3/envs/econ/lib/python3.7/site-packages/tqdm/std.py in wrapper(*args, **kwargs)
#     750                     # take a fast or slow code path; so stop when t.total==t.n
#     751                     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 752                     return func(*args, **kwargs)
#     753
#     754                 # Apply the provided function (in **kwargs)
#
# <ipython-input-337-01356b16fadb> in <lambda>(x)
# ----> 1 df['partitions'] = df.swifter.apply(lambda x: partition_transcript_into_topics(x['Transcript']), axis=1)
#
# <ipython-input-328-3f9b1b2740fa> in partition_transcript_into_topics(transcript)
#      11         for sent in current_cluster:
#      12             vec2 = doc2vec_model.infer_vector(preprocess_text(sent))
# ---> 13             sim+= spatial.distance.cosine(vec1, vec2)
#      14
#      15         avg_sim = sim/len(current_cluster)
#
# ~/anaconda3/envs/econ/lib/python3.7/site-packages/scipy/spatial/distance.py in cosine(u, v, w)
#     764     # cosine distance is also referred to as 'uncentered correlation',
#     765     #   or 'reflective correlation'
# --> 766     return correlation(u, v, w=w, centered=False)
#     767
#     768
#
# ~/anaconda3/envs/econ/lib/python3.7/site-packages/scipy/spatial/distance.py in correlation(u, v, w, centered)
#     715         u = u - umu
#     716         v = v - vmu
# --> 717     uv = np.average(u * v, weights=w)
#     718     uu = np.average(np.square(u), weights=w)
#     719     vv = np.average(np.square(v), weights=w)
#
# KeyboardInterrupt:

# %%
transcripts[2]
# Out:
# 'against the illegal trade in wildlife. He’s very passionate about that. At the World Bank, he will be making a speech which we are told will significant. A critical visit in a country which is of such critical importance to the United Kingdom. Time now for some sport. Premier League football on the way but we start with rugby union where there was a big upset in the European champions cup as Leicester secured a famous victory over the defending champions Toulon. Leicester are not often underdogs but against Toulon, very few are able to complete with rugby’s Galactica ‘s. What they cannot defend is errors. Although Bryan Habana showed why he is the brightest star in the Toulon const
# ---------------------
# In those clear spells, the risk for the Russia Iowa -- those clear spells, the risk for the Russia Iowa -- rush hour will be ice for some of you. Showers are limited to western Scotland, Northern Ireland, North West England and parts of the Midlands.
# ---------------------
# A brief step into the miles # Like I’ve never seen before... # Isn’t it wonderful? # Oh, yeah # I see your smiling face # Like I’ve never seen before... # Isn’t it wonderful? # I wish you a merry Christmas, baby... # I love you so much. # And lots of happiness in the coming year... # This Christmas on BBC One. # You could be my favourite place I have ever been. We are now in that crucial month of December, and for our four teams in action tonight, no time to reflect on the season so far, with the fixtures coming thick and fast.
# ---------------------
# john Hartson, Thomas Hitzlsperger and Asmir Begovic provide our company as we look back on another entertaining and contentious day in the Barclays Premier League.
# ---------------------
# Both West Ham and Swansea City are enjoying their best ever starts to a Premier League campaign.
# ---------------------
# It was February before West Ham had this many points last season, while Swansea have already beaten the likes of Manchester United and Arsenal this term.
# ---------------------
# You won’t find two more content managers, but will Garry Monk burst big Sam’s bubble?
# ---------------------
# The West Ham boss is able to recall Enner Valencia and Alex Song.
# ---------------------
# Mark Noble is not fit enough to return, but Sakho is back amongst the substitutes.
# ---------------------
# Swansea are without the suspended Neil Taylor, who had started every game until now.
# ---------------------
# Leon Brittan continues in midfield, against the club who once paid ÂlIoo,000 for him as a 16-year-old. Nine home wins from 16 Premier League matches in this calendar year.
# ---------------------
# That is cleared by Williams, only as far as Song.
# ---------------------
# Leon Brittan on Downing, which I thought was the bigger shout.
# ---------------------
# It was the driving run of Kouyate that started it. We have seen him put those away over the years. Garry Monk took over as interim manager three days after this corresponding fixture last season. They lost 2-0, and that is when he got the call. He has come a long way since then, in a short space of time. Beautifully worked, against the run of play, you have to say.
# ---------------------
# But Bony, clinical again, the run of play, you have to say.
# ---------------------
# But Bony, clinicalagain, his seventh goal in nine Premier League games.

# %%
df.to_csv('./partitioned_transcripts.csv')

# %%
def build_network():
    model = tf.keras.models.Sequential([
        tf.keras.Input(shape=(100)),
        tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l=0.1)),
        tf.keras.layers.Dense(21, activation='softmax')
    ])
    loss_fn = tf.keras.losses.CategoricalCrossentropy(from_logits=False, label_smoothing=0, name='categorical_crossentropy')

    model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=loss_fn,
              metrics=['accuracy'])
    
    return model

def predict(X, topn=3):
    preprocessed_X = preprocess_text(X)
    vec_X = doc2vec_model.infer_vector(preprocessed_X)
    vec_X = vec_X.reshape(1, vec_X.shape[0])
    pred = classifier.predict(vec_X)
    pred_i = [(topics_index_to_name_map[i], p) for i,p in enumerate(pred[0])]
    pred_sorted = sorted(pred_i, key=lambda x: x[1], reverse=True)
    return pred_sorted[:topn]

# %%
doc2vec_model = Doc2Vec.load('./models/doc2vec/doc2vec_12_13')
classifier = build_network()
classifier.load_weights('./models/doc2vec/classifier_12_13')

# %%
predict('That is cleared by Williams, only as far as Song.')
# Out:
# [('Parliament, government and politics', 0.40107185),
#  ('Others', 0.11620629),
#  ('Culture, media and sport', 0.064145476)]
