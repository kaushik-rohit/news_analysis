# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
from gensim import models, corpora
from gensim.parsing.preprocessing import preprocess_string, strip_tags, strip_punctuation
from gensim.parsing.preprocessing import remove_stopwords, stem_text, strip_non_alphanum, strip_multiple_whitespaces
from gensim.parsing.preprocessing import strip_short, strip_numeric
from gensim.parsing.preprocessing import STOPWORDS
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
import multiprocessing as mp
from sklearn.utils import class_weight
import nltk
import pandas as pd
import numpy as np
import tensorflow as tf
import parmap
import swifter

# %% [markdown]
# # Some constants and Preprocessing methods

# %%
topics_index_to_name_map = {
    0: 'Agriculture, animals, food and rural affairs',
    1: 'Asylum, immigration and nationality',
    2: 'Business, industry and consumers',
    3: 'Communities and families',
    4: 'Crime, civil law, justice and rights',
    5: 'Culture, media and sport',
    6: 'Defence',
    7: 'Economy and finance',
    8: 'Education',
    9: 'Employment and training',
    10: 'Energy and environment',
    11: 'European Union',
    12: 'Health services and medicine',
    13: 'Housing and planning',
    14: 'International affairs',
    15: 'Parliament, government and politics',
    16: 'Science and technology',
    17: 'Social security and pensions',
    18: 'Social services',
    19: 'Transport',
    20: 'Others'
}
topics_name_to_index_map = {y:x for x,y in topics_index_to_name_map.items()}

def strip_short2(text):
    return strip_short(text, minsize=4)


def preprocess_text(text):
    FILTERS = [lambda x: x.lower(), strip_multiple_whitespaces, strip_tags, strip_punctuation,
                   strip_non_alphanum, strip_numeric, strip_short2]
    return preprocess_string(text, FILTERS)

def preprocess(topic):
    ret = []
    topic = topic.strip()
    
    if '|' in topic:
        topics = topic.split('|')
        t = topics[0]
        t = t.strip()
        return topics_name_to_index_map[t]
        
    return topics_name_to_index_map[topic]

# %%
year = 2017
drop = '_no_Others'

# %% [markdown]
# # Read news predictions

# %%
df = pd.read_csv('../data/news_predictions/news_{}_predictions.csv'.format(year))

# %% [markdown]
# # Select one month to train our classifier

# %%
df = df.loc[df.month.isin([1,3,4,5,6])]
df = df.drop(['Unnamed: 0'], axis=1)
df = df.reset_index(drop=True)
df
# Out:
#         source_id             source  day  month  year  \
# 0          400553  Belfast Telegraph    1      1  2017
# 1          400553  Belfast Telegraph    1      1  2017
# 2          400553  Belfast Telegraph    1      1  2017
# 3          400553  Belfast Telegraph    1      1  2017
# 4          400553  Belfast Telegraph    1      1  2017
# ...           ...                ...  ...    ...   ...
# 692700     412338              Wales   30      6  2017
# 692701     412338              Wales   30      6  2017
# 692702     412338              Wales   30      6  2017
# 692703     412338              Wales   30      6  2017
# 692704     412338              Wales   30      6  2017
#
#                                              program_name  \
# 0       Yaya Toure reveals Pep Guardiola's anger at Ma...
# 1       Everton boss Ronald Koeman issues warning to S...
# 2       Stoke manager Mark Hughes hails Peter Crouch's...
# 3       David Moyes braced for "difficult" January win...
# 4       Georginio Wijnaldum unfazed by Chelsea's winni...
# ...                                                   ...
# 692700  Idriss Saadi to be given the chance to impress...
# 692701  Children in Vietnam gave this amazing renditio...
# 692702  The reasons for Warren Gatland's major gamble ...
# 692703  999 turns 80 years old - the most ridiculous e...
# 692704  A new bullying film made in Wales is hoped to ...
#
#                                                transcript  parliament  \
# 0       A lacklustre City lost 1-0 at second-placed Li...           1
# 1       Koeman quit Southampton to take charge at Good...           1
# 2       Crouch netted in Stoke's 4-2 loss at Chelsea a...           1
# 3       For the second straight season the Black Cats ...           1
# 4       A 13th successive victory, tying Arsenal's eff...           1
# ...                                                   ...         ...
# 692700  But a summer exit for the Algeria internationa...           1
# 692701  And the words were displayed phonetically on a...           1
# 692702  The call has divided opinion, based on the rel...           1
# 692703  The last eight decades have seen the service e...           1
# 692704  The Firehorse Productions movie will have its ...           1
#
#                                   top1_topic  top1_acc  \
# 0                   Culture, media and sport     96.34
# 1                                     Others     43.70
# 2       Crime, civil law, justice and rights     22.13
# 3           Business, industry and consumers     29.02
# 4                   Culture, media and sport     97.40
# ...                                      ...       ...
# 692700              Culture, media and sport     32.85
# 692701   Parliament, government and politics     24.29
# 692702                                Others     24.83
# 692703              Culture, media and sport     49.40
# 692704                             Education     32.19
#
#                                   top2_topic  top2_acc  \
# 0       Crime, civil law, justice and rights      0.79
# 1                   Communities and families     17.49
# 2        Parliament, government and politics     21.14
# 3                                     Others     21.56
# 4                                     Others      0.69
# ...                                      ...       ...
# 692700                                Others     17.47
# 692701              Culture, media and sport     21.36
# 692702              Culture, media and sport     22.66
# 692703                                Others     12.63
# 692704                                Others     17.42
#
#                                  top3_topic  top3_acc
# 0          Business, industry and consumers      0.75
# 1                  Culture, media and sport     16.94
# 2                  Culture, media and sport     20.00
# 3                  Culture, media and sport     11.25
# 4                                 Education      0.58
# ...                                     ...       ...
# 692700                            Education      7.46
# 692701                               Others     19.74
# 692702  Parliament, government and politics     14.68
# 692703             Communities and families     12.10
# 692704             Culture, media and sport     16.23
#
# [692705 rows x 14 columns]

# %% [markdown]
# drop rows where transcript is None or empty

# %%
df  = df.dropna(subset=['transcript'])

# %%
total_articles = len(df)
print('total number of news articles: {}'.format(total_articles))
# Out:
# total number of news articles: 692673

# %%
df['top1_topic'].value_counts()
# Out:
# Culture, media and sport                        208426
# Others                                          198430
# Parliament, government and politics              47783
# Crime, civil law, justice and rights             40425
# Health services and medicine                     32678
# Economy and finance                              22594
# International affairs                            21138
# Business, industry and consumers                 20536
# Energy and environment                           19171
# Defence                                          15218
# Transport                                        14840
# Agriculture, animals, food and rural affairs     14621
# European Union                                   12195
# Communities and families                          9358
# Education                                         8578
# Asylum, immigration and nationality               1926
# Science and technology                            1768
# Employment and training                           1513
# Housing and planning                              1426
# Social security and pensions                        33
# Social services                                     16
# Name: top1_topic, dtype: int64

# %% [markdown]
# Drop those where top topic accuracy is less than 40% or is Others

# %%
df = df[df.top1_acc >= 40]

if drop == '_no_Others':
    df = df[df.top1_topic != 'Others']
elif drop == '_no_Others_Parliament':
    df = df[df.top1_topic != 'Others']
    df = df[df.top1_topic != 'Parliament, government and politics']

# %%
df['top1_topic'].value_counts()
# Out:
# Culture, media and sport                        163093
# Parliament, government and politics              25447
# Crime, civil law, justice and rights             23488
# Health services and medicine                     23226
# Economy and finance                              15217
# International affairs                            13133
# Energy and environment                           10974
# Defence                                          10054
# Transport                                         9741
# Business, industry and consumers                  8965
# Agriculture, animals, food and rural affairs      7741
# European Union                                    7629
# Education                                         4940
# Communities and families                          2508
# Housing and planning                               626
# Employment and training                            473
# Asylum, immigration and nationality                433
# Science and technology                             323
# Social security and pensions                         2
# Name: top1_topic, dtype: int64

# %%
print('articles after drop: {}'.format(len(df)))
# Out:
# articles after drop: 328013

# %%
print('percent of articles remaining {}'.format(len(df)/total_articles))
# Out:
# percent of articles remaining 0.47354668075700945

# %%
X = df['transcript'].values
Y = df['top1_topic'].values

# %%
print('preprocessing data!!')
preprocessed_X = parmap.map(preprocess_text, X, pm_pbar=True)
tagged_X = [models.doc2vec.TaggedDocument(doc, [i]) for i, doc in enumerate(preprocessed_X)]
# Out:
# preprocessing data!!
# 328064it [00:35, 9193.24it/s]

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder(handle_unknown='ignore')
Y = df.top1_topic.values
input_Y = Y.reshape(-1,1)
enc.fit(input_Y)
input_Y = enc.transform(input_Y).toarray()

# %%
from joblib import dump, load
dump(enc, '../models/doc2vec/encoder_{}{}.joblib'.format(year, drop))
# Out:
# ['../models/doc2vec/encoder_2017_no_Others.joblib']

# %%
print('training doc2vec')
doc2vec_model = Doc2Vec(vector_size=100, window=3, workers=mp.cpu_count(), epochs=40)
doc2vec_model.build_vocab(tagged_X)
doc2vec_model.train(tagged_X, total_examples=doc2vec_model.corpus_count, epochs=doc2vec_model.epochs)
doc2vec_model.save('../models/doc2vec/doc2vec_news_{}{}'.format(year, drop))
# Out:
# training doc2vec

# %%
print('preparing inputs')

def get_doc_vec(doc):
    return doc2vec_model.infer_vector(doc.words)

inputs = parmap.map(get_doc_vec, tagged_X, pm_pbar=True)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(inputs, input_Y, test_size=0.2, random_state=42)
X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)
print('X_train: ', X_train.shape)
print('y_train: ', y_train.shape)
print('X_test: ', X_test.shape)
print('y_test: ', y_test.shape)

# %%
def build_network():
    model = tf.keras.models.Sequential([
        tf.keras.Input(shape=(100)),
        tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l=0.1)),
        tf.keras.layers.Dense(len(enc.categories_[0]), activation='softmax')
    ])
    loss_fn = tf.keras.losses.CategoricalCrossentropy(from_logits=False, label_smoothing=0, name='categorical_crossentropy')

    model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=loss_fn,
              metrics=['accuracy'])
    
    return model

# %%
model = build_network()
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)
class_weights = class_weight.compute_class_weight('balanced', np.unique(Y), Y)
model.fit(X_train, y_train, batch_size=32, epochs=200, callbacks=[callback], class_weight=class_weights,
          validation_data=(X_test, y_test))

# %%
model.save_weights('../models/doc2vec/news_classifier_{}{}'.format(year, drop))
doc2vec_model.save('../models/doc2vec/doc2vec_news_{}{}'.format(year, drop))

# %%
def predict(X, topn=3):
    preprocessed_X = preprocess_text(X)
    vec_X = doc2vec_model.infer_vector(preprocessed_X)
    vec_X = vec_X.reshape(1, vec_X.shape[0])
    pred = model.predict(vec_X)
    pred_i = []
    for i, p in enumerate(pred[0]):
        one_hot = np.zeros(len(pred[0]))
        one_hot[i] = 1
        pred_i += [(enc.inverse_transform([one_hot])[0][0], p)]
    pred_sorted = sorted(pred_i, key=lambda x: x[1], reverse=True)
    return pred_sorted[:topn]

# %%
predict(X[8])

# %%
X[8]

# %%
df['predicted_topic'] = df.swifter.apply(lambda row: predict(row['transcript']), axis=1)

# %%
df
# Out:
#         source_id             source  day  month  year  \
# 24         163795  Belfast Telegraph    1      3  2017
# 42         163795  Belfast Telegraph    1      3  2017
# 62         163795  Belfast Telegraph    1      3  2017
# 109        163795  Belfast Telegraph    1      3  2017
# 126        400553  Belfast Telegraph    1      3  2017
# ...           ...                ...  ...    ...   ...
# 271490     244365              Wales   30      4  2017
# 271497     244365              Wales   30      4  2017
# 271519     244365              Wales   30      4  2017
# 271544     412338              Wales   30      4  2017
# 271609     412338              Wales   30      4  2017
#
#                                              program_name  \
# 24      Parties keep positions despite seat cut... if ...
# 42           Struck off: GP who falsified clinical trials
# 62      Trophies or I get the boot: Pep;\nEMIRATES FA ...
# 109     Murray is back in the groove on happy return;\...
# 126     Murder probe after body of woman, 80, found in...
# ...                                                   ...
# 271490                                       WELSH League
# 271497        FINISHING LINE NOW IN SIGHT FOR THE OSPREYS
# 271519  BEHIND BARS;\nHere are the faces of some of th...
# 271544  Kumar Sangakkara helps Surrey cruise to victor...
# 271609  Wales reject proves he deserves to tour and ot...
#
#                                                transcript  parliament  \
# 24      Arlene Foster's party would lose six seats, bu...         NaN
# 42      A CROOKED doctor convicted of falsifying clini...         NaN
# 62      City took advantage of a free weekend to trave...         NaN
# 109     The top seed, now fully fit after a bout of sh...         NaN
# 126     At around 2:05am on Tuesday, officers went to ...         NaN
# ...                                                   ...         ...
# 271490  Drew Fahiya scored a hat-trick for Gavin Chest...         NaN
# 271497  Griffiths was the first British athlete home i...         NaN
# 271519  Evans, from Ebbw Vale, committed the assaults ...         NaN
# 271544  After Dominic Sibley was out in the fourth ove...         NaN
# 271609  Their 24-10 victory was achieved after a deter...         NaN
#
#                       top1_topic  top1_acc  \
# 24        Energy and environment     54.92
# 42                     Transport     53.75
# 62      Communities and families     43.17
# 109      Employment and training     42.90
# 126       Energy and environment     45.26
# ...                          ...       ...
# 271490    Energy and environment     47.92
# 271497   Employment and training     44.77
# 271519    Energy and environment     63.39
# 271544   Employment and training     71.24
# 271609   Employment and training     47.83
#
#                                   top2_topic  top2_acc  \
# 24                  Communities and families      9.99
# 42      Crime, civil law, justice and rights      7.65
# 62                    Energy and environment     22.58
# 109                      Economy and finance      7.96
# 126                 Communities and families      8.18
# ...                                      ...       ...
# 271490               Employment and training      9.53
# 271497              Communities and families     12.17
# 271519          Health services and medicine      7.90
# 271544                             Transport      6.08
# 271609              Communities and families     15.23
#
#                                   top3_topic  top3_acc  \
# 24              Health services and medicine      6.75
# 42       Parliament, government and politics      6.39
# 62                     International affairs     11.63
# 109     Crime, civil law, justice and rights      6.59
# 126                                   Others      7.82
# ...                                      ...       ...
# 271490      Business, industry and consumers      7.51
# 271497  Crime, civil law, justice and rights     10.10
# 271519                                Others      6.21
# 271544      Business, industry and consumers      4.57
# 271609                Energy and environment      8.15
#
#                                           predicted_topic
# 24      [(International affairs, 0.361709), (Defence, ...
# 42      [(Transport, 0.90817), (International affairs,...
# 62      [(Employment and training, 0.36442462), (Crime...
# 109     [(Employment and training, 0.9796784), (Crime,...
# 126     [(Energy and environment, 0.83248276), (Transp...
# ...                                                   ...
# 271490  [(Employment and training, 0.5066459), (Energy...
# 271497  [(Employment and training, 0.9628461), (Commun...
# 271519  [(Health services and medicine, 0.58105093), (...
# 271544  [(Employment and training, 0.87342006), (Crime...
# 271609  [(Employment and training, 0.9246553), (Commun...
#
# [18494 rows x 15 columns]

# %%
df = df.drop(['top_class', 'topic'], axis=1)

# %%
df.to_csv('./doc2vec_on_news_transcripts_preds.csv')

# %%
df['predicted_topic'] = df.swifter.apply(lambda row: predict(row['Transcript']), axis=1)
# Out:
# /home/ubuntu/anaconda3/envs/econ/lib/python3.7/site-packages/swifter/swifter.py:55: UserWarning: This pandas object has duplicate indices, and swifter may not be able to improve performance. Consider resetting the indices with `df.reset_index(drop=True)`.
#   "This pandas object has duplicate indices, and swifter may not be able to improve performance. Consider resetting the indices with `df.reset_index(drop=True)`."
# HBox(children=(FloatProgress(value=0.0, description='Pandas Apply', max=1243.0, style=ProgressStyle(descriptio…
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
