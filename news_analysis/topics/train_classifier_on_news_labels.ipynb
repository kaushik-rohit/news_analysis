# %%
import pandas as pd
from gensim import models, corpora
from gensim.parsing.preprocessing import preprocess_string, strip_tags, strip_punctuation
from gensim.parsing.preprocessing import remove_stopwords, stem_text, strip_non_alphanum, strip_multiple_whitespaces
from gensim.parsing.preprocessing import strip_short, strip_numeric
from gensim.parsing.preprocessing import STOPWORDS
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
import multiprocessing as mp
import nltk
import pandas as pd
import numpy as np
import tensorflow as tf
import parmap
import swifter
# Out:
# /home/ubuntu/anaconda3/envs/econ/lib/python3.7/site-packages/dask/dataframe/utils.py:15: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
topics_index_to_name_map = {
    0: 'Agriculture, animals, food and rural affairs',
    1: 'Asylum, immigration and nationality',
    2: 'Business, industry and consumers',
    3: 'Communities and families',
    4: 'Crime, civil law, justice and rights',
    5: 'Culture, media and sport',
    6: 'Defence',
    7: 'Economy and finance',
    8: 'Education',
    9: 'Employment and training',
    10: 'Energy and environment',
    11: 'European Union',
    12: 'Health services and medicine',
    13: 'Housing and planning',
    14: 'International affairs',
    15: 'Parliament, government and politics',
    16: 'Science and technology',
    17: 'Social security and pensions',
    18: 'Social services',
    19: 'Transport',
    20: 'Others'
}
topics_name_to_index_map = {y:x for x,y in topics_index_to_name_map.items()}

def strip_short2(text):
    return strip_short(text, minsize=4)


def preprocess_text(text):
    FILTERS = [lambda x: x.lower(), strip_multiple_whitespaces, strip_tags, strip_punctuation,
                   strip_non_alphanum, strip_numeric, strip_short2]
    return preprocess_string(text, FILTERS)

def preprocess(topic):
    ret = []
    topic = topic.strip()
    
    if '|' in topic:
        topics = topic.split('|')
        t = topics[0]
        t = t.strip()
        return topics_name_to_index_map[t]
        
    return topics_name_to_index_map[topic]

# %%
df = pd.read_csv('data/news_2016_predictions.csv')

# %%
df = df[df.month == 3]
df = df.reset_index()
df
# Out:
#          index  Unnamed: 0  source_id             source  day  month  year  \
# 0       318650      318650     163795  Belfast Telegraph    1      3  2016
# 1       318651      318651     163795  Belfast Telegraph    1      3  2016
# 2       318652      318652     163795  Belfast Telegraph    1      3  2016
# 3       318653      318653     163795  Belfast Telegraph    1      3  2016
# 4       318654      318654     163795  Belfast Telegraph    1      3  2016
# ...        ...         ...        ...                ...  ...    ...   ...
# 167061  485711      485711     412338              Wales   31      3  2016
# 167062  485712      485712     412338              Wales   31      3  2016
# 167063  485713      485713     412338              Wales   31      3  2016
# 167064  485714      485714     412338              Wales   31      3  2016
# 167065  485715      485715     412338              Wales   31      3  2016
#
#                                              program_name  \
# 0                                               CATTERICK
# 1                                               LINGFIELD
# 2                                               LEICESTER
# 3         Ni Chuilin: Windsor perfect for next Carl fight
# 4                  Judge in warning to Trust over records
# ...                                                   ...
# 167061  Cruises to France, Spain and Portugal will sai...
# 167062  Cruises to France, Spain and Portugal will set...
# 167063  Ofcom tested EE, O2, Vodafone and Three for mo...
# 167064  Reform business rates now to save the Welsh hi...
# 167065  Psychologist reveals 11 tips for parents to fo...
#
#                                                transcript  parliament  \
# 0       18+ Helpline Phonovation 0818 217 100 Going: G...         NaN
# 1       18+ Helpline Phonovation 0818 217 100 CAPT KEE...         NaN
# 2       18+ Helpline Phonovation 0818 217 100 Going: S...         NaN
# 3       Sinn Fein's Caral Ni Chuilin appealed to promo...         NaN
# 4       Barney McElholm said that he would consider is...         NaN
# ...                                                   ...         ...
# 167061  Four departures have been announced for June 2...         NaN
# 167062  Four departures have been announced for June 2...         NaN
# 167063  EE, O2, Three and Vodafone were compared when ...         NaN
# 167064  The Welsh Retail Consortium is calling on the ...         NaN
# 167065  Parents of budding sports stars can play a key...         NaN
#
#                                   top1_topic  top1_acc  \
# 0        Parliament, government and politics     22.93
# 1        Parliament, government and politics     18.24
# 2           Business, industry and consumers     19.44
# 3                   Culture, media and sport     60.87
# 4       Crime, civil law, justice and rights     16.12
# ...                                      ...       ...
# 167061                             Transport     63.43
# 167062                             Transport     60.48
# 167063              Culture, media and sport     34.59
# 167064                   Economy and finance     34.99
# 167065                             Education     34.58
#
#                                  top2_topic  top2_acc  \
# 0                                    Others     10.02
# 1                  Culture, media and sport     14.50
# 2                     International affairs     13.14
# 3       Parliament, government and politics     11.89
# 4       Parliament, government and politics     15.08
# ...                                     ...       ...
# 167061                       European Union     10.99
# 167062                       European Union     10.94
# 167063               Science and technology     18.17
# 167064  Parliament, government and politics     29.27
# 167065                               Others     14.83
#
#                                  top3_topic  top3_acc
# 0          Business, industry and consumers      8.48
# 1          Business, industry and consumers     11.02
# 2       Parliament, government and politics     12.32
# 3                                 Transport      7.47
# 4                                    Others     11.86
# ...                                     ...       ...
# 167061  Parliament, government and politics      8.34
# 167062                               Others      9.58
# 167063                            Transport     14.92
# 167064     Business, industry and consumers     10.44
# 167065             Culture, media and sport     12.41
#
# [167066 rows x 16 columns]

# %%
df  = df.dropna(subset=['transcript'])

# %%
total_articles = len(df)
print('total number of news articles: {}'.format(total_articles))
# Out:
# total number of news articles: 167050

# %%
df['top1_topic'].value_counts()
# Out:
# Culture, media and sport                        41101
# Others                                          35545
# Parliament, government and politics             26722
# Crime, civil law, justice and rights            12142
# International affairs                           11736
# Business, industry and consumers                 9590
# Transport                                        6808
# Health services and medicine                     5430
# Economy and finance                              4563
# European Union                                   3669
# Agriculture, animals, food and rural affairs     3613
# Defence                                          1766
# Education                                        1498
# Energy and environment                           1024
# Employment and training                           994
# Communities and families                          562
# Asylum, immigration and nationality               171
# Housing and planning                              114
# Social security and pensions                        2
# Name: top1_topic, dtype: int64

# %%
df = df[df.top1_acc >= 0.4]
df = df[df.top1_topic != 'Others']

# %%
df['top1_topic'].value_counts()
# Out:
# Culture, media and sport                        41101
# Parliament, government and politics             26722
# Crime, civil law, justice and rights            12142
# International affairs                           11736
# Business, industry and consumers                 9590
# Transport                                        6808
# Health services and medicine                     5430
# Economy and finance                              4563
# European Union                                   3669
# Agriculture, animals, food and rural affairs     3613
# Defence                                          1766
# Education                                        1498
# Energy and environment                           1024
# Employment and training                           994
# Communities and families                          562
# Asylum, immigration and nationality               171
# Housing and planning                              114
# Social security and pensions                        2
# Name: top1_topic, dtype: int64

# %%
df = df.drop(['Unnamed: 0'], axis=1)

# %%
print('articles after drop: {}'.format(len(df)))
# Out:
# articles after drop: 131505

# %%
print('percent of articles remaining {}'.format(len(df)/total_articles))
# Out:
# percent of articles remaining 0.7872193953906016

# %%
X = df['transcript'].values
Y = df['top1_topic'].values

# %%
print('preprocessing data!!')
preprocessed_X = parmap.map(preprocess_text, X, pm_pbar=True)
tagged_X = [models.doc2vec.TaggedDocument(doc, [i]) for i, doc in enumerate(preprocessed_X)]
# Out:
# preprocessing data!!
# 131584it [00:18, 7073.21it/s]

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder(handle_unknown='ignore')
input_Y = Y.reshape(-1,1)
enc.fit(input_Y)
input_Y = enc.transform(input_Y).toarray()

# %%
enc.categories_
# Out:
# [array(['Agriculture, animals, food and rural affairs',
#         'Asylum, immigration and nationality',
#         'Business, industry and consumers', 'Communities and families',
#         'Crime, civil law, justice and rights', 'Culture, media and sport',
#         'Defence', 'Economy and finance', 'Education',
#         'Employment and training', 'Energy and environment',
#         'European Union', 'Health services and medicine',
#         'Housing and planning', 'International affairs',
#         'Parliament, government and politics',
#         'Social security and pensions', 'Transport'], dtype=object)]

# %%
print('training doc2vec')
doc2vec_model = Doc2Vec(vector_size=100, window=3, workers=mp.cpu_count(), epochs=40)
doc2vec_model.build_vocab(tagged_X)
doc2vec_model.train(tagged_X, total_examples=doc2vec_model.corpus_count, epochs=doc2vec_model.epochs)
doc2vec_model.save('./models/doc2vec/doc2vec_news_2016')
# Out:
# training doc2vec

# %%
print('preparing inputs')

def get_doc_vec(doc):
    return doc2vec_model.infer_vector(doc.words)

inputs = parmap.map(get_doc_vec, tagged_X, pm_pbar=True)

# for x in tagged_X:
#     topic_vec = doc2vec_model.infer_vector(x.words)
#     inputs.append(topic_vec)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(inputs, input_Y, test_size=0.2, random_state=42)
X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)
print('X_train: ', X_train.shape)
print('y_train: ', y_train.shape)
print('X_test: ', X_test.shape)
print('y_test: ', y_test.shape)
# Out:
# preparing inputs
# 131584it [03:35, 610.72it/s]
# X_train:  (105204, 100)
# y_train:  (105204, 18)
# X_test:  (26301, 100)
# y_test:  (26301, 18)

# %%
def build_network():
    model = tf.keras.models.Sequential([
        tf.keras.Input(shape=(100)),
        tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l=0.1)),
        tf.keras.layers.Dense(21, activation='softmax')
    ])
    loss_fn = tf.keras.losses.CategoricalCrossentropy(from_logits=False, label_smoothing=0, name='categorical_crossentropy')

    model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=loss_fn,
              metrics=['accuracy'])
    
    return model

# %%
model = build_network()
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)
model.fit(X_train, y_train, batch_size=32, epochs=200, callbacks=[callback], validation_data=(X_test, y_test))
# Out:
# Train on 47439 samples, validate on 11860 samples
# Epoch 1/200
# 47439/47439 [==============================] - 9s 193us/sample - loss: 1.7034 - accuracy: 0.6442 - val_loss: 1.1368 - val_accuracy: 0.6992
# Epoch 2/200
# 47439/47439 [==============================] - 7s 144us/sample - loss: 1.0703 - accuracy: 0.7110 - val_loss: 1.0319 - val_accuracy: 0.7122
# Epoch 3/200
# 47439/47439 [==============================] - 6s 122us/sample - loss: 0.9982 - accuracy: 0.7174 - val_loss: 0.9851 - val_accuracy: 0.7134
# Epoch 4/200
# 47439/47439 [==============================] - 9s 187us/sample - loss: 0.9646 - accuracy: 0.7191 - val_loss: 0.9583 - val_accuracy: 0.7132
# Epoch 5/200
# 47439/47439 [==============================] - 5s 103us/sample - loss: 0.9434 - accuracy: 0.7220 - val_loss: 0.9321 - val_accuracy: 0.7197
# Epoch 6/200
# 47439/47439 [==============================] - 4s 82us/sample - loss: 0.9279 - accuracy: 0.7229 - val_loss: 0.9270 - val_accuracy: 0.7152
# Epoch 7/200
# 47439/47439 [==============================] - 4s 77us/sample - loss: 0.9220 - accuracy: 0.7240 - val_loss: 0.9257 - val_accuracy: 0.7159
# Epoch 8/200
# 47439/47439 [==============================] - 3s 69us/sample - loss: 0.9150 - accuracy: 0.7209 - val_loss: 0.9319 - val_accuracy: 0.7136
# Epoch 9/200
# 47439/47439 [==============================] - 3s 70us/sample - loss: 0.9103 - accuracy: 0.7221 - val_loss: 0.9125 - val_accuracy: 0.7171
# Epoch 10/200
# 47439/47439 [==============================] - 3s 72us/sample - loss: 0.9026 - accuracy: 0.7242 - val_loss: 0.9133 - val_accuracy: 0.7126
# Epoch 11/200
# 47439/47439 [==============================] - 4s 81us/sample - loss: 0.8996 - accuracy: 0.7251 - val_loss: 0.9099 - val_accuracy: 0.7147
# Epoch 12/200
# 47439/47439 [==============================] - 3s 64us/sample - loss: 0.8969 - accuracy: 0.7210 - val_loss: 0.9096 - val_accuracy: 0.7135
# Epoch 13/200
# 47439/47439 [==============================] - 4s 84us/sample - loss: 0.8933 - accuracy: 0.7257 - val_loss: 0.9166 - val_accuracy: 0.7141
# Epoch 14/200
# 47439/47439 [==============================] - 4s 81us/sample - loss: 0.8947 - accuracy: 0.7230 - val_loss: 0.8965 - val_accuracy: 0.7171
# Epoch 15/200
# 47439/47439 [==============================] - 3s 59us/sample - loss: 0.8923 - accuracy: 0.7238 - val_loss: 0.8877 - val_accuracy: 0.7206
# Epoch 16/200
# 47439/47439 [==============================] - 3s 60us/sample - loss: 0.8918 - accuracy: 0.7223 - val_loss: 0.9085 - val_accuracy: 0.7067
# Epoch 17/200
# 47439/47439 [==============================] - 3s 64us/sample - loss: 0.8889 - accuracy: 0.7242 - val_loss: 0.9111 - val_accuracy: 0.7171
# Epoch 18/200
# 47439/47439 [==============================] - 3s 63us/sample - loss: 0.8875 - accuracy: 0.7248 - val_loss: 0.8936 - val_accuracy: 0.7189

# %%
model.save_weights('./models/doc2vec/doc2vec_news_classifier')

# %%
def predict(X, topn=3):
    preprocessed_X = preprocess_text(X)
    vec_X = doc2vec_model.infer_vector(preprocessed_X)
    vec_X = vec_X.reshape(1, vec_X.shape[0])
    pred = model.predict(vec_X)
    pred_i = [(topics_index_to_name_map[i], p) for i,p in enumerate(pred[0])]
    pred_sorted = sorted(pred_i, key=lambda x: x[1], reverse=True)
    return pred_sorted[:topn]

# %%
df
# Out:
#         source_id             source  day  month  year  \
# 0          163795  Belfast Telegraph    1      1  2014
# 3          163795  Belfast Telegraph    1      1  2014
# 5          163795  Belfast Telegraph    1      1  2014
# 6          163795  Belfast Telegraph    1      1  2014
# 9          163795  Belfast Telegraph    1      1  2014
# ...           ...                ...  ...    ...   ...
# 147277     412338              Wales   31      1  2014
# 147278     412338              Wales   31      1  2014
# 147279     412338              Wales   31      1  2014
# 147280     412338              Wales   31      1  2014
# 147283     412338              Wales   31      1  2014
#
#                                              program_name  \
# 0          Hunt begins for team to secure cultural legacy
# 3       Derry treated as poor relation, say rail campa...
# 5       FAILURE REVERBERATES;\nFrustration in Washingt...
# 6                                    5 GREAT THINGS TO DO
# 9       Despite a lot of seemingly tireless work, it g...
# ...                                                   ...
# 147277  Six Nations 2014: 26 pictures of the great pla...
# 147278  Aled Blake: Rejoice, rugby's cultural monopoly...
# 147279  Wales weather: Fresh storms threaten more floo...
# 147280  Wales weather: Weekend high tides expected to ...
# 147283  Hannah Jones: Sorry Mam, but I've tried cannab...
#
#                                                transcript  \
# 0       As the clock struck midnight last night, Londo...
# 3       Campaigners from Into The West argued that Der...
# 5       Minutes before the final text of the negotiati...
# 6       Little 'uns can get right up close to the acti...
# 9       Many had hung around - seemingly unwilling or ...
# ...                                                   ...
# 147277  Since the Grand Slam win in 2005 Wales have wo...
# 147278  An overstatement? I don't think so. Why? At th...
# 147279  A combination of driving rain, high tides, a p...
# 147280  A combination of driving rain, high tides, a p...
# 147283  Worse, I inhaled. Worse even still, I don't th...
#
#                                           predicted_topic  \
# 0       [(Science and technology, 0.7244457), (Culture...
# 3       [(Transport, 0.6714804), (Parliament, governme...
# 5       [(Parliament, government and politics, 0.55315...
# 6       [(Culture, media and sport, 0.46135047), (Othe...
# 9       [(Parliament, government and politics, 0.40623...
# ...                                                   ...
# 147277  [(Parliament, government and politics, 0.84473...
# 147278  [(Parliament, government and politics, 0.58371...
# 147279  [(Parliament, government and politics, 0.44981...
# 147280  [(Parliament, government and politics, 0.55013...
# 147283  [(Parliament, government and politics, 0.49223...
#
#                                   top_class  topic
# 0                    Science and technology     16
# 3                                 Transport     19
# 5       Parliament, government and politics     15
# 6                  Culture, media and sport      5
# 9       Parliament, government and politics     15
# ...                                     ...    ...
# 147277  Parliament, government and politics     15
# 147278  Parliament, government and politics     15
# 147279  Parliament, government and politics     15
# 147280  Parliament, government and politics     15
# 147283  Parliament, government and politics     15
#
# [59299 rows x 10 columns]

# %%
df['predicted_topic2'] = df.swifter.apply(lambda row: predict(row['transcript']), axis=1)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Pandas Apply', max=59299.0, style=ProgressStyle(descripti…
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# ...
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)

# %%
df
# Out:
#         source_id             source  day  month  year  \
# 0          163795  Belfast Telegraph    1      1  2014
# 3          163795  Belfast Telegraph    1      1  2014
# 5          163795  Belfast Telegraph    1      1  2014
# 6          163795  Belfast Telegraph    1      1  2014
# 9          163795  Belfast Telegraph    1      1  2014
# ...           ...                ...  ...    ...   ...
# 147277     412338              Wales   31      1  2014
# 147278     412338              Wales   31      1  2014
# 147279     412338              Wales   31      1  2014
# 147280     412338              Wales   31      1  2014
# 147283     412338              Wales   31      1  2014
#
#                                              program_name  \
# 0          Hunt begins for team to secure cultural legacy
# 3       Derry treated as poor relation, say rail campa...
# 5       FAILURE REVERBERATES;\nFrustration in Washingt...
# 6                                    5 GREAT THINGS TO DO
# 9       Despite a lot of seemingly tireless work, it g...
# ...                                                   ...
# 147277  Six Nations 2014: 26 pictures of the great pla...
# 147278  Aled Blake: Rejoice, rugby's cultural monopoly...
# 147279  Wales weather: Fresh storms threaten more floo...
# 147280  Wales weather: Weekend high tides expected to ...
# 147283  Hannah Jones: Sorry Mam, but I've tried cannab...
#
#                                                transcript  \
# 0       As the clock struck midnight last night, Londo...
# 3       Campaigners from Into The West argued that Der...
# 5       Minutes before the final text of the negotiati...
# 6       Little 'uns can get right up close to the acti...
# 9       Many had hung around - seemingly unwilling or ...
# ...                                                   ...
# 147277  Since the Grand Slam win in 2005 Wales have wo...
# 147278  An overstatement? I don't think so. Why? At th...
# 147279  A combination of driving rain, high tides, a p...
# 147280  A combination of driving rain, high tides, a p...
# 147283  Worse, I inhaled. Worse even still, I don't th...
#
#                                           predicted_topic  \
# 0       [(Science and technology, 0.7244457), (Culture...
# 3       [(Transport, 0.6714804), (Parliament, governme...
# 5       [(Parliament, government and politics, 0.55315...
# 6       [(Culture, media and sport, 0.46135047), (Othe...
# 9       [(Parliament, government and politics, 0.40623...
# ...                                                   ...
# 147277  [(Parliament, government and politics, 0.84473...
# 147278  [(Parliament, government and politics, 0.58371...
# 147279  [(Parliament, government and politics, 0.44981...
# 147280  [(Parliament, government and politics, 0.55013...
# 147283  [(Parliament, government and politics, 0.49223...
#
#                                   top_class  topic  \
# 0                    Science and technology     16
# 3                                 Transport     19
# 5       Parliament, government and politics     15
# 6                  Culture, media and sport      5
# 9       Parliament, government and politics     15
# ...                                     ...    ...
# 147277  Parliament, government and politics     15
# 147278  Parliament, government and politics     15
# 147279  Parliament, government and politics     15
# 147280  Parliament, government and politics     15
# 147283  Parliament, government and politics     15
#
#                                          predicted_topic2
# 0       [(Parliament, government and politics, 0.40627...
# 3       [(Transport, 0.9525657), (Parliament, governme...
# 5       [(Parliament, government and politics, 0.84827...
# 6       [(Culture, media and sport, 0.6547228), (Parli...
# 9       [(Parliament, government and politics, 0.61372...
# ...                                                   ...
# 147277  [(Culture, media and sport, 0.7159495), (Parli...
# 147278  [(Parliament, government and politics, 0.88941...
# 147279  [(Energy and environment, 0.5894057), (Parliam...
# 147280  [(Energy and environment, 0.6159892), (Parliam...
# 147283  [(Others, 0.70770824), (Parliament, government...
#
# [59299 rows x 11 columns]

# %%
df = df.drop(['top_class', 'topic'], axis=1)

# %%
df.to_csv('./doc2vec_on_news_transcripts_preds.csv')

# %%
import os
path = './data/bbc/2016/transcripts'
files = os.listdir(path)

data = []
for source in files:
    data.append(pd.read_csv(os.path.join(path, source)))
df = pd.concat(data)
df = df.drop(['Unnamed: 0', 'Has Transcript', 'Unavailable link', 'Unavailable reason'], axis=1)
df
# Out:
#           Source         Date     Program Name   Time Duration  \
# 0    BBC1 London   6-dec-2014         BBC News  22:00  20 mins
# 1    BBC1 London   7-dec-2014         BBC News  22:00  20 mins
# 2    BBC1 London   7-dec-2014  BBC London News  22:20  10 mins
# 3    BBC1 London   5-dec-2014  BBC News at One  13:00  30 mins
# 4    BBC1 London   5-dec-2014  BBC News at Ten  22:00  25 mins
# ..           ...          ...              ...    ...      ...
# 107  BBC1 London  26-jun-2014  BBC News at One  13:00  30 mins
# 108  BBC1 London  26-jun-2014  BBC London News  13:30  15 mins
# 109  BBC1 London  26-jun-2014  BBC News at Six  19:10  25 mins
# 110  BBC1 London  26-jun-2014  BBC News at Ten  22:00  30 mins
# 111  BBC1 London  26-jun-2014  BBC London News  22:30  10 mins
#
#                                             Transcript
# 0    #Ah... # Dreaming ofthe days # APPLAUSE Hiya, ...
# 1    Alex Salmond unveils plans to seek a Westminst...
# 2    against the illegal trade in wildlife. He’s ve...
# 3    # The way I love you. # Making Christmas speci...
# 4    Two British men are jailed for travelling to S...
# ..                                                 ...
# 107  Hello, Glastonbury. Hello, Glastonbury! Hello,...
# 108  A little bit more cloud around but some of us ...
# 109  Yet more shocking re-lations about the extent ...
# 110  The most detailed picture yet ofthe The most d...
# 111  He was known as Mark Stone. But in fact, he wa...
#
# [1243 rows x 6 columns]

# %%
df['predicted_topic'] = df.swifter.apply(lambda row: predict(row['Transcript']), axis=1)
# Out:
# /home/ubuntu/anaconda3/envs/econ/lib/python3.7/site-packages/swifter/swifter.py:55: UserWarning: This pandas object has duplicate indices, and swifter may not be able to improve performance. Consider resetting the indices with `df.reset_index(drop=True)`.
#   "This pandas object has duplicate indices, and swifter may not be able to improve performance. Consider resetting the indices with `df.reset_index(drop=True)`."
# HBox(children=(FloatProgress(value=0.0, description='Pandas Apply', max=1243.0, style=ProgressStyle(descriptio…
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)
# (100,)

# %%
df
# Out:
#           Source         Date     Program Name   Time Duration  \
# 0    BBC1 London   6-dec-2014         BBC News  22:00  20 mins
# 1    BBC1 London   7-dec-2014         BBC News  22:00  20 mins
# 2    BBC1 London   7-dec-2014  BBC London News  22:20  10 mins
# 3    BBC1 London   5-dec-2014  BBC News at One  13:00  30 mins
# 4    BBC1 London   5-dec-2014  BBC News at Ten  22:00  25 mins
# ..           ...          ...              ...    ...      ...
# 107  BBC1 London  26-jun-2014  BBC News at One  13:00  30 mins
# 108  BBC1 London  26-jun-2014  BBC London News  13:30  15 mins
# 109  BBC1 London  26-jun-2014  BBC News at Six  19:10  25 mins
# 110  BBC1 London  26-jun-2014  BBC News at Ten  22:00  30 mins
# 111  BBC1 London  26-jun-2014  BBC London News  22:30  10 mins
#
#                                             Transcript  \
# 0    #Ah... # Dreaming ofthe days # APPLAUSE Hiya, ...
# 1    Alex Salmond unveils plans to seek a Westminst...
# 2    against the illegal trade in wildlife. He’s ve...
# 3    # The way I love you. # Making Christmas speci...
# 4    Two British men are jailed for travelling to S...
# ..                                                 ...
# 107  Hello, Glastonbury. Hello, Glastonbury! Hello,...
# 108  A little bit more cloud around but some of us ...
# 109  Yet more shocking re-lations about the extent ...
# 110  The most detailed picture yet ofthe The most d...
# 111  He was known as Mark Stone. But in fact, he wa...
#
#                                        predicted_topic
# 0    [(Parliament, government and politics, 0.37201...
# 1    [(Parliament, government and politics, 0.70019...
# 2    [(Transport, 0.40607873), (Culture, media and ...
# 3    [(Parliament, government and politics, 0.42028...
# 4    [(Crime, civil law, justice and rights, 0.5460...
# ..                                                 ...
# 107  [(Crime, civil law, justice and rights, 0.6193...
# 108  [(Culture, media and sport, 0.40613863), (Parl...
# 109  [(Crime, civil law, justice and rights, 0.5205...
# 110  [(Crime, civil law, justice and rights, 0.5720...
# 111  [(Parliament, government and politics, 0.56809...
#
# [1243 rows x 7 columns]

# %%
df.to_csv('doc2vec_on_news_bbc_2016_preds.csv')
